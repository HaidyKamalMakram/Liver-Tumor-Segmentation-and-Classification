# %% [markdown]
# # **Unet Model (ResNet 50)**

# %% [markdown]
# # **Data Prepare**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # **Preprocessing**

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import glob

import nibabel as nib
import cv2
import imageio
from tqdm.notebook import tqdm
from ipywidgets import *
from PIL import Image

# %%
#!pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html > /dev/null
#!pip install --upgrade kornia > /dev/null
#!pip install allennlp==1.1.0.rc4 > /dev/null
#!pip install --upgrade fastai > /dev/null
import fastai; fastai.__version__
# Out:
# '2.7.11'

# %%
from fastai.basics import *
from fastai.vision.all import *
from fastai.data.transforms import *

# %%
# Create a meta file for nii files processing

file_list = []
for dirname, _, filenames in os.walk('/content/liver-tumor-segmentation'):
    for filename in filenames:
#         print(os.path.join(dirname, filename))
        file_list.append((dirname,filename))

for dirname, _, filenames in os.walk('/content/liver-tumor-segmentation-part-2'):
    for filename in filenames:
        file_list.append((dirname,filename))

df_files = pd.DataFrame(file_list, columns =['dirname', 'filename'])
df_files.sort_values(by=['filename'], ascending=True)
# Out:
#                                                  dirname              filename
# 44       /content/liver-tumor-segmentation/segmentations    segmentation-0.nii
# 56       /content/liver-tumor-segmentation/segmentations    segmentation-1.nii
# 34       /content/liver-tumor-segmentation/segmentations  segmentation-100.nii
# 87       /content/liver-tumor-segmentation/segmentations  segmentation-101.nii
# 66       /content/liver-tumor-segmentation/segmentations  segmentation-102.nii
# ..                                                   ...                   ...
# 131  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-86.nii
# 126  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-87.nii
# 123  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-88.nii
# 135  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-89.nii
# 13          /content/liver-tumor-segmentation/volume_pt1          volume-9.nii
#
# [143 rows x 2 columns]

# %%
# Map CT scan and label

df_files["mask_dirname"] = "" ; df_files["mask_filename"] = ""

for i in range(131):
    ct = f"volume-{i}.nii"
    mask = f"segmentation-{i}.nii"

    df_files.loc[df_files['filename'] == ct, 'mask_filename'] = mask
    df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = "/content/liver-tumor-segmentation/segmentations"

# drop segment rows
df_files = df_files[df_files.mask_filename != ''].sort_values(by=['filename']).reset_index(drop=True)
print(len(df_files))
df_files
# Out:
# 72
#                                                 dirname        filename  \
# 0          /content/liver-tumor-segmentation/volume_pt1    volume-0.nii
# 1          /content/liver-tumor-segmentation/volume_pt1    volume-1.nii
# 2          /content/liver-tumor-segmentation/volume_pt1   volume-10.nii
# 3   /content/liver-tumor-segmentation-part-2/volume_pt6  volume-100.nii
# 4   /content/liver-tumor-segmentation-part-2/volume_pt8  volume-101.nii
# ..                                                  ...             ...
# 67  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-86.nii
# 68  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-87.nii
# 69  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-88.nii
# 70  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-89.nii
# 71         /content/liver-tumor-segmentation/volume_pt1    volume-9.nii
#
#                                        mask_dirname         mask_filename
# 0   /content/liver-tumor-segmentation/segmentations    segmentation-0.nii
# 1   /content/liver-tumor-segmentation/segmentations    segmentation-1.nii
# 2   /content/liver-tumor-segmentation/segmentations   segmentation-10.nii
# 3   /content/liver-tumor-segmentation/segmentations  segmentation-100.nii
# 4   /content/liver-tumor-segmentation/segmentations  segmentation-101.nii
# ..                                              ...                   ...
# 67  /content/liver-tumor-segmentation/segmentations   segmentation-86.nii
# 68  /content/liver-tumor-segmentation/segmentations   segmentation-87.nii
# 69  /content/liver-tumor-segmentation/segmentations   segmentation-88.nii
# 70  /content/liver-tumor-segmentation/segmentations   segmentation-89.nii
# 71  /content/liver-tumor-segmentation/segmentations    segmentation-9.nii
#
# [72 rows x 4 columns]

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample = 1
sample_ct   = read_nii(df_files.loc[sample,'dirname']+"/"+df_files.loc[sample,'filename'])
sample_mask  = read_nii(df_files.loc[sample,'mask_dirname']+"/"+df_files.loc[sample,'mask_filename'])
sample_ct.shape, sample_mask.shape
# Out:
# ((512, 512, 123), (512, 512, 123))

# %%
print(np.amin(sample_ct), np.amax(sample_ct))
print(np.amin(sample_mask), np.amax(sample_mask))
# Out:
# -3024.0 3071.0
# 0.0 2.0

# %%
# Preprocess the nii file

dicom_windows = types.SimpleNamespace(
    brain=(80,40),
    subdural=(254,100),
    stroke=(8,32),
    brain_bone=(2800,600),
    brain_soft=(375,40),
    lungs=(1500,-600),
    mediastinum=(350,50),
    abdomen_soft=(400,50),
    liver=(150,30),
    spine_soft=(250,50),
    spine_bone=(1800,400),
    custom = (200,60)
)

@patch
def windowed(self:Tensor, w, l):
    px = self.clone()
    px_min = l - w//2
    px_max = l + w//2
    px[px<px_min] = px_min
    px[px>px_max] = px_max
    return (px-px_min) / (px_max-px_min)

plt.imshow(tensor(sample_ct[...,50].astype(np.float32)).windowed(*dicom_windows.liver), cmap=plt.cm.bone);

# %%
def plot_sample(array_list, color_map = 'nipy_spectral'):
    '''
    Plots and a slice with all available annotations
    '''
    fig = plt.figure(figsize=(18,15))

    plt.subplot(1,4,1)
    plt.imshow(array_list[0], cmap='bone')
    plt.title('Original Image')

    plt.subplot(1,4,2)
    plt.imshow(tensor(array_list[0].astype(np.float32)).windowed(*dicom_windows.liver), cmap='bone');
    plt.title('Windowed Image')

    plt.subplot(1,4,3)
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Mask')

    plt.subplot(1,4,4)
    plt.imshow(array_list[0], cmap='bone')
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Liver & Mask')

    plt.show()

# %%
sample=50
sample_slice = tensor(sample_ct[...,sample].astype(np.float32))

plot_sample([sample_ct[...,sample], sample_mask[...,sample]])

# %%
# Check the mask values
mask = Image.fromarray(sample_mask[...,sample].astype('uint8'), mode="L")
unique, counts = np.unique(mask, return_counts=True)
print( np.array((unique, counts)).T)
# Out:
# [[     0 252044]
#  [     1  10100]]

# %%
# Preprocessing functions

class TensorCTScan(TensorImageBW): _show_args = {'cmap':'bone'}

@patch
def freqhist_bins(self:Tensor, n_bins=100):
    "A function to split the range of pixel values into groups, such that each group has around the same number of pixels"
    imsd = self.view(-1).sort()[0]
    t = torch.cat([tensor([0.001]),
                   torch.arange(n_bins).float()/n_bins+(1/2/n_bins),
                   tensor([0.999])])
    t = (len(imsd)*t).long()
    return imsd[t].unique()

@patch
def hist_scaled(self:Tensor, brks=None):
    "Scales a tensor using `freqhist_bins` to values between 0 and 1"
    if self.device.type=='cuda': return self.hist_scaled_pt(brks)
    if brks is None: brks = self.freqhist_bins()
    ys = np.linspace(0., 1., len(brks))
    x = self.numpy().flatten()
    x = np.interp(x, brks.numpy(), ys)
    return tensor(x).reshape(self.shape).clamp(0.,1.)


@patch
def to_nchan(x:Tensor, wins, bins=None):
    res = [x.windowed(*win) for win in wins]
    if not isinstance(bins,int) or bins!=0: res.append(x.hist_scaled(bins).clamp(0,1))
    dim = [0,1][x.dim()==3]
    return TensorCTScan(torch.stack(res, dim=dim))


@patch
def save_jpg(x:(Tensor), path, wins, bins=None, quality=90):
    fn = Path(path).with_suffix('.jpg')
    x = (x.to_nchan(wins, bins)*255).byte()
    im = Image.fromarray(x.permute(1,2,0).numpy(), mode=['RGB','CMYK'][x.shape[0]==4])
    im.save(fn, quality=quality)

_,axs=subplots(1,1)

sample_slice.save_jpg('test.jpg', [dicom_windows.liver,dicom_windows.custom])
show_image(Image.open('test.jpg'), ax=axs[0])
# Out:
# <Axes: >

# %%
# Make custom JPG files for Unet training
# Total number of 131 nii files contains 67072 slices

GENERATE_JPG_FILES = True   # warning: generation takes ~ 1h

if (GENERATE_JPG_FILES) :

    path = Path(".")

    os.makedirs('train_images',exist_ok=True)
    os.makedirs('train_masks',exist_ok=True)

    for ii in tqdm(range(0,len(df_files),3)): # take 1/3 nii files for training
        curr_ct        = read_nii(df_files.loc[ii,'dirname']+"/"+df_files.loc[ii,'filename'])
        curr_mask      = read_nii(df_files.loc[ii,'mask_dirname']+"/"+df_files.loc[ii,'mask_filename'])
        curr_file_name = str(df_files.loc[ii,'filename']).split('.')[0]
        curr_dim       = curr_ct.shape[2] # 512, 512, curr_dim

        for curr_slice in range(0,curr_dim,2): # export every 2nd slice for training
            data = tensor(curr_ct[...,curr_slice].astype(np.float32))
            mask = Image.fromarray(curr_mask[...,curr_slice].astype('uint8'), mode="L")
            data.save_jpg(f"train_images/{curr_file_name}_slice_{curr_slice}.jpg", [dicom_windows.liver,dicom_windows.custom])
            mask.save(f"train_masks/{curr_file_name}_slice_{curr_slice}_mask.png")
else:

    path = Path("/content/liver-segmentation-with-fastai-v2") # read jpg from saved kernel output
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]

# %% [markdown]
# # **Training**

# %%
bs = 16
im_size = 128

codes = np.array(["background","liver","tumor"])

def get_x(fname:Path): return fname
def label_func(x): return path/'train_masks'/f'{x.stem}_mask.png'

tfms = [IntToFloatTensor(),Normalize()]

db = DataBlock(blocks=(ImageBlock(),MaskBlock(codes)),  #codes = {"Backround": 0,"Liver": 1,"Tumor": 2}
               batch_tfms=tfms,
               splitter=RandomSplitter(),
               item_tfms=[Resize(im_size)],
               get_items=get_image_files,
               get_y=label_func
              )

ds = db.datasets(source=path/'train_images')

# %%
idx=400
imgs = [ds[idx][0],ds[idx][1]]
fig,axs = plt.subplots(1, 2)
for i,ax in enumerate(axs.flatten()):
    ax.axis('off')
    ax.imshow(imgs[i]) #, cmap='gray'

# %%
unique, counts = np.unique(array(ds[idx][1]), return_counts=True)

print( np.array((unique, counts)).T)
# Out:
# [[     0 244060]
#  [     1  18084]]

# %%
dls = db.dataloaders(path/'train_images',bs = bs) #, num_workers=0
dls.show_batch()

# %%
def foreground_acc(inp, targ, bkg_idx=0, axis=1):  # exclude a background from metric
    "Computes non-background accuracy for multiclass segmentation"
    targ = targ.squeeze(1)
    mask = targ != bkg_idx
    return (inp.argmax(dim=axis)[mask]==targ[mask]).float().mean()

def cust_foreground_acc(inp, targ):  # # include a background into the metric
    return foreground_acc(inp=inp, targ=targ, bkg_idx=3, axis=1) # 3 is a dummy value to include the background which is 0

# %%
learn = cnn_learner(dls, resnet50, loss_func=CrossEntropyLossFlat(axis=1), metrics=[foreground_acc, cust_foreground_acc])
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
learn.fine_tune(1, wd=0.1, cbs=SaveModelCallback() )

#done take it
#learn.unfreeze()
#learn.fit_one_cycle(1, lr_max=slice(1e-7, 1e-6))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>cust_foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.154746</td>
#       <td>0.028584</td>
#       <td>0.757966</td>
#       <td>0.991839</td>
#       <td>1:53:37</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.028584174811840057.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>cust_foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.008773</td>
#       <td>0.007700</td>
#       <td>0.921931</td>
#       <td>0.997099</td>
#       <td>2:05:11</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.0076997713185846806.

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# Save the model
#/content/gdrive/MyDrive/Graduation Project /GP_FirstModels
learn.export(path/f'Liver_segmentation')

# %% [markdown]
# # **Testing**

# %%
# Load saved model
if (GENERATE_JPG_FILES) :

    tfms = [Resize(im_size), IntToFloatTensor(),Normalize()]
    #/content/gdrive/MyDrive/Graduation Project /GP_FirstModels
    learn0               = load_learner(path/f'Liver_segmentation',cpu=False )
    learn0.dls.transform = tfms

# %%
def nii_tfm(fn,wins):

    test_nii  = read_nii(fn)
    curr_dim  = test_nii.shape[2] # 512, 512, curr_dim
    slices = []

    for curr_slice in range(curr_dim):
        data = tensor(test_nii[...,curr_slice].astype(np.float32))
        data = (data.to_nchan(wins)*255).byte()
        slices.append(TensorImage(data))

    return slices

# %%
len(df_files)
# Out:
# 72

# %%
os.mkdir('/content/train_m/')
os.mkdir('/content/train_i/')
os.mkdir('/content/train_RGB_i/')

# %%
for i in range(len(df_files)):
  test_nii   = read_nii(df_files.loc[i,'dirname']+"/"+df_files.loc[i,'filename'])
  test_mask  = read_nii(df_files.loc[i,'mask_dirname']+"/"+df_files.loc[i,'mask_filename'])

# %%
counter = 0
for i in range(len(df_files)):

  for j in range(test_nii.shape[2]-1):
    r = test_mask[...,0]
    strnum = str(counter)
    counter = counter + 1
    sample_slice = tensor(test_nii[...,j].astype(np.float32))
    if test_mask[...,j].any()  != r.all():
      if test_nii[...,j].any() != r.all():

        plt.imsave('/content/train_m/' + 'slice'+strnum+'.png', test_mask[...,j])
        plt.imsave('/content/train_i/' + 'slice'+strnum+'.png', tensor([test_nii[...,j], test_mask[...,j]][0].astype(np.float32)).windowed(*dicom_windows.liver), cmap='bone')
        plt.imsave('/content/train_RGB_i/' + 'slice'+strnum+'.png', tensor([test_nii[...,j], test_mask[...,j]][0].astype(np.float32)).windowed(*dicom_windows.liver))

# %%
len(os.listdir('/content/train_m/'))
# Out:
# 19872

# %%
counter
# Out:
# 49248

# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import os

lst =[]
lst_image =[]
lst_RGB_image =[]

dir_m = '/content/train_m/'
dir_i = '/content/train_i/'
dir_RGB_i = '/content/train_RGB_i/'

# assign directory
directory = dir_m

# iterate over files in that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):

        image_i = cv2.imread(f)
        original = image_i.copy()
        img = original

        # set red range
        lowcolor = (0,0,10)
        highcolor =(140, 144, 32)
        #cv2_imshow(img)
        # threshold
        thresh = cv2.inRange(img, lowcolor, highcolor)
        count = np.sum(np.nonzero(thresh))
        #print("Count = ",count)

        if count == 0:
            print("Not Tumor")
        else:
            print("Tumor Found")

        # Tumor Found
        if (count > 0):

          image_i = cv2.cvtColor(image_i, cv2.COLOR_BGR2HSV)
          lower = np.array([22, 93, 0], dtype="uint8")
          upper = np.array([45, 255, 255], dtype="uint8")
          mask = cv2.inRange(image_i, lower, upper)

          cnts = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
          cnts = cnts[0] if len(cnts) == 2 else cnts[1]

          for c in cnts:
              x,y,w,h = cv2.boundingRect(c)
              cv2.rectangle(original, (x, y), (x + w, y + h), (36,255,12), 2)

          ##print('Mask')
          ##cv2_imshow(mask)
          ##print('original')
          ##cv2_imshow(original)
          ##cv2.waitKey()


          (cnt, hierarchy) = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
          rgb = cv2.cvtColor(image_i, cv2.COLOR_BGR2RGB)
          cv2.drawContours(rgb, cnt, -1, (0, 255, 0), 2)


          imageCounter = 0
          plt.imsave('rgb'+str(imageCounter)+'.png',rgb)

          image_f= cv2.imread('/content/rgb'+str(imageCounter)+'.png')
          imageCounter = 1 + imageCounter
          original_image= image_f

          gray= cv2.cvtColor(image_f,cv2.COLOR_BGR2GRAY)

          edged= cv2.Canny(gray, 50,200)

          contours, hierarchy= cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

          print('image')
          cv2_imshow(image_f)
          cv2.waitKey(0)
          cv2.destroyAllWindows()


          def get_contour_areas(contours):

              all_areas= []
              r = 0
              cnt = ()
              for cnt in contours:
                  area= cv2.contourArea(cnt)
                  r = round(((area * 2.54) / 96), 2)
                  all_areas.append(r)

              return all_areas



          print('** Total Data ** \n Object Counter: ',len(cnt) ,"\n Objects size: ", get_contour_areas(cnt))
          lst.append([f, len(cnt) , get_contour_areas(cnt)])
          lst_image.append([os.path.join(dir_i, f[17:]), len(cnt) , get_contour_areas(cnt))
          lst_RGB_image.append([os.path.join(dir_RGB_i, f[17:]), len(cnt) , get_contour_areas(cnt)])

          cnt = tuple()
          contours = tuple()

          # No Tumor
        else:
          print('-****************No NO NO NON NO *********** \n ', f)
          cv2_imshow(original)
          lst.append([f, 0 , [0]])
          lst_image.append([os.path.join(dir_i, f[17:]), 0 , [0]])
          lst_RGB_image.append([os.path.join(dir_RGB_i, f[17:]), 0 , [0]])

# %%
lst
# Out:
# [['/content/train_m/slice12197.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_m/slice43011.png', 3, [2.67, 0.04, 231.21]],
#  ['/content/train_m/slice13556.png', 3, [0.38, 1.6, 260.67]],
#  ['/content/train_m/slice32559.png', 1, [1.53]],
#  ['/content/train_m/slice13515.png', 2, [203.74, 9.59]],
#  ['/content/train_m/slice12915.png', 3, [2.67, 0.04, 231.21]],
#  ['/content/train_m/slice49179.png', 2, [2.57, 186.09]],
#  ['/content/train_m/slice33903.png', 0, [0]],
#  ['/content/train_m/slice12285.png', 0, [0]],
#  ['/content/train_m/slice38953.png', 0, [0]],
#  ['/content/train_m/slice45581.png', 1, [54.41]],
#  ['/content/train_m/slice14903.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_m/slice21148.png', 1, [94.92]],
#  ['/content/train_m/slice34096.png', 2, [1.77, 278.1]],
#  ['/content/train_m/slice23041.png', 2, [189.52, 15.4]],
#  ['/content/train_m/slice12044.png', 0, [0]],
#  ['/content/train_m/slice8017.png', 1, [207.02]],
#  ['/content/train_m/slice20937.png', 0, [0]],
#  ['/content/train_m/slice39600.png', 2, [4.72, 204.21]],
#  ['/content/train_m/slice12917.png', 2, [3.53, 225.61]],
#  ['/content/train_m/slice4605.png', 1, [227.05]],
#  ['/content/train_m/slice29994.png', 2, [2.83, 280.34]],
#  ['/content/train_m/slice19798.png', 1, [0.44]],
#  ['/content/train_m/slice32705.png', 2, [1.03, 246.09]],
#  ['/content/train_m/slice10894.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_m/slice17739.png', 2, [0.3, 6.3]],
#  ['/content/train_m/slice4722.png', 1, [172.81]],
#  ['/content/train_m/slice37362.png', 1, [13.52]],
#  ['/content/train_m/slice22519.png', 1, [64.66]],
#  ['/content/train_m/slice18223.png', 1, [68.09]],
#  ['/content/train_m/slice14993.png', 1, [84.71]],
#  ['/content/train_m/slice3147.png', 1, [1.53]],
#  ['/content/train_m/slice10016.png', 1, [78.83]],
#  ['/content/train_m/slice45621.png', 2, [203.84, 6.54]],
#  ['/content/train_m/slice41609.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_m/slice39438.png', 1, [146.83]],
#  ['/content/train_m/slice26482.png', 1, [207.02]],
#  ['/content/train_m/slice44278.png', 1, [224.78]],
#  ['/content/train_m/slice32097.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_m/slice14900.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_m/slice35429.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_m/slice29971.png', 2, [1.79, 259.36]],
#  ['/content/train_m/slice38268.png', 0, [0]],
#  ['/content/train_m/slice34097.png', 2, [2.12, 277.47]],
#  ['/content/train_m/slice17005.png', 2, [5.56, 257.6]],
#  ['/content/train_m/slice25781.png', 2, [195.37, 9.54]],
#  ['/content/train_m/slice10125.png', 2, [0.12, 201.14]],
#  ['/content/train_m/slice34024.png', 2, [219.34, 0.48]],
#  ['/content/train_m/slice27899.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_m/slice13427.png', 1, [28.46]],
#  ['/content/train_m/slice662.png', 0, [0]],
#  ['/content/train_m/slice7269.png', 1, [23.71]],
#  ['/content/train_m/slice16184.png', 2, [1.84, 157.64]],
#  ['/content/train_m/slice30635.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_m/slice11371.png', 1, [19.67]],
#  ['/content/train_m/slice1251.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_m/slice22517.png', 1, [84.71]],
#  ['/content/train_m/slice27819.png', 1, [184.03]],
#  ['/content/train_m/slice31213.png', 1, [33.77]],
#  ['/content/train_m/slice1147.png', 1, [196.02]],
#  ['/content/train_m/slice31251.png', 2, [191.45, 11.15]],
#  ['/content/train_m/slice17584.png', 1, [210.25]],
#  ['/content/train_m/slice44350.png', 1, [272.64]],
#  ['/content/train_m/slice33403.png', 2, [0.62, 279.65]],
#  ['/content/train_m/slice2465.png', 1, [0.19]],
#  ['/content/train_m/slice20311.png', 2, [198.05, 8.0]],
#  ['/content/train_m/slice3999.png', 2, [1.15, 272.53]],
#  ['/content/train_m/slice14885.png', 2, [198.28, 10.12]],
#  ['/content/train_m/slice7962.png', 1, [60.17]],
#  ['/content/train_m/slice32785.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_m/slice14894.png', 2, [179.16, 5.34]],
#  ['/content/train_m/slice31349.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_m/slice1217.png', 2, [175.59, 3.52]],
#  ['/content/train_m/slice38780.png', 2, [201.69, 7.33]],
#  ['/content/train_m/slice2479.png', 1, [19.67]],
#  ['/content/train_m/slice23161.png', 2, [5.56, 257.6]],
#  ['/content/train_m/slice18933.png', 1, [199.23]],
#  ['/content/train_m/slice32119.png', 0, [0]],
#  ['/content/train_m/slice36771.png', 2, [203.74, 9.59]],
#  ['/content/train_m/slice8632.png', 1, [6.91]],
#  ['/content/train_m/slice36129.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_m/slice30499.png', 0, [0]],
#  ['/content/train_m/slice17502.png', 0, [0]],
#  ['/content/train_m/slice1846.png', 2, [205.58, 5.93]],
#  ['/content/train_m/slice22465.png', 2, [0.56, 276.34]],
#  ['/content/train_m/slice40840.png', 1, [210.25]],
#  ['/content/train_m/slice535.png', 2, [171.82, 1.59]],
#  ['/content/train_m/slice12717.png', 0, [0]],
#  ['/content/train_m/slice14070.png', 0, [0]],
#  ['/content/train_m/slice30666.png', 2, [0.75, 277.48]],
#  ['/content/train_m/slice17657.png', 2, [1.03, 246.09]],
#  ['/content/train_m/slice8163.png', 2, [0.3, 6.3]],
#  ['/content/train_m/slice25058.png', 1, [38.63]],
#  ['/content/train_m/slice19692.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_m/slice44396.png', 1, [166.78]],
#  ['/content/train_m/slice20327.png', 1, [206.35]],
#  ['/content/train_m/slice6074.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_m/slice4542.png', 1, [60.17]],
#  ['/content/train_m/slice2463.png', 1, [1.53]],
#  ['/content/train_m/slice23114.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_m/slice27837.png', 2, [203.84, 6.54]],
#  ['/content/train_m/slice9987.png', 1, [1.53]],
#  ['/content/train_m/slice39560.png', 1, [277.02]],
#  ['/content/train_m/slice35360.png', 2, [201.69, 7.33]],
#  ['/content/train_m/slice2585.png', 2, [175.59, 3.52]],
#  ['/content/train_m/slice19637.png', 1, [209.4]],
#  ['/content/train_m/slice9453.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_m/slice20960.png', 1, [78.83]],
#  ['/content/train_m/slice19080.png', 2, [4.72, 204.21]],
#  ['/content/train_m/slice7230.png', 0, [0]],
#  ['/content/train_m/slice47611.png', 0, [0]],
#  ['/content/train_m/slice5987.png', 2, [212.87, 6.28]],
#  ['/content/train_m/slice4639.png', 2, [171.82, 1.59]],
#  ['/content/train_m/slice40164.png', 1, [205.71]],
#  ['/content/train_m/slice40951.png', 3, [1.48, 7.22, 242.87]],
#  ['/content/train_m/slice12750.png', 1, [60.17]],
#  ['/content/train_m/slice27155.png', 2, [207.87, 3.7]],
#  ['/content/train_m/slice12747.png', 1, [42.84]],
#  ['/content/train_m/slice15529.png', 2, [1.1, 213.14]],
#  ['/content/train_m/slice16905.png', 1, [207.78]],
#  ['/content/train_m/slice21660.png', 1, [175.21]],
#  ['/content/train_m/slice16988.png', 1, [277.02]],
#  ['/content/train_m/slice25722.png', 0, [0]],
#  ['/content/train_m/slice36042.png', 2, [196.65, 8.59]],
#  ['/content/train_m/slice36838.png', 2, [2.84, 279.11]],
#  ['/content/train_m/slice10112.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_m/slice44947.png', 1, [208.69]],
#  ['/content/train_m/slice23092.png', 2, [202.71, 9.68]],
#  ['/content/train_m/slice37344.png', 1, [1.22]],
#  ['/content/train_m/slice5920.png', 1, [136.51]],
#  ['/content/train_m/slice20346.png', 2, [215.41, 1.61]],
#  ['/content/train_m/slice7451.png', 2, [5.53, 209.39]],
#  ['/content/train_m/slice31416.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_m/slice14333.png', 0, [0]],
#  ['/content/train_m/slice1816.png', 1, [136.51]],
#  ['/content/train_m/slice12930.png', 1, [172.81]],
#  ['/content/train_m/slice22487.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_m/slice21609.png', 0, [0]],
#  ['/content/train_m/slice15586.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_m/slice6024.png', 1, [218.98]],
#  ['/content/train_m/slice31284.png', 1, [222.54]],
#  ['/content/train_m/slice12238.png', 2, [5.3, 212.21]],
#  ['/content/train_m/slice42964.png', 2, [0.91, 241.08]],
#  ['/content/train_m/slice46904.png', 0, [0]],
#  ['/content/train_m/slice39515.png', 2, [188.25, 7.57]],
#  ['/content/train_m/slice47753.png', 2, [1.03, 246.09]],
#  ['/content/train_m/slice33470.png', 2, [0.22, 6.5]],
#  ['/content/train_m/slice43027.png', 1, [169.77]],
#  ['/content/train_m/slice4524.png', 2, [0.0, 0.01]],
#  ['/content/train_m/slice38041.png', 1, [2.34]],
#  ['/content/train_m/slice5398.png', 2, [5.3, 212.21]],
#  ['/content/train_m/slice23029.png', 1, [177.05]],
#  ['/content/train_m/slice8177.png', 0, [0]],
#  ['/content/train_m/slice1832.png', 1, [197.47]],
#  ['/content/train_m/slice5859.png', 0, [0]],
#  ['/content/train_m/slice12037.png', 1, [1.24]],
#  ['/content/train_m/slice18307.png', 2, [196.96, 11.58]],
#  ['/content/train_m/slice29864.png', 2, [1.84, 157.64]],
#  ['/content/train_m/slice15540.png', 1, [205.71]],
#  ['/content/train_m/slice17555.png', 1, [171.6]],
#  ['/content/train_m/slice14316.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_m/slice20328.png', 1, [205.71]],
#  ['/content/train_m/slice33240.png', 1, [1.22]],
#  ['/content/train_m/slice37537.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_m/slice11426.png', 2, [0.01, 211.38]],
#  ['/content/train_m/slice33928.png', 1, [0.5]],
#  ['/content/train_m/slice1935.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_m/slice35399.png', 2, [212.87, 6.28]],
#  ['/content/train_m/slice8779.png', 2, [0.62, 279.65]],
#  ['/content/train_m/slice28678.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_m/slice4012.png', 2, [7.13, 250.72]],
#  ['/content/train_m/slice39435.png', 1, [130.7]],
#  ['/content/train_m/slice29141.png', 1, [0.19]],
#  ['/content/train_m/slice3327.png', 2, [6.54, 252.78]],
#  ['/content/train_m/slice43658.png', 3, [1.88, 2.34, 270.21]],
#  ['/content/train_m/slice19719.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_m/slice11391.png', 1, [130.7]],
#  ['/content/train_m/slice44937.png', 2, [203.84, 6.54]],
#  ['/content/train_m/slice18886.png', 0, [0]],
#  ['/content/train_m/slice19670.png', 2, [207.31, 8.92]],
#  ['/content/train_m/slice23156.png', 2, [3.94, 283.63]],
#  ['/content/train_m/slice12772.png', 1, [187.02]],
#  ['/content/train_m/slice9491.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_m/slice16271.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_m/slice34113.png', 3, [1.39, 4.72, 242.28]],
#  ['/content/train_m/slice31289.png', 2, [218.16, 1.01]],
#  ['/content/train_m/slice29342.png', 2, [3.15, 191.52]],
#  ['/content/train_m/slice37442.png', 1, [221.64]],
#  ['/content/train_m/slice32051.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_m/slice36193.png', 1, [114.8]],
#  ['/content/train_m/slice47732.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_m/slice38826.png', 2, [197.55, 11.07]],
#  ['/content/train_m/slice1303.png', 1, [169.77]],
#  ['/content/train_m/slice46287.png', 1, [184.03]],
#  ['/content/train_m/slice48347.png', 2, [186.43, 15.39]],
#  ['/content/train_m/slice588.png', 2, [4.91, 260.75]],
#  ['/content/train_m/slice23062.png', 1, [207.02]],
#  ['/content/train_m/slice12214.png', 2, [2.84, 279.11]],
#  ['/content/train_m/slice43703.png', 2, [5.53, 209.39]],
#  ['/content/train_m/slice9464.png', 1, [277.02]],
#  ['/content/train_m/slice1292.png', 2, [4.59, 218.29]],
#  ['/content/train_m/slice25283.png', 0, [0]],
#  ['/content/train_m/slice35387.png', 1, [224.58]],
#  ['/content/train_m/slice19605.png', 2, [2.59, 164.07]],
#  ['/content/train_m/slice7336.png', 1, [214.85]],
#  ['/content/train_m/slice12861.png', 2, [0.12, 201.14]],
#  ['/content/train_m/slice31427.png', 0, [0]],
#  ['/content/train_m/slice42970.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_m/slice3968.png', 2, [0.48, 198.31]],
#  ['/content/train_m/slice39455.png', 2, [186.43, 15.39]],
#  ['/content/train_m/slice3318.png', 2, [2.83, 280.34]],
#  ['/content/train_m/slice44890.png', 1, [26.05]],
#  ['/content/train_m/slice5867.png', 0, [0]],
#  ['/content/train_m/slice44204.png', 1, [21.64]],
#  ['/content/train_m/slice6134.png', 0, [0]],
#  ['/content/train_m/slice18266.png', 2, [0.01, 211.38]],
#  ['/content/train_m/slice20391.png', 2, [0.44, 233.44]],
#  ['/content/train_m/slice40772.png', 0, [0]],
#  ['/content/train_m/slice48332.png', 2, [1.84, 157.64]],
#  ['/content/train_m/slice34083.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_m/slice4726.png', 1, [142.95]],
#  ['/content/train_m/slice21134.png', 2, [3.15, 191.52]],
#  ['/content/train_m/slice48957.png', 0, [0]],
#  ['/content/train_m/slice41484.png', 1, [114.22]],
#  ['/content/train_m/slice23076.png', 1, [222.54]],
#  ['/content/train_m/slice16134.png', 0, [0]],
#  ['/content/train_m/slice19800.png', 0, [0]],
#  ['/content/train_m/slice36748.png', 1, [214.85]],
#  ['/content/train_m/slice37448.png', 2, [212.61, 3.06]],
#  ['/content/train_m/slice48484.png', 2, [3.12, 227.94]],
#  ['/content/train_m/slice34596.png', 0, [0]],
#  ['/content/train_m/slice39479.png', 1, [206.35]],
#  ['/content/train_m/slice20493.png', 0, [0]],
#  ['/content/train_m/slice43627.png', 2, [171.82, 1.59]],
#  ['/content/train_m/slice36790.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_m/slice6101.png', 1, [84.71]],
#  ['/content/train_m/slice45627.png', 1, [211.01]],
#  ['/content/train_m/slice14233.png', 1, [226.13]],
#  ['/content/train_m/slice19038.png', 2, [0.75, 277.48]],
#  ['/content/train_m/slice40943.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_m/slice21633.png', 1, [23.71]],
#  ['/content/train_m/slice9327.png', 1, [42.84]],
#  ['/content/train_m/slice47596.png', 0, [0]],
#  ['/content/train_m/slice40123.png', 2, [1.44, 153.02]],
#  ['/content/train_m/slice40313.png', 2, [0.09, 5.38]],
#  ['/content/train_m/slice35365.png', 2, [1.1, 213.14]],
#  ['/content/train_m/slice22970.png', 0, [0]],
#  ['/content/train_m/slice8767.png', 2, [1.79, 259.36]],
#  ['/content/train_m/slice2501.png', 1, [141.86]],
#  ['/content/train_m/slice26415.png', 1, [4.52]],
#  ['/content/train_m/slice23705.png', 1, [141.86]],
#  ['/content/train_m/slice600.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_m/slice37511.png', 1, [271.15]],
#  ['/content/train_m/slice14275.png', 3, [1.48, 7.22, 242.87]],
#  ['/content/train_m/slice18318.png', 2, [181.76, 3.4]],
#  ['/content/train_m/slice42885.png', 2, [203.84, 6.54]],
#  ['/content/train_m/slice9454.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_m/slice47657.png', 1, [189.94]],
#  ['/content/train_m/slice28623.png', 2, [1.15, 272.53]],
#  ['/content/train_m/slice2532.png', 2, [2.12, 210.69]],
#  ['/content/train_m/slice21616.png', 1, [0.5]],
#  ['/content/train_m/slice23712.png', 1, [175.21]],
#  ['/content/train_m/slice5357.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_m/slice13473.png', 2, [203.84, 6.54]],
#  ['/content/train_m/slice26484.png', 1, [205.71]],
#  ['/content/train_m/slice37416.png', 2, [2.12, 210.69]],
#  ['/content/train_m/slice29228.png', 1, [224.54]],
#  ['/content/train_m/slice8834.png', 1, [107.99]],
#  ['/content/train_m/slice47771.png', 1, [271.15]],
#  ['/content/train_m/slice43753.png', 0, [0]],
#  ['/content/train_m/slice12038.png', 1, [1.35]],
#  ['/content/train_m/slice47031.png', 2, [203.74, 9.59]],
#  ['/content/train_m/slice8715.png', 1, [220.08]],
#  ['/content/train_m/slice10145.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_m/slice29167.png', 1, [68.09]],
#  ['/content/train_m/slice8098.png', 1, [272.64]],
#  ['/content/train_m/slice3226.png', 1, [207.02]],
#  ['/content/train_m/slice47705.png', 2, [218.16, 1.01]],
#  ['/content/train_m/slice2011.png', 2, [0.2, 1.98]],
#  ['/content/train_m/slice3977.png', 2, [1.03, 246.09]],
#  ['/content/train_m/slice1911.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_m/slice24553.png', 2, [4.0, 198.37]],
#  ['/content/train_m/slice2508.png', 1, [175.21]],
#  ['/content/train_m/slice47659.png', 1, [196.02]],
#  ['/content/train_m/slice22985.png', 1, [0.19]],
#  ['/content/train_m/slice40972.png', 2, [2.18, 181.76]],
#  ['/content/train_m/slice31308.png', 2, [183.3, 6.6]],
#  ['/content/train_m/slice40942.png', 2, [2.84, 279.11]],
#  ['/content/train_m/slice26537.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_m/slice5905.png', 1, [33.77]],
#  ['/content/train_m/slice28652.png', 2, [4.59, 218.29]],
#  ['/content/train_m/slice9404.png', 2, [212.61, 3.06]],
#  ['/content/train_m/slice4500.png', 0, [0]],
#  ['/content/train_m/slice12800.png', 1, [208.25]],
#  ['/content/train_m/slice48454.png', 1, [272.64]],
#  ['/content/train_m/slice12825.png', 2, [210.36, 4.03]],
#  ['/content/train_m/slice38847.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_m/slice44998.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_m/slice16318.png', 2, [2.84, 279.11]],
#  ['/content/train_m/slice18917.png', 1, [141.86]],
#  ['/content/train_m/slice2526.png', 2, [196.65, 8.59]],
#  ['/content/train_m/slice25837.png', 2, [179.64, 5.91]],
#  ['/content/train_m/slice40102.png', 1, [26.05]],
#  ['/content/train_m/slice10878.png', 1, [172.81]],
#  ['/content/train_m/slice46384.png', 2, [0.91, 241.08]],
#  ['/content/train_m/slice10692.png', 1, [31.83]],
#  ['/content/train_m/slice24481.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_m/slice8773.png', 3, [2.22, 2.54, 269.77]],
#  ['/content/train_m/slice47619.png', 1, [4.52]],
#  ['/content/train_m/slice38769.png', 1, [199.23]],
#  ['/content/train_m/slice42150.png', 1, [13.52]],
#  ['/content/train_m/slice17735.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_m/slice37472.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_m/slice24459.png', 2, [203.74, 9.59]],
#  ['/content/train_m/slice33351.png', 2, [203.74, 9.59]],
#  ['/content/train_m/slice1805.png', 1, [54.41]],
#  ['/content/train_m/slice11473.png', 2, [179.64, 5.91]],
#  ['/content/train_m/slice26646.png', 0, [0]],
#  ['/content/train_m/slice44358.png', 2, [2.83, 280.34]],
#  ['/content/train_m/slice13551.png', 2, [0.44, 233.44]],
#  ['/content/train_m/slice18268.png', 1, [210.25]],
#  ['/content/train_m/slice2443.png', 0, [0]],
#  ['/content/train_m/slice31364.png', 2, [3.94, 283.63]],
#  ['/content/train_m/slice17648.png', 2, [0.48, 198.31]],
#  ['/content/train_m/slice1216.png', 2, [180.17, 4.18]],
#  ['/content/train_m/slice25895.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_m/slice1236.png', 1, [218.98]],
#  ['/content/train_m/slice8618.png', 1, [1.35]],
#  ['/content/train_m/slice32586.png', 1, [60.17]],
#  ['/content/train_m/slice23195.png', 1, [132.07]],
#  ['/content/train_m/slice16290.png', 2, [1.53, 251.42]],
#  ['/content/train_m/slice4635.png', 2, [179.64, 4.51]],
#  ['/content/train_m/slice18985.png', 2, [213.66, 8.26]],
#  ['/content/train_m/slice9529.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_m/slice8097.png', 1, [273.22]],
#  ['/content/train_m/slice39482.png', 1, [209.68]],
#  ['/content/train_m/slice40098.png', 1, [13.52]],
#  ['/content/train_m/slice33261.png', 1, [23.71]],
#  ['/content/train_m/slice45609.png', 1, [199.23]],
#  ['/content/train_m/slice7360.png', 2, [202.71, 9.68]],
#  ['/content/train_m/slice46954.png', 1, [95.36]],
#  ['/content/train_m/slice41640.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_m/slice29157.png', 1, [23.71]],
#  ['/content/train_m/slice11461.png', 2, [213.66, 8.26]],
#  ['/content/train_m/slice24594.png', 0, [0]],
#  ['/content/train_m/slice10118.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_m/slice13508.png', 2, [212.61, 3.06]],
#  ['/content/train_m/slice38731.png', 1, [19.67]],
#  ['/content/train_m/slice9351.png', 1, [184.03]],
#  ['/content/train_m/slice4603.png', 1, [222.0]],
#  ['/content/train_m/slice25091.png', 2, [186.43, 15.39]],
#  ['/content/train_m/slice31248.png', 2, [187.46, 15.31]],
#  ['/content/train_m/slice19625.png', 2, [195.37, 9.54]],
#  ['/content/train_m/slice15595.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_m/slice40067.png', 0, [0]],
#  ['/content/train_m/slice12104.png', 2, [201.69, 7.33]],
#  ['/content/train_m/slice44351.png', 1, [271.15]],
#  ['/content/train_m/slice33934.png', 0, [0]],
#  ['/content/train_m/slice45572.png', 1, [21.64]],
#  ['/content/train_m/slice34805.png', 2, [3.53, 225.61]],
#  ['/content/train_m/slice11488.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_m/slice27933.png', 1, [273.22]],
#  ['/content/train_m/slice29210.png', 2, [0.01, 211.38]],
#  ['/content/train_m/slice36130.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_m/slice4713.png', 2, [4.86, 215.11]],
#  ['/content/train_m/slice21754.png', 1, [207.35]],
#  ['/content/train_m/slice38206.png', 2, [2.84, 279.11]],
#  ['/content/train_m/slice30685.png', 2, [5.56, 257.6]],
#  ['/content/train_m/slice27104.png', 1, [21.64]],
#  ['/content/train_m/slice40888.png', 2, [180.17, 4.18]],
#  ['/content/train_m/slice19803.png', 0, [0]],
#  ['/content/train_m/slice42134.png', 1, [1.35]],
#  ['/content/train_m/slice25924.png', 2, [2.18, 181.76]],
#  ['/content/train_m/slice47677.png', 2, [1.1, 213.14]],
#  ['/content/train_m/slice6724.png', 3, [1.44, 1.36, 276.57]],
#  ['/content/train_m/slice48349.png', 2, [189.52, 15.4]],
#  ['/content/train_m/slice38893.png', 2, [5.56, 257.6]],
#  ['/content/train_m/slice30657.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_m/slice43692.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_m/slice26553.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_m/slice22305.png', 0, [0]],
#  ['/content/train_m/slice5320.png', 2, [180.17, 4.18]],
#  ['/content/train_m/slice26462.png', 2, [190.5, 12.86]],
#  ['/content/train_m/slice41695.png', 0, [0]],
#  ['/content/train_m/slice1784.png', 0, [0]],
#  ['/content/train_m/slice24549.png', 2, [4.86, 215.11]],
#  ['/content/train_m/slice14928.png', 4, [0.83, 1.83, 0.78, 266.04]],
#  ['/content/train_m/slice43032.png', 1, [122.05]],
#  ['/content/train_m/slice3866.png', 1, [124.18]],
#  ['/content/train_m/slice19052.png', 2, [3.94, 283.63]],
#  ['/content/train_m/slice49080.png', 2, [218.66, 7.9]],
#  ['/content/train_m/slice12812.png', 1, [224.54]],
#  ['/content/train_m/slice36097.png', 2, [179.64, 5.91]],
#  ['/content/train_m/slice9403.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice21662.png', 1, [180.19]],
#  ['/content/train_m/slice46296.png', 2, [187.46, 15.31]],
#  ['/content/train_m/slice45732.png', 2, [4.91, 260.75]],
#  ['/content/train_m/slice36815.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_m/slice36019.png', 2, [1.44, 153.02]],
#  ['/content/train_m/slice36903.png', 0, [0]],
#  ['/content/train_m/slice30554.png', 1, [180.19]],
#  ['/content/train_m/slice14123.png', 1, [104.7]],
#  ['/content/train_m/slice6673.png', 2, [213.66, 8.26]],
#  ['/content/train_m/slice49114.png', 1, [207.35]],
#  ['/content/train_m/slice2470.png', 0, [0]],
#  ['/content/train_m/slice5384.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_m/slice25855.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_m/slice17700.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_m/slice2461.png', 1, [1.24]],
#  ['/content/train_m/slice43671.png', 2, [1.15, 272.53]],
#  ['/content/train_m/slice40808.png', 2, [1.84, 157.64]],
#  ['/content/train_m/slice25866.png', 2, [1.53, 251.42]],
#  ['/content/train_m/slice12802.png', 1, [207.02]],
#  ['/content/train_m/slice8044.png', 2, [202.71, 9.68]],
#  ['/content/train_m/slice3840.png', 2, [0.0, 0.01]],
#  ['/content/train_m/slice5869.png', 0, [0]],
#  ['/content/train_m/slice18934.png', 1, [199.79]],
#  ['/content/train_m/slice49220.png', 0, [0]],
#  ['/content/train_m/slice35350.png', 1, [199.79]],
#  ['/content/train_m/slice27296.png', 1, [166.78]],
#  ['/content/train_m/slice23805.png', 2, [0.12, 201.14]],
#  ['/content/train_m/slice28551.png', 1, [220.08]],
#  ['/content/train_m/slice40074.png', 0, [0]],
#  ['/content/train_m/slice21090.png', 2, [0.75, 277.48]],
#  ['/content/train_m/slice6561.png', 0, [0]],
#  ['/content/train_m/slice10679.png', 0, [0]],
#  ['/content/train_m/slice29387.png', 0, [0]],
#  ['/content/train_m/slice20443.png', 2, [4.18, 220.12]],
#  ['/content/train_m/slice46246.png', 0, [0]],
#  ['/content/train_m/slice13521.png', 2, [194.95, 9.05]],
#  ['/content/train_m/slice40777.png', 1, [2.34]],
#  ['/content/train_m/slice47141.png', 1, [84.71]],
#  ['/content/train_m/slice2489.png', 1, [54.41]],
#  ['/content/train_m/slice24361.png', 1, [2.34]],
#  ['/content/train_m/slice11468.png', 2, [194.6, 10.42]],
#  ['/content/train_m/slice29283.png', 2, [0.44, 233.44]],
#  ['/content/train_m/slice25044.png', 2, [0.0, 0.01]],
#  ['/content/train_m/slice30747.png', 0, [0]],
#  ['/content/train_m/slice38881.png', 2, [0.56, 276.34]],
#  ['/content/train_m/slice31388.png', 2, [4.59, 218.29]],
#  ['/content/train_m/slice25727.png', 0, [0]],
#  ['/content/train_m/slice42959.png', 1, [212.75]],
#  ['/content/train_m/slice13586.png', 2, [5.71, 253.95]],
#  ['/content/train_m/slice10738.png', 2, [205.58, 5.93]],
#  ['/content/train_m/slice42795.png', 0, [0]],
#  ['/content/train_m/slice15596.png', 2, [0.48, 198.31]],
#  ['/content/train_m/slice21840.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_m/slice10199.png', 1, [132.07]],
#  ['/content/train_m/slice18263.png', 2, [207.87, 3.7]],
#  ['/content/train_m/slice29877.png', 1, [199.23]],
#  ['/content/train_m/slice27829.png', 2, [189.52, 15.4]],
#  ['/content/train_m/slice22289.png', 0, [0]],
#  ['/content/train_m/slice5868.png', 0, [0]],
#  ['/content/train_m/slice21705.png', 1, [227.05]],
#  ['/content/train_m/slice15514.png', 1, [199.79]],
#  ['/content/train_m/slice35485.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_m/slice35381.png', 1, [217.26]],
#  ['/content/train_m/slice24516.png', 2, [0.13, 272.04]],
#  ['/content/train_m/slice2639.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_m/slice44936.png', 2, [201.69, 7.33]],
#  ['/content/train_m/slice34653.png', 2, [2.59, 164.07]],
#  ['/content/train_m/slice34775.png', 1, [271.15]],
#  ['/content/train_m/slice44184.png', 1, [1.22]],
#  ['/content/train_m/slice10164.png', 2, [4.91, 260.75]],
#  ['/content/train_m/slice20413.png', 2, [0.56, 276.34]],
#  ['/content/train_m/slice32002.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_m/slice29170.png', 1, [95.36]],
#  ['/content/train_m/slice10116.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_m/slice37452.png', 2, [218.66, 7.9]],
#  ['/content/train_m/slice17028.png', 2, [4.72, 204.21]],
#  ['/content/train_m/slice10216.png', 2, [0.77, 5.62]],
#  ['/content/train_m/slice29239.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice48451.png', 2, [0.62, 279.65]],
#  ['/content/train_m/slice542.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_m/slice48280.png', 0, [0]],
#  ['/content/train_m/slice44393.png', 1, [177.89]],
#  ['/content/train_m/slice17708.png', 2, [4.59, 218.29]],
#  ['/content/train_m/slice33332.png', 1, [224.54]],
#  ['/content/train_m/slice22967.png', 0, [0]],
#  ['/content/train_m/slice19807.png', 0, [0]],
#  ['/content/train_m/slice44887.png', 1, [19.67]],
#  ['/content/train_m/slice19784.png', 2, [4.79, 41.22]],
#  ['/content/train_m/slice47052.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_m/slice14976.png', 2, [4.72, 204.21]],
#  ['/content/train_m/slice29980.png', 3, [1.44, 1.36, 276.57]],
#  ['/content/train_m/slice3253.png', 2, [213.66, 8.26]],
#  ['/content/train_m/slice21033.png', 2, [210.36, 4.03]],
#  ['/content/train_m/slice38757.png', 2, [2.59, 164.07]],
#  ['/content/train_m/slice8118.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_m/slice20380.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_m/slice27094.png', 0, [0]],
#  ['/content/train_m/slice42280.png', 2, [0.91, 241.08]],
#  ['/content/train_m/slice20429.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_m/slice9538.png', 1, [0.44]],
#  ['/content/train_m/slice39612.png', 1, [122.05]],
#  ['/content/train_m/slice31436.png', 0, [0]],
#  ['/content/train_m/slice29929.png', 2, [213.66, 8.26]],
#  ['/content/train_m/slice40312.png', 2, [0.77, 5.62]],
#  ['/content/train_m/slice26467.png', 2, [198.05, 8.0]],
#  ['/content/train_m/slice6061.png', 2, [5.56, 257.6]],
#  ['/content/train_m/slice7244.png', 0, [0]],
#  ['/content/train_m/slice26472.png', 2, [2.12, 210.69]],
#  ['/content/train_m/slice38246.png', 1, [107.99]],
#  ['/content/train_m/slice42355.png', 1, [64.66]],
#  ['/content/train_m/slice46354.png', 2, [194.65, 8.52]],
#  ['/content/train_m/slice47056.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_m/slice47789.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_m/slice22982.png', 1, [1.35]],
#  ['/content/train_m/slice47146.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_m/slice31933.png', 2, [189.52, 15.4]],
#  ['/content/train_m/slice34104.png', 2, [4.91, 260.75]],
#  ['/content/train_m/slice522.png', 2, [197.55, 11.07]],
#  ['/content/train_m/slice48442.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_m/slice44921.png', 1, [189.94]],
#  ['/content/train_m/slice21176.png', 0, [0]],
#  ['/content/train_m/slice33247.png', 0, [0]],
#  ['/content/train_m/slice46395.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_m/slice20324.png', 1, [208.25]],
#  ['/content/train_m/slice45798.png', 0, [0]],
#  ['/content/train_m/slice14145.png', 1, [199.23]],
#  ['/content/train_m/slice38848.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_m/slice19603.png', 2, [1.44, 153.02]],
#  ['/content/train_m/slice12724.png', 1, [0.5]],
#  ['/content/train_m/slice7937.png', 1, [0.19]],
#  ['/content/train_m/slice43673.png', 2, [2.12, 277.47]],
#  ['/content/train_m/slice21079.png', 2, [1.79, 259.36]],
#  ['/content/train_m/slice12787.png', 2, [198.05, 8.0]],
#  ['/content/train_m/slice42379.png', 0, [0]],
#  ['/content/train_m/slice19014.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_m/slice34706.png', 1, [221.64]],
#  ['/content/train_m/slice31317.png', 4, [9.29, 1.52, 149.57, 0.57]],
#  ['/content/train_m/slice24576.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_m/slice8794.png', 2, [2.84, 279.11]],
#  ['/content/train_m/slice44404.png', 1, [94.92]],
#  ['/content/train_m/slice26550.png', 2, [1.53, 251.42]],
#  ['/content/train_m/slice43694.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_m/slice47774.png', 2, [1.15, 275.35]],
#  ['/content/train_m/slice8859.png', 0, [0]],
#  ['/content/train_m/slice43729.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_m/slice7470.png', 1, [74.76]],
#  ['/content/train_m/slice18905.png', 1, [54.41]],
#  ['/content/train_m/slice3256.png', 2, [202.71, 9.68]],
#  ['/content/train_m/slice21150.png', 1, [74.76]],
#  ['/content/train_m/slice41007.png', 0, [0]],
#  ['/content/train_m/slice17626.png', 2, [194.65, 8.52]],
#  ['/content/train_m/slice36117.png', 2, [0.12, 201.14]],
#  ['/content/train_m/slice39444.png', 1, [175.21]],
#  ['/content/train_m/slice3193.png', 1, [177.05]],
#  ['/content/train_m/slice24511.png', 2, [0.62, 279.65]],
#  ['/content/train_m/slice8176.png', 0, [0]],
#  ['/content/train_m/slice48368.png', 1, [208.25]],
#  ['/content/train_m/slice5447.png', 0, [0]],
#  ['/content/train_m/slice16374.png', 2, [0.05, 3.56]],
#  ['/content/train_m/slice4756.png', 0, [0]],
#  ['/content/train_m/slice18222.png', 1, [60.17]],
#  ['/content/train_m/slice21081.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_m/slice43519.png', 1, [19.67]],
#  ['/content/train_m/slice11406.png', 1, [191.8]],
#  ['/content/train_m/slice31403.png', 1, [132.07]],
#  ['/content/train_m/slice5305.png', 2, [213.66, 8.26]],
#  ['/content/train_m/slice28456.png', 1, [0.5]],
#  ['/content/train_m/slice27962.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_m/slice39491.png', 1, [224.58]],
#  ['/content/train_m/slice13459.png', 1, [196.02]],
#  ['/content/train_m/slice44287.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice36153.png', 2, [3.21, 278.18]],
#  ['/content/train_m/slice32038.png', 1, [272.64]],
#  ['/content/train_m/slice10701.png', 1, [87.67]],
#  ['/content/train_m/slice48438.png', 2, [1.53, 251.42]],
#  ['/content/train_m/slice30497.png', 0, [0]],
#  ['/content/train_m/slice6577.png', 1, [2.34]],
#  ['/content/train_m/slice23055.png', 1, [211.01]],
#  ['/content/train_m/slice15680.png', 2, [4.79, 41.22]],
#  ['/content/train_m/slice21112.png', 2, [7.13, 250.72]],
#  ['/content/train_m/slice18341.png', 2, [1.03, 246.09]],
#  ['/content/train_m/slice14753.png', 0, [0]],
#  ['/content/train_m/slice8123.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_m/slice45023.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_m/slice12769.png', 1, [177.05]],
#  ['/content/train_m/slice46300.png', 2, [192.82, 10.38]],
#  ['/content/train_m/slice16311.png', 2, [1.15, 272.53]],
#  ['/content/train_m/slice1850.png', 2, [0.01, 211.38]],
#  ['/content/train_m/slice2712.png', 0, [0]],
#  ['/content/train_m/slice38925.png', 1, [153.86]],
#  ['/content/train_m/slice43552.png', 1, [187.02]],
#  ['/content/train_m/slice47655.png', 1, [184.03]],
#  ['/content/train_m/slice33408.png', 2, [0.13, 272.04]],
#  ['/content/train_m/slice14760.png', 0, [0]],
#  ['/content/train_m/slice22301.png', 1, [0.19]],
#  ['/content/train_m/slice14121.png', 1, [87.67]],
#  ['/content/train_m/slice45654.png', 2, [215.41, 1.61]],
#  ['/content/train_m/slice38254.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_m/slice15619.png', 2, [0.62, 279.65]],
#  ['/content/train_m/slice3821.png', 0, [0]],
#  ['/content/train_m/slice6005.png', 2, [175.59, 3.52]],
#  ['/content/train_m/slice10019.png', 1, [104.7]],
#  ['/content/train_m/slice46309.png', 2, [1.1, 213.14]],
#  ['/content/train_m/slice6131.png', 0, [0]],
#  ['/content/train_m/slice35529.png', 1, [0.45]],
#  ['/content/train_m/slice39410.png', 1, [3.24]],
#  ['/content/train_m/slice10895.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_m/slice6010.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_m/slice24541.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_m/slice20462.png', 1, [107.99]],
#  ['/content/train_m/slice32703.png', 2, [0.44, 233.44]],
#  ['/content/train_m/slice2444.png', 0, [0]],
#  ['/content/train_m/slice14933.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_m/slice16962.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_m/slice37545.png', 2, [4.86, 215.11]],
#  ['/content/train_m/slice40076.png', 0, [0]],
#  ['/content/train_m/slice42273.png', 2, [0.12, 201.14]],
#  ['/content/train_m/slice2668.png', 2, [2.18, 181.76]],
#  ['/content/train_m/slice1987.png', 1, [169.77]],
#  ['/content/train_m/slice26503.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice22278.png', 0, [0]],
#  ['/content/train_m/slice10080.png', 1, [222.54]],
#  ['/content/train_m/slice15495.png', 1, [130.7]],
#  ['/content/train_m/slice19662.png', 2, [215.41, 1.61]],
#  ['/content/train_m/slice44224.png', 1, [136.51]],
#  ['/content/train_m/slice25926.png', 1, [172.81]],
#  ['/content/train_m/slice3247.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice44389.png', 2, [4.0, 198.37]],
#  ['/content/train_m/slice29269.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_m/slice20432.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_m/slice1810.png', 1, [95.36]],
#  ['/content/train_m/slice39433.png', 1, [118.2]],
#  ['/content/train_m/slice39450.png', 1, [191.8]],
#  ['/content/train_m/slice27936.png', 2, [0.13, 272.04]],
#  ['/content/train_m/slice12193.png', 3, [2.22, 2.54, 269.77]],
#  ['/content/train_m/slice39508.png', 2, [202.71, 9.68]],
#  ['/content/train_m/slice20909.png', 0, [0]],
#  ['/content/train_m/slice29134.png', 1, [0.24]],
#  ['/content/train_m/slice9282.png', 0, [0]],
#  ['/content/train_m/slice28509.png', 1, [199.23]],
#  ['/content/train_m/slice9442.png', 1, [207.35]],
#  ['/content/train_m/slice25187.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_m/slice14956.png', 2, [7.13, 250.72]],
#  ['/content/train_m/slice43543.png', 2, [1.44, 153.02]],
#  ['/content/train_m/slice21677.png', 2, [195.37, 9.54]],
#  ['/content/train_m/slice12157.png', 2, [179.64, 5.91]],
#  ['/content/train_m/slice16208.png', 2, [201.69, 7.33]],
#  ['/content/train_m/slice16332.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_m/slice27211.png', 2, [171.82, 1.59]],
#  ['/content/train_m/slice40278.png', 2, [3.85, 223.1]],
#  ['/content/train_m/slice2552.png', 1, [224.54]],
#  ['/content/train_m/slice32810.png', 0, [0]],
#  ['/content/train_m/slice15509.png', 1, [189.94]],
#  ['/content/train_m/slice44988.png', 2, [183.3, 6.6]],
#  ['/content/train_m/slice5906.png', 1, [38.63]],
#  ['/content/train_m/slice10680.png', 2, [0.0, 0.01]],
#  ['/content/train_m/slice14819.png', 1, [171.6]],
#  ['/content/train_m/slice11437.png', 1, [207.02]],
#  ['/content/train_m/slice28573.png', 2, [179.64, 5.91]],
#  ['/content/train_m/slice14814.png', 1, [146.83]],
#  ['/content/train_m/slice37412.png', 2, [201.69, 7.33]],
#  ['/content/train_m/slice42167.png', 1, [104.7]],
#  ['/content/train_m/slice24357.png', 0, [0]],
#  ['/content/train_m/slice27136.png', 1, [187.02]],
#  ['/content/train_m/slice8634.png', 1, [13.52]],
#  ['/content/train_m/slice20944.png', 1, [6.91]],
#  ['/content/train_m/slice38936.png', 2, [4.79, 41.22]],
#  ['/content/train_m/slice20451.png', 2, [2.57, 186.09]],
#  ['/content/train_m/slice5318.png', 2, [179.16, 5.34]],
#  ['/content/train_m/slice48426.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_m/slice2615.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_m/slice12866.png', 2, [0.28, 230.25]],
#  ['/content/train_m/slice43680.png', 2, [4.91, 260.75]],
#  ['/content/train_m/slice41559.png', 2, [203.74, 9.59]],
#  ['/content/train_m/slice30536.png', 1, [78.83]],
#  ['/content/train_m/slice38852.png', 2, [0.48, 198.31]],
#  ['/content/train_m/slice36057.png', 1, [207.78]],
#  ['/content/train_m/slice48346.png', 1, [199.79]],
#  ['/content/train_m/slice19016.png', 2, [0.48, 198.31]],
#  ['/content/train_m/slice6676.png', 2, [202.71, 9.68]],
#  ['/content/train_m/slice43546.png', 1, [169.98]],
#  ['/content/train_m/slice8129.png', 2, [3.53, 225.61]],
#  ['/content/train_m/slice43558.png', 1, [199.79]],
#  ['/content/train_m/slice17503.png', 0, [0]],
#  ['/content/train_m/slice31947.png', 1, [211.01]],
#  ['/content/train_m/slice11498.png', 2, [0.28, 230.25]],
#  ['/content/train_m/slice10205.png', 1, [84.71]],
#  ['/content/train_m/slice21071.png', 1, [212.75]],
#  ['/content/train_m/slice8664.png', 1, [175.21]],
#  ['/content/train_m/slice519.png', 2, [203.74, 9.59]],
#  ['/content/train_m/slice23767.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice45533.png', 0, [0]],
#  ['/content/train_m/slice36218.png', 0, [0]],
#  ['/content/train_m/slice17551.png', 2, [1.44, 153.02]],
#  ['/content/train_m/slice24463.png', 2, [196.96, 11.58]],
#  ['/content/train_m/slice25108.png', 1, [210.25]],
#  ['/content/train_m/slice23729.png', 2, [195.37, 9.54]],
#  ['/content/train_m/slice20289.png', 2, [2.59, 164.07]],
#  ['/content/train_m/slice7274.png', 1, [38.63]],
#  ['/content/train_m/slice38939.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_m/slice34061.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_m/slice5910.png', 1, [60.17]],
#  ['/content/train_m/slice35326.png', 1, [95.36]],
#  ['/content/train_m/slice40081.png', 1, [1.24]],
#  ['/content/train_m/slice27187.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice47831.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_m/slice16860.png', 1, [114.22]],
#  ['/content/train_m/slice20418.png', 2, [2.83, 280.34]],
#  ['/content/train_m/slice11338.png', 0, [0]],
#  ['/content/train_m/slice1106.png', 1, [3.24]],
#  ['/content/train_m/slice2518.png', 1, [199.79]],
#  ['/content/train_m/slice18413.png', 1, [84.71]],
#  ['/content/train_m/slice11532.png', 2, [4.91, 260.75]],
#  ['/content/train_m/slice1982.png', 2, [3.15, 191.52]],
#  ['/content/train_m/slice22440.png', 1, [218.98]],
#  ['/content/train_m/slice3191.png', 1, [171.6]],
#  ['/content/train_m/slice43737.png', 1, [0.45]],
#  ['/content/train_m/slice25921.png', 2, [4.0, 198.37]],
#  ['/content/train_m/slice19596.png', 1, [114.22]],
#  ['/content/train_m/slice29886.png', 2, [196.65, 8.59]],
#  ['/content/train_m/slice6783.png', 1, [100.85]],
#  ['/content/train_m/slice39523.png', 2, [171.82, 1.59]],
#  ['/content/train_m/slice27932.png', 1, [277.02]],
#  ['/content/train_m/slice11471.png', 2, [188.25, 7.57]],
#  ['/content/train_m/slice3263.png', 2, [188.25, 7.57]],
#  ['/content/train_m/slice1893.png', 2, [194.95, 9.05]],
#  ['/content/train_m/slice5243.png', 1, [171.6]],
#  ['/content/train_m/slice41659.png', 1, [169.77]],
#  ['/content/train_m/slice554.png', 2, [0.28, 230.25]],
#  ['/content/train_m/slice33953.png', 1, [54.41]],
#  ['/content/train_m/slice18396.png', 2, [4.72, 204.21]],
#  ['/content/train_m/slice43051.png', 2, [0.2, 1.98]],
#  ['/content/train_m/slice27131.png', 1, [171.6]],
#  ['/content/train_m/slice33263.png', 1, [28.46]],
#  ['/content/train_m/slice44872.png', 1, [0.5]],
#  ['/content/train_m/slice36810.png', 2, [1.53, 251.42]],
#  ['/content/train_m/slice17038.png', 1, [142.95]],
#  ['/content/train_m/slice25720.png', 1, [0.5]],
#  ['/content/train_m/slice29927.png', 2, [212.87, 6.28]],
#  ['/content/train_m/slice16186.png', 1, [169.98]],
#  ['/content/train_m/slice29303.png', 1, [271.15]],
#  ['/content/train_m/slice19025.png', 2, [1.03, 246.09]],
#  ['/content/train_m/slice40773.png', 0, [0]],
#  ['/content/train_m/slice38877.png', 1, [273.22]],
#  ['/content/train_m/slice29892.png', 2, [2.12, 210.69]],
#  ['/content/train_m/slice42800.png', 0, [0]],
#  ['/content/train_m/slice19549.png', 0, [0]],
#  ['/content/train_m/slice40071.png', 0, [0]],
#  ['/content/train_m/slice28703.png', 0, [0]],
#  ['/content/train_m/slice2693.png', 2, [0.09, 5.38]],
#  ['/content/train_m/slice21723.png', 2, [203.74, 9.59]],
#  ['/content/train_m/slice16282.png', 1, [207.35]],
#  ['/content/train_m/slice30510.png', 0, [0]],
#  ['/content/train_m/slice42155.png', 1, [28.46]],
#  ['/content/train_m/slice39421.png', 1, [33.77]],
#  ['/content/train_m/slice2644.png', 2, [7.13, 250.72]],
#  ['/content/train_m/slice9355.png', 1, [196.02]],
#  ['/content/train_m/slice44315.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_m/slice34142.png', 1, [107.99]],
#  ['/content/train_m/slice48339.png', 1, [184.03]],
#  ['/content/train_m/slice45592.png', 1, [136.51]],
#  ['/content/train_m/slice36665.png', 1, [0.19]],
#  ['/content/train_m/slice23201.png', 1, [84.71]],
#  ['/content/train_m/slice7431.png', 2, [6.54, 252.78]],
#  ['/content/train_m/slice15578.png', 2, [179.16, 5.34]],
#  ['/content/train_m/slice45685.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_m/slice40754.png', 0, [0]],
#  ['/content/train_m/slice14207.png', 2, [188.25, 7.57]],
#  ['/content/train_m/slice6547.png', 0, [0]],
#  ['/content/train_m/slice28554.png', 2, [215.41, 1.61]],
#  ['/content/train_m/slice13652.png', 0, [0]],
#  ['/content/train_m/slice14890.png', 2, [194.65, 8.52]],
#  ['/content/train_m/slice34053.png', 4, [9.29, 1.52, 149.57, 0.57]],
#  ['/content/train_m/slice46439.png', 2, [5.53, 209.39]],
#  ['/content/train_m/slice7358.png', 2, [207.31, 8.92]],
#  ['/content/train_m/slice45003.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_m/slice37529.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_m/slice12117.png', 1, [207.78]],
#  ['/content/train_m/slice15450.png', 0, [0]],
#  ['/content/train_m/slice33970.png', 1, [169.98]],
#  ['/content/train_m/slice1882.png', 2, [210.46, 5.48]],
#  ['/content/train_m/slice6589.png', 1, [33.77]],
#  ['/content/train_m/slice16377.png', 1, [0.45]],
#  ['/content/train_m/slice42149.png', 1, [9.26]],
#  ['/content/train_m/slice40309.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_m/slice35476.png', 2, [7.13, 250.72]],
#  ['/content/train_m/slice19034.png', 3, [1.88, 2.34, 270.21]],
#  ['/content/train_m/slice20303.png', 2, [186.43, 15.39]],
#  ['/content/train_m/slice31973.png', 2, [218.16, 1.01]],
#  ['/content/train_m/slice25013.png', 0, [0]],
#  ['/content/train_m/slice37325.png', 0, [0]],
#  ['/content/train_m/slice35335.png', 2, [1.44, 153.02]],
#  ['/content/train_m/slice33321.png', 1, [207.78]],
#  ['/content/train_m/slice21646.png', 1, [95.36]],
#  ['/content/train_m/slice41578.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_m/slice2472.png', 2, [0.0, 0.01]],
#  ['/content/train_m/slice8597.png', 0, [0]],
#  ['/content/train_m/slice43593.png', 1, [227.05]],
#  ['/content/train_m/slice39381.png', 0, [0]],
#  ['/content/train_m/slice47855.png', 0, [0]],
#  ['/content/train_m/slice34102.png', 2, [2.84, 279.11]],
#  ['/content/train_m/slice25249.png', 1, [114.8]],
#  ['/content/train_m/slice1344.png', 0, [0]],
#  ['/content/train_m/slice25129.png', 1, [221.77]],
#  ['/content/train_m/slice9356.png', 1, [197.47]],
#  ['/content/train_m/slice27840.png', 2, [2.12, 210.69]],
#  ['/content/train_m/slice15545.png', 1, [217.26]],
#  ['/content/train_m/slice16877.png', 1, [189.94]],
#  ['/content/train_m/slice38854.png', 1, [207.35]],
#  ['/content/train_m/slice48302.png', 1, [3.24]],
#  ['/content/train_m/slice19544.png', 0, [0]],
#  ['/content/train_m/slice40867.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice18928.png', 1, [187.02]],
#  ['/content/train_m/slice23885.png', 1, [84.71]],
#  ['/content/train_m/slice12182.png', 2, [0.28, 230.25]],
#  ['/content/train_m/slice3932.png', 2, [212.61, 3.06]],
#  ['/content/train_m/slice35289.png', 0, [0]],
#  ['/content/train_m/slice3177.png', 1, [87.67]],
#  ['/content/train_m/slice36865.png', 2, [4.0, 198.37]],
#  ['/content/train_m/slice20936.png', 0, [0]],
#  ['/content/train_m/slice38781.png', 2, [203.84, 6.54]],
#  ['/content/train_m/slice35976.png', 1, [1.22]],
#  ['/content/train_m/slice40317.png', 1, [0.45]],
#  ['/content/train_m/slice42903.png', 1, [212.82]],
#  ['/content/train_m/slice38758.png', 1, [169.98]],
#  ['/content/train_m/slice5870.png', 0, [0]],
#  ['/content/train_m/slice39517.png', 2, [179.64, 5.91]],
#  ['/content/train_m/slice1813.png', 1, [118.2]],
#  ['/content/train_m/slice40165.png', 1, [207.02]],
#  ['/content/train_m/slice9984.png', 1, [1.22]],
#  ['/content/train_m/slice25752.png', 1, [114.22]],
#  ['/content/train_m/slice32644.png', 1, [214.85]],
#  ['/content/train_m/slice40271.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_m/slice15015.png', 0, [0]],
#  ['/content/train_m/slice3906.png', 1, [209.22]],
#  ['/content/train_m/slice22303.png', 0, [0]],
#  ['/content/train_m/slice41585.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_m/slice9504.png', 2, [4.72, 204.21]],
#  ['/content/train_m/slice33911.png', 0, [0]],
#  ['/content/train_m/slice7939.png', 0, [0]],
#  ['/content/train_m/slice10174.png', 3, [0.73, 3.1, 239.17]],
#  ['/content/train_m/slice8691.png', 1, [211.01]],
#  ['/content/train_m/slice35502.png', 1, [172.81]],
#  ['/content/train_m/slice27152.png', 2, [201.69, 7.33]],
#  ['/content/train_m/slice44926.png', 1, [199.79]],
#  ['/content/train_m/slice29324.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_m/slice21016.png', 1, [214.85]],
#  ['/content/train_m/slice10225.png', 0, [0]],
#  ['/content/train_m/slice16955.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_m/slice35505.png', 1, [153.86]],
#  ['/content/train_m/slice1962.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_m/slice3962.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_m/slice14846.png', 2, [0.01, 211.38]],
#  ['/content/train_m/slice20911.png', 0, [0]],
#  ['/content/train_m/slice14102.png', 1, [3.24]],
#  ['/content/train_m/slice36079.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice3153.png', 0, [0]],
#  ['/content/train_m/slice7397.png', 2, [1.03, 246.09]],
#  ['/content/train_m/slice28690.png', 1, [0.44]],
#  ['/content/train_m/slice21744.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_m/slice19084.png', 2, [2.18, 181.76]],
#  ['/content/train_m/slice44981.png', 2, [198.28, 10.12]],
#  ['/content/train_m/slice22518.png', 1, [74.76]],
#  ['/content/train_m/slice42127.png', 0, [0]],
#  ['/content/train_m/slice47167.png', 0, [0]],
#  ['/content/train_m/slice3967.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_m/slice4624.png', 2, [202.71, 9.68]],
#  ['/content/train_m/slice17742.png', 2, [0.05, 3.56]],
#  ['/content/train_m/slice12068.png', 1, [78.83]],
#  ['/content/train_m/slice22366.png', 2, [205.58, 5.93]],
#  ['/content/train_m/slice12967.png', 0, [0]],
#  ['/content/train_m/slice44239.png', 1, [196.02]],
#  ['/content/train_m/slice1759.png', 0, [0]],
#  ['/content/train_m/slice29947.png', 2, [171.82, 1.59]],
#  ['/content/train_m/slice10811.png', 1, [212.75]],
#  ['/content/train_m/slice32654.png', 1, [221.64]],
#  ['/content/train_m/slice17711.png', 2, [5.53, 209.39]],
#  ['/content/train_m/slice14873.png', 2, [218.16, 1.01]],
#  ['/content/train_m/slice45737.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_m/slice33219.png', 0, [0]],
#  ['/content/train_m/slice36120.png', 1, [218.98]],
#  ['/content/train_m/slice8736.png', 2, [183.3, 6.6]],
#  ['/content/train_m/slice46987.png', 2, [198.05, 8.0]],
#  ['/content/train_m/slice49044.png', 2, [2.12, 210.69]],
#  ['/content/train_m/slice38878.png', 1, [272.64]],
#  ['/content/train_m/slice27192.png', 2, [218.66, 7.9]],
#  ['/content/train_m/slice1919.png', 1, [212.75]],
#  ['/content/train_m/slice12913.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_m/slice16241.png', 2, [218.16, 1.01]],
#  ['/content/train_m/slice47103.png', 2, [6.54, 252.78]],
#  ['/content/train_m/slice2492.png', 1, [78.83]],
#  ['/content/train_m/slice18967.png', 1, [222.0]],
#  ['/content/train_m/slice32073.png', 2, [4.86, 215.11]],
#  ['/content/train_m/slice45587.png', 1, [104.7]],
#  ['/content/train_m/slice30625.png', 2, [179.64, 5.91]],
#  ['/content/train_m/slice45031.png', 2, [0.62, 279.65]],
#  ['/content/train_m/slice31377.png', 3, [1.39, 4.72, 242.28]],
#  ['/content/train_m/slice17694.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_m/slice31277.png', 1, [217.26]],
#  ['/content/train_m/slice45061.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_m/slice12222.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_m/slice22306.png', 0, [0]],
#  ['/content/train_m/slice21093.png', 1, [273.22]],
#  ['/content/train_m/slice44851.png', 0, [0]],
#  ['/content/train_m/slice3952.png', 2, [180.17, 4.18]],
#  ['/content/train_m/slice18927.png', 1, [184.03]],
#  ['/content/train_m/slice20469.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_m/slice27105.png', 1, [23.71]],
#  ['/content/train_m/slice38256.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_m/slice41495.png', 1, [171.6]],
#  ['/content/train_m/slice16351.png', 1, [169.77]],
#  ['/content/train_m/slice42876.png', 2, [187.46, 15.31]],
#  ['/content/train_m/slice44307.png', 2, [179.64, 4.51]],
#  ['/content/train_m/slice34678.png', 2, [205.58, 5.93]],
#  ['/content/train_m/slice21673.png', 2, [189.52, 15.4]],
#  ['/content/train_m/slice30063.png', 0, [0]],
#  ['/content/train_m/slice21122.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_m/slice36651.png', 0, [0]],
#  ['/content/train_m/slice10027.png', 2, [1.44, 153.02]],
#  ['/content/train_m/slice46235.png', 1, [0.61]],
#  ['/content/train_m/slice44928.png', 2, [187.46, 15.31]],
#  ['/content/train_m/slice12242.png', 2, [3.15, 191.52]],
#  ['/content/train_m/slice48978.png', 0, [0]],
#  ['/content/train_m/slice41527.png', 1, [208.69]],
#  ['/content/train_m/slice43637.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_m/slice9493.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_m/slice5364.png', 2, [0.13, 272.04]],
#  ['/content/train_m/slice10736.png', 2, [201.69, 7.33]],
#  ['/content/train_m/slice2541.png', 1, [207.78]],
#  ['/content/train_m/slice43659.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_m/slice39497.png', 2, [218.16, 1.01]],
#  ['/content/train_m/slice42299.png', 1, [271.15]],
#  ['/content/train_m/slice2007.png', 2, [0.3, 6.3]],
#  ['/content/train_m/slice11487.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_m/slice45691.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_m/slice24498.png', 2, [1.53, 251.42]],
#  ['/content/train_m/slice9290.png', 0, [0]],
#  ['/content/train_m/slice48396.png', 2, [218.66, 7.9]],
#  ['/content/train_m/slice36073.png', 1, [221.77]],
#  ['/content/train_m/slice23050.png', 2, [205.58, 5.93]],
#  ['/content/train_m/slice8751.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_m/slice44855.png', 0, [0]],
#  ['/content/train_m/slice41433.png', 0, [0]],
#  ['/content/train_m/slice20958.png', 1, [60.17]],
#  ['/content/train_m/slice32653.png', 1, [221.77]],
#  ['/content/train_m/slice21172.png', 0, [0]],
#  ['/content/train_m/slice7461.png', 1, [153.86]],
#  ['/content/train_m/slice7997.png', 2, [195.37, 9.54]],
#  ['/content/train_m/slice12277.png', 0, [0]],
#  ['/content/train_m/slice27097.png', 1, [2.34]],
#  ['/content/train_m/slice11458.png', 2, [210.46, 5.48]],
#  ['/content/train_m/slice42863.png', 1, [171.6]],
#  ['/content/train_m/slice5924.png', 2, [1.84, 157.64]],
#  ['/content/train_m/slice46903.png', 0, [0]],
#  ['/content/train_m/slice38146.png', 2, [194.65, 8.52]],
#  ['/content/train_m/slice6047.png', 1, [271.15]],
#  ['/content/train_m/slice24602.png', 0, [0]],
#  ['/content/train_m/slice12049.png', 1, [2.34]],
#  ['/content/train_m/slice6059.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_m/slice42361.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_m/slice5299.png', 2, [213.14, 2.09]],
#  ['/content/train_m/slice1084.png', 0, [0]],
#  ['/content/train_m/slice12142.png', 2, [210.46, 5.48]],
#  ['/content/train_m/slice18895.png', 1, [19.67]],
#  ['/content/train_m/slice3233.png', 1, [217.26]],
#  ['/content/train_m/slice18203.png', 0, [0]],
#  ['/content/train_m/slice34173.png', 0, [0]],
#  ['/content/train_m/slice24440.png', 1, [224.54]],
#  ['/content/train_m/slice12200.png', 1, [277.02]],
#  ['/content/train_m/slice42206.png', 2, [0.01, 211.38]],
#  ['/content/train_m/slice7448.png', 2, [4.59, 218.29]],
#  ['/content/train_m/slice47127.png', 2, [2.57, 186.09]],
#  ['/content/train_m/slice7388.png', 2, [0.48, 198.31]],
#  ['/content/train_m/slice29943.png', 2, [179.64, 4.51]],
#  ['/content/train_m/slice4675.png', 2, [0.62, 279.65]],
#  ['/content/train_m/slice20253.png', 0, [0]],
#  ['/content/train_m/slice13629.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_m/slice42804.png', 0, [0]],
#  ['/content/train_m/slice16172.png', 1, [78.83]],
#  ['/content/train_m/slice12868.png', 2, [0.91, 241.08]],
#  ['/content/train_m/slice47612.png', 0, [0]],
#  ['/content/train_m/slice33259.png', 1, [19.67]],
#  ['/content/train_m/slice26546.png', 2, [0.28, 230.25]],
#  ['/content/train_m/slice7259.png', 0, [0]],
#  ['/content/train_m/slice6730.png', 1, [272.64]],
#  ['/content/train_m/slice14144.png', 1, [197.47]],
#  ['/content/train_m/slice47054.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_m/slice39471.png', 1, [211.01]],
#  ['/content/train_m/slice18225.png', 1, [87.67]],
#  ['/content/train_m/slice32623.png', 2, [198.05, 8.0]],
#  ['/content/train_m/slice30565.png', 2, [189.52, 15.4]],
#  ['/content/train_m/slice29286.png', 2, [1.53, 251.42]],
#  ['/content/train_m/slice9328.png', 1, [47.53]],
#  ['/content/train_m/slice34017.png', 1, [227.05]],
#  ['/content/train_m/slice20976.png', 1, [175.21]],
#  ['/content/train_m/slice29215.png', 1, [208.69]],
#  ['/content/train_m/slice32788.png', 2, [0.77, 5.62]],
#  ['/content/train_m/slice21765.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_m/slice23010.png', 1, [60.17]],
#  ['/content/train_m/slice17762.png', 0, [0]],
#  ['/content/train_m/slice3877.png', 1, [177.05]],
#  ['/content/train_m/slice8777.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_m/slice44246.png', 2, [190.5, 12.86]],
#  ['/content/train_m/slice22330.png', 1, [95.36]],
#  ['/content/train_m/slice10237.png', 0, [0]],
#  ['/content/train_m/slice21180.png', 0, [0]],
#  ...]

# %%
lst_image
# Out:
# [['/content/train_i/slice12197.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_i/slice43011.png', 3, [2.67, 0.04, 231.21]],
#  ['/content/train_i/slice13556.png', 3, [0.38, 1.6, 260.67]],
#  ['/content/train_i/slice32559.png', 1, [1.53]],
#  ['/content/train_i/slice13515.png', 2, [203.74, 9.59]],
#  ['/content/train_i/slice12915.png', 3, [2.67, 0.04, 231.21]],
#  ['/content/train_i/slice49179.png', 2, [2.57, 186.09]],
#  ['/content/train_i/slice33903.png', 0, [0]],
#  ['/content/train_i/slice12285.png', 0, [0]],
#  ['/content/train_i/slice38953.png', 0, [0]],
#  ['/content/train_i/slice45581.png', 1, [54.41]],
#  ['/content/train_i/slice14903.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_i/slice21148.png', 1, [94.92]],
#  ['/content/train_i/slice34096.png', 2, [1.77, 278.1]],
#  ['/content/train_i/slice23041.png', 2, [189.52, 15.4]],
#  ['/content/train_i/slice12044.png', 0, [0]],
#  ['/content/train_i/slice8017.png', 1, [207.02]],
#  ['/content/train_i/slice20937.png', 0, [0]],
#  ['/content/train_i/slice39600.png', 2, [4.72, 204.21]],
#  ['/content/train_i/slice12917.png', 2, [3.53, 225.61]],
#  ['/content/train_i/slice4605.png', 1, [227.05]],
#  ['/content/train_i/slice29994.png', 2, [2.83, 280.34]],
#  ['/content/train_i/slice19798.png', 1, [0.44]],
#  ['/content/train_i/slice32705.png', 2, [1.03, 246.09]],
#  ['/content/train_i/slice10894.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_i/slice17739.png', 2, [0.3, 6.3]],
#  ['/content/train_i/slice4722.png', 1, [172.81]],
#  ['/content/train_i/slice37362.png', 1, [13.52]],
#  ['/content/train_i/slice22519.png', 1, [64.66]],
#  ['/content/train_i/slice18223.png', 1, [68.09]],
#  ['/content/train_i/slice14993.png', 1, [84.71]],
#  ['/content/train_i/slice3147.png', 1, [1.53]],
#  ['/content/train_i/slice10016.png', 1, [78.83]],
#  ['/content/train_i/slice45621.png', 2, [203.84, 6.54]],
#  ['/content/train_i/slice41609.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_i/slice39438.png', 1, [146.83]],
#  ['/content/train_i/slice26482.png', 1, [207.02]],
#  ['/content/train_i/slice44278.png', 1, [224.78]],
#  ['/content/train_i/slice32097.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_i/slice14900.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_i/slice35429.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_i/slice29971.png', 2, [1.79, 259.36]],
#  ['/content/train_i/slice38268.png', 0, [0]],
#  ['/content/train_i/slice34097.png', 2, [2.12, 277.47]],
#  ['/content/train_i/slice17005.png', 2, [5.56, 257.6]],
#  ['/content/train_i/slice25781.png', 2, [195.37, 9.54]],
#  ['/content/train_i/slice10125.png', 2, [0.12, 201.14]],
#  ['/content/train_i/slice34024.png', 2, [219.34, 0.48]],
#  ['/content/train_i/slice27899.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_i/slice13427.png', 1, [28.46]],
#  ['/content/train_i/slice662.png', 0, [0]],
#  ['/content/train_i/slice7269.png', 1, [23.71]],
#  ['/content/train_i/slice16184.png', 2, [1.84, 157.64]],
#  ['/content/train_i/slice30635.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_i/slice11371.png', 1, [19.67]],
#  ['/content/train_i/slice1251.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_i/slice22517.png', 1, [84.71]],
#  ['/content/train_i/slice27819.png', 1, [184.03]],
#  ['/content/train_i/slice31213.png', 1, [33.77]],
#  ['/content/train_i/slice1147.png', 1, [196.02]],
#  ['/content/train_i/slice31251.png', 2, [191.45, 11.15]],
#  ['/content/train_i/slice17584.png', 1, [210.25]],
#  ['/content/train_i/slice44350.png', 1, [272.64]],
#  ['/content/train_i/slice33403.png', 2, [0.62, 279.65]],
#  ['/content/train_i/slice2465.png', 1, [0.19]],
#  ['/content/train_i/slice20311.png', 2, [198.05, 8.0]],
#  ['/content/train_i/slice3999.png', 2, [1.15, 272.53]],
#  ['/content/train_i/slice14885.png', 2, [198.28, 10.12]],
#  ['/content/train_i/slice7962.png', 1, [60.17]],
#  ['/content/train_i/slice32785.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_i/slice14894.png', 2, [179.16, 5.34]],
#  ['/content/train_i/slice31349.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_i/slice1217.png', 2, [175.59, 3.52]],
#  ['/content/train_i/slice38780.png', 2, [201.69, 7.33]],
#  ['/content/train_i/slice2479.png', 1, [19.67]],
#  ['/content/train_i/slice23161.png', 2, [5.56, 257.6]],
#  ['/content/train_i/slice18933.png', 1, [199.23]],
#  ['/content/train_i/slice32119.png', 0, [0]],
#  ['/content/train_i/slice36771.png', 2, [203.74, 9.59]],
#  ['/content/train_i/slice8632.png', 1, [6.91]],
#  ['/content/train_i/slice36129.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_i/slice30499.png', 0, [0]],
#  ['/content/train_i/slice17502.png', 0, [0]],
#  ['/content/train_i/slice1846.png', 2, [205.58, 5.93]],
#  ['/content/train_i/slice22465.png', 2, [0.56, 276.34]],
#  ['/content/train_i/slice40840.png', 1, [210.25]],
#  ['/content/train_i/slice535.png', 2, [171.82, 1.59]],
#  ['/content/train_i/slice12717.png', 0, [0]],
#  ['/content/train_i/slice14070.png', 0, [0]],
#  ['/content/train_i/slice30666.png', 2, [0.75, 277.48]],
#  ['/content/train_i/slice17657.png', 2, [1.03, 246.09]],
#  ['/content/train_i/slice8163.png', 2, [0.3, 6.3]],
#  ['/content/train_i/slice25058.png', 1, [38.63]],
#  ['/content/train_i/slice19692.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_i/slice44396.png', 1, [166.78]],
#  ['/content/train_i/slice20327.png', 1, [206.35]],
#  ['/content/train_i/slice6074.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_i/slice4542.png', 1, [60.17]],
#  ['/content/train_i/slice2463.png', 1, [1.53]],
#  ['/content/train_i/slice23114.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_i/slice27837.png', 2, [203.84, 6.54]],
#  ['/content/train_i/slice9987.png', 1, [1.53]],
#  ['/content/train_i/slice39560.png', 1, [277.02]],
#  ['/content/train_i/slice35360.png', 2, [201.69, 7.33]],
#  ['/content/train_i/slice2585.png', 2, [175.59, 3.52]],
#  ['/content/train_i/slice19637.png', 1, [209.4]],
#  ['/content/train_i/slice9453.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_i/slice20960.png', 1, [78.83]],
#  ['/content/train_i/slice19080.png', 2, [4.72, 204.21]],
#  ['/content/train_i/slice7230.png', 0, [0]],
#  ['/content/train_i/slice47611.png', 0, [0]],
#  ['/content/train_i/slice5987.png', 2, [212.87, 6.28]],
#  ['/content/train_i/slice4639.png', 2, [171.82, 1.59]],
#  ['/content/train_i/slice40164.png', 1, [205.71]],
#  ['/content/train_i/slice40951.png', 3, [1.48, 7.22, 242.87]],
#  ['/content/train_i/slice12750.png', 1, [60.17]],
#  ['/content/train_i/slice27155.png', 2, [207.87, 3.7]],
#  ['/content/train_i/slice12747.png', 1, [42.84]],
#  ['/content/train_i/slice15529.png', 2, [1.1, 213.14]],
#  ['/content/train_i/slice16905.png', 1, [207.78]],
#  ['/content/train_i/slice21660.png', 1, [175.21]],
#  ['/content/train_i/slice16988.png', 1, [277.02]],
#  ['/content/train_i/slice25722.png', 0, [0]],
#  ['/content/train_i/slice36042.png', 2, [196.65, 8.59]],
#  ['/content/train_i/slice36838.png', 2, [2.84, 279.11]],
#  ['/content/train_i/slice10112.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_i/slice44947.png', 1, [208.69]],
#  ['/content/train_i/slice23092.png', 2, [202.71, 9.68]],
#  ['/content/train_i/slice37344.png', 1, [1.22]],
#  ['/content/train_i/slice5920.png', 1, [136.51]],
#  ['/content/train_i/slice20346.png', 2, [215.41, 1.61]],
#  ['/content/train_i/slice7451.png', 2, [5.53, 209.39]],
#  ['/content/train_i/slice31416.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_i/slice14333.png', 0, [0]],
#  ['/content/train_i/slice1816.png', 1, [136.51]],
#  ['/content/train_i/slice12930.png', 1, [172.81]],
#  ['/content/train_i/slice22487.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_i/slice21609.png', 0, [0]],
#  ['/content/train_i/slice15586.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_i/slice6024.png', 1, [218.98]],
#  ['/content/train_i/slice31284.png', 1, [222.54]],
#  ['/content/train_i/slice12238.png', 2, [5.3, 212.21]],
#  ['/content/train_i/slice42964.png', 2, [0.91, 241.08]],
#  ['/content/train_i/slice46904.png', 0, [0]],
#  ['/content/train_i/slice39515.png', 2, [188.25, 7.57]],
#  ['/content/train_i/slice47753.png', 2, [1.03, 246.09]],
#  ['/content/train_i/slice33470.png', 2, [0.22, 6.5]],
#  ['/content/train_i/slice43027.png', 1, [169.77]],
#  ['/content/train_i/slice4524.png', 2, [0.0, 0.01]],
#  ['/content/train_i/slice38041.png', 1, [2.34]],
#  ['/content/train_i/slice5398.png', 2, [5.3, 212.21]],
#  ['/content/train_i/slice23029.png', 1, [177.05]],
#  ['/content/train_i/slice8177.png', 0, [0]],
#  ['/content/train_i/slice1832.png', 1, [197.47]],
#  ['/content/train_i/slice5859.png', 0, [0]],
#  ['/content/train_i/slice12037.png', 1, [1.24]],
#  ['/content/train_i/slice18307.png', 2, [196.96, 11.58]],
#  ['/content/train_i/slice29864.png', 2, [1.84, 157.64]],
#  ['/content/train_i/slice15540.png', 1, [205.71]],
#  ['/content/train_i/slice17555.png', 1, [171.6]],
#  ['/content/train_i/slice14316.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_i/slice20328.png', 1, [205.71]],
#  ['/content/train_i/slice33240.png', 1, [1.22]],
#  ['/content/train_i/slice37537.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_i/slice11426.png', 2, [0.01, 211.38]],
#  ['/content/train_i/slice33928.png', 1, [0.5]],
#  ['/content/train_i/slice1935.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_i/slice35399.png', 2, [212.87, 6.28]],
#  ['/content/train_i/slice8779.png', 2, [0.62, 279.65]],
#  ['/content/train_i/slice28678.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_i/slice4012.png', 2, [7.13, 250.72]],
#  ['/content/train_i/slice39435.png', 1, [130.7]],
#  ['/content/train_i/slice29141.png', 1, [0.19]],
#  ['/content/train_i/slice3327.png', 2, [6.54, 252.78]],
#  ['/content/train_i/slice43658.png', 3, [1.88, 2.34, 270.21]],
#  ['/content/train_i/slice19719.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_i/slice11391.png', 1, [130.7]],
#  ['/content/train_i/slice44937.png', 2, [203.84, 6.54]],
#  ['/content/train_i/slice18886.png', 0, [0]],
#  ['/content/train_i/slice19670.png', 2, [207.31, 8.92]],
#  ['/content/train_i/slice23156.png', 2, [3.94, 283.63]],
#  ['/content/train_i/slice12772.png', 1, [187.02]],
#  ['/content/train_i/slice9491.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_i/slice16271.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_i/slice34113.png', 3, [1.39, 4.72, 242.28]],
#  ['/content/train_i/slice31289.png', 2, [218.16, 1.01]],
#  ['/content/train_i/slice29342.png', 2, [3.15, 191.52]],
#  ['/content/train_i/slice37442.png', 1, [221.64]],
#  ['/content/train_i/slice32051.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_i/slice36193.png', 1, [114.8]],
#  ['/content/train_i/slice47732.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_i/slice38826.png', 2, [197.55, 11.07]],
#  ['/content/train_i/slice1303.png', 1, [169.77]],
#  ['/content/train_i/slice46287.png', 1, [184.03]],
#  ['/content/train_i/slice48347.png', 2, [186.43, 15.39]],
#  ['/content/train_i/slice588.png', 2, [4.91, 260.75]],
#  ['/content/train_i/slice23062.png', 1, [207.02]],
#  ['/content/train_i/slice12214.png', 2, [2.84, 279.11]],
#  ['/content/train_i/slice43703.png', 2, [5.53, 209.39]],
#  ['/content/train_i/slice9464.png', 1, [277.02]],
#  ['/content/train_i/slice1292.png', 2, [4.59, 218.29]],
#  ['/content/train_i/slice25283.png', 0, [0]],
#  ['/content/train_i/slice35387.png', 1, [224.58]],
#  ['/content/train_i/slice19605.png', 2, [2.59, 164.07]],
#  ['/content/train_i/slice7336.png', 1, [214.85]],
#  ['/content/train_i/slice12861.png', 2, [0.12, 201.14]],
#  ['/content/train_i/slice31427.png', 0, [0]],
#  ['/content/train_i/slice42970.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_i/slice3968.png', 2, [0.48, 198.31]],
#  ['/content/train_i/slice39455.png', 2, [186.43, 15.39]],
#  ['/content/train_i/slice3318.png', 2, [2.83, 280.34]],
#  ['/content/train_i/slice44890.png', 1, [26.05]],
#  ['/content/train_i/slice5867.png', 0, [0]],
#  ['/content/train_i/slice44204.png', 1, [21.64]],
#  ['/content/train_i/slice6134.png', 0, [0]],
#  ['/content/train_i/slice18266.png', 2, [0.01, 211.38]],
#  ['/content/train_i/slice20391.png', 2, [0.44, 233.44]],
#  ['/content/train_i/slice40772.png', 0, [0]],
#  ['/content/train_i/slice48332.png', 2, [1.84, 157.64]],
#  ['/content/train_i/slice34083.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_i/slice4726.png', 1, [142.95]],
#  ['/content/train_i/slice21134.png', 2, [3.15, 191.52]],
#  ['/content/train_i/slice48957.png', 0, [0]],
#  ['/content/train_i/slice41484.png', 1, [114.22]],
#  ['/content/train_i/slice23076.png', 1, [222.54]],
#  ['/content/train_i/slice16134.png', 0, [0]],
#  ['/content/train_i/slice19800.png', 0, [0]],
#  ['/content/train_i/slice36748.png', 1, [214.85]],
#  ['/content/train_i/slice37448.png', 2, [212.61, 3.06]],
#  ['/content/train_i/slice48484.png', 2, [3.12, 227.94]],
#  ['/content/train_i/slice34596.png', 0, [0]],
#  ['/content/train_i/slice39479.png', 1, [206.35]],
#  ['/content/train_i/slice20493.png', 0, [0]],
#  ['/content/train_i/slice43627.png', 2, [171.82, 1.59]],
#  ['/content/train_i/slice36790.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_i/slice6101.png', 1, [84.71]],
#  ['/content/train_i/slice45627.png', 1, [211.01]],
#  ['/content/train_i/slice14233.png', 1, [226.13]],
#  ['/content/train_i/slice19038.png', 2, [0.75, 277.48]],
#  ['/content/train_i/slice40943.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_i/slice21633.png', 1, [23.71]],
#  ['/content/train_i/slice9327.png', 1, [42.84]],
#  ['/content/train_i/slice47596.png', 0, [0]],
#  ['/content/train_i/slice40123.png', 2, [1.44, 153.02]],
#  ['/content/train_i/slice40313.png', 2, [0.09, 5.38]],
#  ['/content/train_i/slice35365.png', 2, [1.1, 213.14]],
#  ['/content/train_i/slice22970.png', 0, [0]],
#  ['/content/train_i/slice8767.png', 2, [1.79, 259.36]],
#  ['/content/train_i/slice2501.png', 1, [141.86]],
#  ['/content/train_i/slice26415.png', 1, [4.52]],
#  ['/content/train_i/slice23705.png', 1, [141.86]],
#  ['/content/train_i/slice600.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_i/slice37511.png', 1, [271.15]],
#  ['/content/train_i/slice14275.png', 3, [1.48, 7.22, 242.87]],
#  ['/content/train_i/slice18318.png', 2, [181.76, 3.4]],
#  ['/content/train_i/slice42885.png', 2, [203.84, 6.54]],
#  ['/content/train_i/slice9454.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_i/slice47657.png', 1, [189.94]],
#  ['/content/train_i/slice28623.png', 2, [1.15, 272.53]],
#  ['/content/train_i/slice2532.png', 2, [2.12, 210.69]],
#  ['/content/train_i/slice21616.png', 1, [0.5]],
#  ['/content/train_i/slice23712.png', 1, [175.21]],
#  ['/content/train_i/slice5357.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_i/slice13473.png', 2, [203.84, 6.54]],
#  ['/content/train_i/slice26484.png', 1, [205.71]],
#  ['/content/train_i/slice37416.png', 2, [2.12, 210.69]],
#  ['/content/train_i/slice29228.png', 1, [224.54]],
#  ['/content/train_i/slice8834.png', 1, [107.99]],
#  ['/content/train_i/slice47771.png', 1, [271.15]],
#  ['/content/train_i/slice43753.png', 0, [0]],
#  ['/content/train_i/slice12038.png', 1, [1.35]],
#  ['/content/train_i/slice47031.png', 2, [203.74, 9.59]],
#  ['/content/train_i/slice8715.png', 1, [220.08]],
#  ['/content/train_i/slice10145.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_i/slice29167.png', 1, [68.09]],
#  ['/content/train_i/slice8098.png', 1, [272.64]],
#  ['/content/train_i/slice3226.png', 1, [207.02]],
#  ['/content/train_i/slice47705.png', 2, [218.16, 1.01]],
#  ['/content/train_i/slice2011.png', 2, [0.2, 1.98]],
#  ['/content/train_i/slice3977.png', 2, [1.03, 246.09]],
#  ['/content/train_i/slice1911.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_i/slice24553.png', 2, [4.0, 198.37]],
#  ['/content/train_i/slice2508.png', 1, [175.21]],
#  ['/content/train_i/slice47659.png', 1, [196.02]],
#  ['/content/train_i/slice22985.png', 1, [0.19]],
#  ['/content/train_i/slice40972.png', 2, [2.18, 181.76]],
#  ['/content/train_i/slice31308.png', 2, [183.3, 6.6]],
#  ['/content/train_i/slice40942.png', 2, [2.84, 279.11]],
#  ['/content/train_i/slice26537.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_i/slice5905.png', 1, [33.77]],
#  ['/content/train_i/slice28652.png', 2, [4.59, 218.29]],
#  ['/content/train_i/slice9404.png', 2, [212.61, 3.06]],
#  ['/content/train_i/slice4500.png', 0, [0]],
#  ['/content/train_i/slice12800.png', 1, [208.25]],
#  ['/content/train_i/slice48454.png', 1, [272.64]],
#  ['/content/train_i/slice12825.png', 2, [210.36, 4.03]],
#  ['/content/train_i/slice38847.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_i/slice44998.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_i/slice16318.png', 2, [2.84, 279.11]],
#  ['/content/train_i/slice18917.png', 1, [141.86]],
#  ['/content/train_i/slice2526.png', 2, [196.65, 8.59]],
#  ['/content/train_i/slice25837.png', 2, [179.64, 5.91]],
#  ['/content/train_i/slice40102.png', 1, [26.05]],
#  ['/content/train_i/slice10878.png', 1, [172.81]],
#  ['/content/train_i/slice46384.png', 2, [0.91, 241.08]],
#  ['/content/train_i/slice10692.png', 1, [31.83]],
#  ['/content/train_i/slice24481.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_i/slice8773.png', 3, [2.22, 2.54, 269.77]],
#  ['/content/train_i/slice47619.png', 1, [4.52]],
#  ['/content/train_i/slice38769.png', 1, [199.23]],
#  ['/content/train_i/slice42150.png', 1, [13.52]],
#  ['/content/train_i/slice17735.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_i/slice37472.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_i/slice24459.png', 2, [203.74, 9.59]],
#  ['/content/train_i/slice33351.png', 2, [203.74, 9.59]],
#  ['/content/train_i/slice1805.png', 1, [54.41]],
#  ['/content/train_i/slice11473.png', 2, [179.64, 5.91]],
#  ['/content/train_i/slice26646.png', 0, [0]],
#  ['/content/train_i/slice44358.png', 2, [2.83, 280.34]],
#  ['/content/train_i/slice13551.png', 2, [0.44, 233.44]],
#  ['/content/train_i/slice18268.png', 1, [210.25]],
#  ['/content/train_i/slice2443.png', 0, [0]],
#  ['/content/train_i/slice31364.png', 2, [3.94, 283.63]],
#  ['/content/train_i/slice17648.png', 2, [0.48, 198.31]],
#  ['/content/train_i/slice1216.png', 2, [180.17, 4.18]],
#  ['/content/train_i/slice25895.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_i/slice1236.png', 1, [218.98]],
#  ['/content/train_i/slice8618.png', 1, [1.35]],
#  ['/content/train_i/slice32586.png', 1, [60.17]],
#  ['/content/train_i/slice23195.png', 1, [132.07]],
#  ['/content/train_i/slice16290.png', 2, [1.53, 251.42]],
#  ['/content/train_i/slice4635.png', 2, [179.64, 4.51]],
#  ['/content/train_i/slice18985.png', 2, [213.66, 8.26]],
#  ['/content/train_i/slice9529.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_i/slice8097.png', 1, [273.22]],
#  ['/content/train_i/slice39482.png', 1, [209.68]],
#  ['/content/train_i/slice40098.png', 1, [13.52]],
#  ['/content/train_i/slice33261.png', 1, [23.71]],
#  ['/content/train_i/slice45609.png', 1, [199.23]],
#  ['/content/train_i/slice7360.png', 2, [202.71, 9.68]],
#  ['/content/train_i/slice46954.png', 1, [95.36]],
#  ['/content/train_i/slice41640.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_i/slice29157.png', 1, [23.71]],
#  ['/content/train_i/slice11461.png', 2, [213.66, 8.26]],
#  ['/content/train_i/slice24594.png', 0, [0]],
#  ['/content/train_i/slice10118.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_i/slice13508.png', 2, [212.61, 3.06]],
#  ['/content/train_i/slice38731.png', 1, [19.67]],
#  ['/content/train_i/slice9351.png', 1, [184.03]],
#  ['/content/train_i/slice4603.png', 1, [222.0]],
#  ['/content/train_i/slice25091.png', 2, [186.43, 15.39]],
#  ['/content/train_i/slice31248.png', 2, [187.46, 15.31]],
#  ['/content/train_i/slice19625.png', 2, [195.37, 9.54]],
#  ['/content/train_i/slice15595.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_i/slice40067.png', 0, [0]],
#  ['/content/train_i/slice12104.png', 2, [201.69, 7.33]],
#  ['/content/train_i/slice44351.png', 1, [271.15]],
#  ['/content/train_i/slice33934.png', 0, [0]],
#  ['/content/train_i/slice45572.png', 1, [21.64]],
#  ['/content/train_i/slice34805.png', 2, [3.53, 225.61]],
#  ['/content/train_i/slice11488.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_i/slice27933.png', 1, [273.22]],
#  ['/content/train_i/slice29210.png', 2, [0.01, 211.38]],
#  ['/content/train_i/slice36130.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_i/slice4713.png', 2, [4.86, 215.11]],
#  ['/content/train_i/slice21754.png', 1, [207.35]],
#  ['/content/train_i/slice38206.png', 2, [2.84, 279.11]],
#  ['/content/train_i/slice30685.png', 2, [5.56, 257.6]],
#  ['/content/train_i/slice27104.png', 1, [21.64]],
#  ['/content/train_i/slice40888.png', 2, [180.17, 4.18]],
#  ['/content/train_i/slice19803.png', 0, [0]],
#  ['/content/train_i/slice42134.png', 1, [1.35]],
#  ['/content/train_i/slice25924.png', 2, [2.18, 181.76]],
#  ['/content/train_i/slice47677.png', 2, [1.1, 213.14]],
#  ['/content/train_i/slice6724.png', 3, [1.44, 1.36, 276.57]],
#  ['/content/train_i/slice48349.png', 2, [189.52, 15.4]],
#  ['/content/train_i/slice38893.png', 2, [5.56, 257.6]],
#  ['/content/train_i/slice30657.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_i/slice43692.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_i/slice26553.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_i/slice22305.png', 0, [0]],
#  ['/content/train_i/slice5320.png', 2, [180.17, 4.18]],
#  ['/content/train_i/slice26462.png', 2, [190.5, 12.86]],
#  ['/content/train_i/slice41695.png', 0, [0]],
#  ['/content/train_i/slice1784.png', 0, [0]],
#  ['/content/train_i/slice24549.png', 2, [4.86, 215.11]],
#  ['/content/train_i/slice14928.png', 4, [0.83, 1.83, 0.78, 266.04]],
#  ['/content/train_i/slice43032.png', 1, [122.05]],
#  ['/content/train_i/slice3866.png', 1, [124.18]],
#  ['/content/train_i/slice19052.png', 2, [3.94, 283.63]],
#  ['/content/train_i/slice49080.png', 2, [218.66, 7.9]],
#  ['/content/train_i/slice12812.png', 1, [224.54]],
#  ['/content/train_i/slice36097.png', 2, [179.64, 5.91]],
#  ['/content/train_i/slice9403.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice21662.png', 1, [180.19]],
#  ['/content/train_i/slice46296.png', 2, [187.46, 15.31]],
#  ['/content/train_i/slice45732.png', 2, [4.91, 260.75]],
#  ['/content/train_i/slice36815.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_i/slice36019.png', 2, [1.44, 153.02]],
#  ['/content/train_i/slice36903.png', 0, [0]],
#  ['/content/train_i/slice30554.png', 1, [180.19]],
#  ['/content/train_i/slice14123.png', 1, [104.7]],
#  ['/content/train_i/slice6673.png', 2, [213.66, 8.26]],
#  ['/content/train_i/slice49114.png', 1, [207.35]],
#  ['/content/train_i/slice2470.png', 0, [0]],
#  ['/content/train_i/slice5384.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_i/slice25855.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_i/slice17700.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_i/slice2461.png', 1, [1.24]],
#  ['/content/train_i/slice43671.png', 2, [1.15, 272.53]],
#  ['/content/train_i/slice40808.png', 2, [1.84, 157.64]],
#  ['/content/train_i/slice25866.png', 2, [1.53, 251.42]],
#  ['/content/train_i/slice12802.png', 1, [207.02]],
#  ['/content/train_i/slice8044.png', 2, [202.71, 9.68]],
#  ['/content/train_i/slice3840.png', 2, [0.0, 0.01]],
#  ['/content/train_i/slice5869.png', 0, [0]],
#  ['/content/train_i/slice18934.png', 1, [199.79]],
#  ['/content/train_i/slice49220.png', 0, [0]],
#  ['/content/train_i/slice35350.png', 1, [199.79]],
#  ['/content/train_i/slice27296.png', 1, [166.78]],
#  ['/content/train_i/slice23805.png', 2, [0.12, 201.14]],
#  ['/content/train_i/slice28551.png', 1, [220.08]],
#  ['/content/train_i/slice40074.png', 0, [0]],
#  ['/content/train_i/slice21090.png', 2, [0.75, 277.48]],
#  ['/content/train_i/slice6561.png', 0, [0]],
#  ['/content/train_i/slice10679.png', 0, [0]],
#  ['/content/train_i/slice29387.png', 0, [0]],
#  ['/content/train_i/slice20443.png', 2, [4.18, 220.12]],
#  ['/content/train_i/slice46246.png', 0, [0]],
#  ['/content/train_i/slice13521.png', 2, [194.95, 9.05]],
#  ['/content/train_i/slice40777.png', 1, [2.34]],
#  ['/content/train_i/slice47141.png', 1, [84.71]],
#  ['/content/train_i/slice2489.png', 1, [54.41]],
#  ['/content/train_i/slice24361.png', 1, [2.34]],
#  ['/content/train_i/slice11468.png', 2, [194.6, 10.42]],
#  ['/content/train_i/slice29283.png', 2, [0.44, 233.44]],
#  ['/content/train_i/slice25044.png', 2, [0.0, 0.01]],
#  ['/content/train_i/slice30747.png', 0, [0]],
#  ['/content/train_i/slice38881.png', 2, [0.56, 276.34]],
#  ['/content/train_i/slice31388.png', 2, [4.59, 218.29]],
#  ['/content/train_i/slice25727.png', 0, [0]],
#  ['/content/train_i/slice42959.png', 1, [212.75]],
#  ['/content/train_i/slice13586.png', 2, [5.71, 253.95]],
#  ['/content/train_i/slice10738.png', 2, [205.58, 5.93]],
#  ['/content/train_i/slice42795.png', 0, [0]],
#  ['/content/train_i/slice15596.png', 2, [0.48, 198.31]],
#  ['/content/train_i/slice21840.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_i/slice10199.png', 1, [132.07]],
#  ['/content/train_i/slice18263.png', 2, [207.87, 3.7]],
#  ['/content/train_i/slice29877.png', 1, [199.23]],
#  ['/content/train_i/slice27829.png', 2, [189.52, 15.4]],
#  ['/content/train_i/slice22289.png', 0, [0]],
#  ['/content/train_i/slice5868.png', 0, [0]],
#  ['/content/train_i/slice21705.png', 1, [227.05]],
#  ['/content/train_i/slice15514.png', 1, [199.79]],
#  ['/content/train_i/slice35485.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_i/slice35381.png', 1, [217.26]],
#  ['/content/train_i/slice24516.png', 2, [0.13, 272.04]],
#  ['/content/train_i/slice2639.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_i/slice44936.png', 2, [201.69, 7.33]],
#  ['/content/train_i/slice34653.png', 2, [2.59, 164.07]],
#  ['/content/train_i/slice34775.png', 1, [271.15]],
#  ['/content/train_i/slice44184.png', 1, [1.22]],
#  ['/content/train_i/slice10164.png', 2, [4.91, 260.75]],
#  ['/content/train_i/slice20413.png', 2, [0.56, 276.34]],
#  ['/content/train_i/slice32002.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_i/slice29170.png', 1, [95.36]],
#  ['/content/train_i/slice10116.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_i/slice37452.png', 2, [218.66, 7.9]],
#  ['/content/train_i/slice17028.png', 2, [4.72, 204.21]],
#  ['/content/train_i/slice10216.png', 2, [0.77, 5.62]],
#  ['/content/train_i/slice29239.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice48451.png', 2, [0.62, 279.65]],
#  ['/content/train_i/slice542.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_i/slice48280.png', 0, [0]],
#  ['/content/train_i/slice44393.png', 1, [177.89]],
#  ['/content/train_i/slice17708.png', 2, [4.59, 218.29]],
#  ['/content/train_i/slice33332.png', 1, [224.54]],
#  ['/content/train_i/slice22967.png', 0, [0]],
#  ['/content/train_i/slice19807.png', 0, [0]],
#  ['/content/train_i/slice44887.png', 1, [19.67]],
#  ['/content/train_i/slice19784.png', 2, [4.79, 41.22]],
#  ['/content/train_i/slice47052.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_i/slice14976.png', 2, [4.72, 204.21]],
#  ['/content/train_i/slice29980.png', 3, [1.44, 1.36, 276.57]],
#  ['/content/train_i/slice3253.png', 2, [213.66, 8.26]],
#  ['/content/train_i/slice21033.png', 2, [210.36, 4.03]],
#  ['/content/train_i/slice38757.png', 2, [2.59, 164.07]],
#  ['/content/train_i/slice8118.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_i/slice20380.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_i/slice27094.png', 0, [0]],
#  ['/content/train_i/slice42280.png', 2, [0.91, 241.08]],
#  ['/content/train_i/slice20429.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_i/slice9538.png', 1, [0.44]],
#  ['/content/train_i/slice39612.png', 1, [122.05]],
#  ['/content/train_i/slice31436.png', 0, [0]],
#  ['/content/train_i/slice29929.png', 2, [213.66, 8.26]],
#  ['/content/train_i/slice40312.png', 2, [0.77, 5.62]],
#  ['/content/train_i/slice26467.png', 2, [198.05, 8.0]],
#  ['/content/train_i/slice6061.png', 2, [5.56, 257.6]],
#  ['/content/train_i/slice7244.png', 0, [0]],
#  ['/content/train_i/slice26472.png', 2, [2.12, 210.69]],
#  ['/content/train_i/slice38246.png', 1, [107.99]],
#  ['/content/train_i/slice42355.png', 1, [64.66]],
#  ['/content/train_i/slice46354.png', 2, [194.65, 8.52]],
#  ['/content/train_i/slice47056.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_i/slice47789.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_i/slice22982.png', 1, [1.35]],
#  ['/content/train_i/slice47146.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_i/slice31933.png', 2, [189.52, 15.4]],
#  ['/content/train_i/slice34104.png', 2, [4.91, 260.75]],
#  ['/content/train_i/slice522.png', 2, [197.55, 11.07]],
#  ['/content/train_i/slice48442.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_i/slice44921.png', 1, [189.94]],
#  ['/content/train_i/slice21176.png', 0, [0]],
#  ['/content/train_i/slice33247.png', 0, [0]],
#  ['/content/train_i/slice46395.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_i/slice20324.png', 1, [208.25]],
#  ['/content/train_i/slice45798.png', 0, [0]],
#  ['/content/train_i/slice14145.png', 1, [199.23]],
#  ['/content/train_i/slice38848.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_i/slice19603.png', 2, [1.44, 153.02]],
#  ['/content/train_i/slice12724.png', 1, [0.5]],
#  ['/content/train_i/slice7937.png', 1, [0.19]],
#  ['/content/train_i/slice43673.png', 2, [2.12, 277.47]],
#  ['/content/train_i/slice21079.png', 2, [1.79, 259.36]],
#  ['/content/train_i/slice12787.png', 2, [198.05, 8.0]],
#  ['/content/train_i/slice42379.png', 0, [0]],
#  ['/content/train_i/slice19014.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_i/slice34706.png', 1, [221.64]],
#  ['/content/train_i/slice31317.png', 4, [9.29, 1.52, 149.57, 0.57]],
#  ['/content/train_i/slice24576.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_i/slice8794.png', 2, [2.84, 279.11]],
#  ['/content/train_i/slice44404.png', 1, [94.92]],
#  ['/content/train_i/slice26550.png', 2, [1.53, 251.42]],
#  ['/content/train_i/slice43694.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_i/slice47774.png', 2, [1.15, 275.35]],
#  ['/content/train_i/slice8859.png', 0, [0]],
#  ['/content/train_i/slice43729.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_i/slice7470.png', 1, [74.76]],
#  ['/content/train_i/slice18905.png', 1, [54.41]],
#  ['/content/train_i/slice3256.png', 2, [202.71, 9.68]],
#  ['/content/train_i/slice21150.png', 1, [74.76]],
#  ['/content/train_i/slice41007.png', 0, [0]],
#  ['/content/train_i/slice17626.png', 2, [194.65, 8.52]],
#  ['/content/train_i/slice36117.png', 2, [0.12, 201.14]],
#  ['/content/train_i/slice39444.png', 1, [175.21]],
#  ['/content/train_i/slice3193.png', 1, [177.05]],
#  ['/content/train_i/slice24511.png', 2, [0.62, 279.65]],
#  ['/content/train_i/slice8176.png', 0, [0]],
#  ['/content/train_i/slice48368.png', 1, [208.25]],
#  ['/content/train_i/slice5447.png', 0, [0]],
#  ['/content/train_i/slice16374.png', 2, [0.05, 3.56]],
#  ['/content/train_i/slice4756.png', 0, [0]],
#  ['/content/train_i/slice18222.png', 1, [60.17]],
#  ['/content/train_i/slice21081.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_i/slice43519.png', 1, [19.67]],
#  ['/content/train_i/slice11406.png', 1, [191.8]],
#  ['/content/train_i/slice31403.png', 1, [132.07]],
#  ['/content/train_i/slice5305.png', 2, [213.66, 8.26]],
#  ['/content/train_i/slice28456.png', 1, [0.5]],
#  ['/content/train_i/slice27962.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_i/slice39491.png', 1, [224.58]],
#  ['/content/train_i/slice13459.png', 1, [196.02]],
#  ['/content/train_i/slice44287.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice36153.png', 2, [3.21, 278.18]],
#  ['/content/train_i/slice32038.png', 1, [272.64]],
#  ['/content/train_i/slice10701.png', 1, [87.67]],
#  ['/content/train_i/slice48438.png', 2, [1.53, 251.42]],
#  ['/content/train_i/slice30497.png', 0, [0]],
#  ['/content/train_i/slice6577.png', 1, [2.34]],
#  ['/content/train_i/slice23055.png', 1, [211.01]],
#  ['/content/train_i/slice15680.png', 2, [4.79, 41.22]],
#  ['/content/train_i/slice21112.png', 2, [7.13, 250.72]],
#  ['/content/train_i/slice18341.png', 2, [1.03, 246.09]],
#  ['/content/train_i/slice14753.png', 0, [0]],
#  ['/content/train_i/slice8123.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_i/slice45023.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_i/slice12769.png', 1, [177.05]],
#  ['/content/train_i/slice46300.png', 2, [192.82, 10.38]],
#  ['/content/train_i/slice16311.png', 2, [1.15, 272.53]],
#  ['/content/train_i/slice1850.png', 2, [0.01, 211.38]],
#  ['/content/train_i/slice2712.png', 0, [0]],
#  ['/content/train_i/slice38925.png', 1, [153.86]],
#  ['/content/train_i/slice43552.png', 1, [187.02]],
#  ['/content/train_i/slice47655.png', 1, [184.03]],
#  ['/content/train_i/slice33408.png', 2, [0.13, 272.04]],
#  ['/content/train_i/slice14760.png', 0, [0]],
#  ['/content/train_i/slice22301.png', 1, [0.19]],
#  ['/content/train_i/slice14121.png', 1, [87.67]],
#  ['/content/train_i/slice45654.png', 2, [215.41, 1.61]],
#  ['/content/train_i/slice38254.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_i/slice15619.png', 2, [0.62, 279.65]],
#  ['/content/train_i/slice3821.png', 0, [0]],
#  ['/content/train_i/slice6005.png', 2, [175.59, 3.52]],
#  ['/content/train_i/slice10019.png', 1, [104.7]],
#  ['/content/train_i/slice46309.png', 2, [1.1, 213.14]],
#  ['/content/train_i/slice6131.png', 0, [0]],
#  ['/content/train_i/slice35529.png', 1, [0.45]],
#  ['/content/train_i/slice39410.png', 1, [3.24]],
#  ['/content/train_i/slice10895.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_i/slice6010.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_i/slice24541.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_i/slice20462.png', 1, [107.99]],
#  ['/content/train_i/slice32703.png', 2, [0.44, 233.44]],
#  ['/content/train_i/slice2444.png', 0, [0]],
#  ['/content/train_i/slice14933.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_i/slice16962.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_i/slice37545.png', 2, [4.86, 215.11]],
#  ['/content/train_i/slice40076.png', 0, [0]],
#  ['/content/train_i/slice42273.png', 2, [0.12, 201.14]],
#  ['/content/train_i/slice2668.png', 2, [2.18, 181.76]],
#  ['/content/train_i/slice1987.png', 1, [169.77]],
#  ['/content/train_i/slice26503.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice22278.png', 0, [0]],
#  ['/content/train_i/slice10080.png', 1, [222.54]],
#  ['/content/train_i/slice15495.png', 1, [130.7]],
#  ['/content/train_i/slice19662.png', 2, [215.41, 1.61]],
#  ['/content/train_i/slice44224.png', 1, [136.51]],
#  ['/content/train_i/slice25926.png', 1, [172.81]],
#  ['/content/train_i/slice3247.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice44389.png', 2, [4.0, 198.37]],
#  ['/content/train_i/slice29269.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_i/slice20432.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_i/slice1810.png', 1, [95.36]],
#  ['/content/train_i/slice39433.png', 1, [118.2]],
#  ['/content/train_i/slice39450.png', 1, [191.8]],
#  ['/content/train_i/slice27936.png', 2, [0.13, 272.04]],
#  ['/content/train_i/slice12193.png', 3, [2.22, 2.54, 269.77]],
#  ['/content/train_i/slice39508.png', 2, [202.71, 9.68]],
#  ['/content/train_i/slice20909.png', 0, [0]],
#  ['/content/train_i/slice29134.png', 1, [0.24]],
#  ['/content/train_i/slice9282.png', 0, [0]],
#  ['/content/train_i/slice28509.png', 1, [199.23]],
#  ['/content/train_i/slice9442.png', 1, [207.35]],
#  ['/content/train_i/slice25187.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_i/slice14956.png', 2, [7.13, 250.72]],
#  ['/content/train_i/slice43543.png', 2, [1.44, 153.02]],
#  ['/content/train_i/slice21677.png', 2, [195.37, 9.54]],
#  ['/content/train_i/slice12157.png', 2, [179.64, 5.91]],
#  ['/content/train_i/slice16208.png', 2, [201.69, 7.33]],
#  ['/content/train_i/slice16332.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_i/slice27211.png', 2, [171.82, 1.59]],
#  ['/content/train_i/slice40278.png', 2, [3.85, 223.1]],
#  ['/content/train_i/slice2552.png', 1, [224.54]],
#  ['/content/train_i/slice32810.png', 0, [0]],
#  ['/content/train_i/slice15509.png', 1, [189.94]],
#  ['/content/train_i/slice44988.png', 2, [183.3, 6.6]],
#  ['/content/train_i/slice5906.png', 1, [38.63]],
#  ['/content/train_i/slice10680.png', 2, [0.0, 0.01]],
#  ['/content/train_i/slice14819.png', 1, [171.6]],
#  ['/content/train_i/slice11437.png', 1, [207.02]],
#  ['/content/train_i/slice28573.png', 2, [179.64, 5.91]],
#  ['/content/train_i/slice14814.png', 1, [146.83]],
#  ['/content/train_i/slice37412.png', 2, [201.69, 7.33]],
#  ['/content/train_i/slice42167.png', 1, [104.7]],
#  ['/content/train_i/slice24357.png', 0, [0]],
#  ['/content/train_i/slice27136.png', 1, [187.02]],
#  ['/content/train_i/slice8634.png', 1, [13.52]],
#  ['/content/train_i/slice20944.png', 1, [6.91]],
#  ['/content/train_i/slice38936.png', 2, [4.79, 41.22]],
#  ['/content/train_i/slice20451.png', 2, [2.57, 186.09]],
#  ['/content/train_i/slice5318.png', 2, [179.16, 5.34]],
#  ['/content/train_i/slice48426.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_i/slice2615.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_i/slice12866.png', 2, [0.28, 230.25]],
#  ['/content/train_i/slice43680.png', 2, [4.91, 260.75]],
#  ['/content/train_i/slice41559.png', 2, [203.74, 9.59]],
#  ['/content/train_i/slice30536.png', 1, [78.83]],
#  ['/content/train_i/slice38852.png', 2, [0.48, 198.31]],
#  ['/content/train_i/slice36057.png', 1, [207.78]],
#  ['/content/train_i/slice48346.png', 1, [199.79]],
#  ['/content/train_i/slice19016.png', 2, [0.48, 198.31]],
#  ['/content/train_i/slice6676.png', 2, [202.71, 9.68]],
#  ['/content/train_i/slice43546.png', 1, [169.98]],
#  ['/content/train_i/slice8129.png', 2, [3.53, 225.61]],
#  ['/content/train_i/slice43558.png', 1, [199.79]],
#  ['/content/train_i/slice17503.png', 0, [0]],
#  ['/content/train_i/slice31947.png', 1, [211.01]],
#  ['/content/train_i/slice11498.png', 2, [0.28, 230.25]],
#  ['/content/train_i/slice10205.png', 1, [84.71]],
#  ['/content/train_i/slice21071.png', 1, [212.75]],
#  ['/content/train_i/slice8664.png', 1, [175.21]],
#  ['/content/train_i/slice519.png', 2, [203.74, 9.59]],
#  ['/content/train_i/slice23767.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice45533.png', 0, [0]],
#  ['/content/train_i/slice36218.png', 0, [0]],
#  ['/content/train_i/slice17551.png', 2, [1.44, 153.02]],
#  ['/content/train_i/slice24463.png', 2, [196.96, 11.58]],
#  ['/content/train_i/slice25108.png', 1, [210.25]],
#  ['/content/train_i/slice23729.png', 2, [195.37, 9.54]],
#  ['/content/train_i/slice20289.png', 2, [2.59, 164.07]],
#  ['/content/train_i/slice7274.png', 1, [38.63]],
#  ['/content/train_i/slice38939.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_i/slice34061.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_i/slice5910.png', 1, [60.17]],
#  ['/content/train_i/slice35326.png', 1, [95.36]],
#  ['/content/train_i/slice40081.png', 1, [1.24]],
#  ['/content/train_i/slice27187.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice47831.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_i/slice16860.png', 1, [114.22]],
#  ['/content/train_i/slice20418.png', 2, [2.83, 280.34]],
#  ['/content/train_i/slice11338.png', 0, [0]],
#  ['/content/train_i/slice1106.png', 1, [3.24]],
#  ['/content/train_i/slice2518.png', 1, [199.79]],
#  ['/content/train_i/slice18413.png', 1, [84.71]],
#  ['/content/train_i/slice11532.png', 2, [4.91, 260.75]],
#  ['/content/train_i/slice1982.png', 2, [3.15, 191.52]],
#  ['/content/train_i/slice22440.png', 1, [218.98]],
#  ['/content/train_i/slice3191.png', 1, [171.6]],
#  ['/content/train_i/slice43737.png', 1, [0.45]],
#  ['/content/train_i/slice25921.png', 2, [4.0, 198.37]],
#  ['/content/train_i/slice19596.png', 1, [114.22]],
#  ['/content/train_i/slice29886.png', 2, [196.65, 8.59]],
#  ['/content/train_i/slice6783.png', 1, [100.85]],
#  ['/content/train_i/slice39523.png', 2, [171.82, 1.59]],
#  ['/content/train_i/slice27932.png', 1, [277.02]],
#  ['/content/train_i/slice11471.png', 2, [188.25, 7.57]],
#  ['/content/train_i/slice3263.png', 2, [188.25, 7.57]],
#  ['/content/train_i/slice1893.png', 2, [194.95, 9.05]],
#  ['/content/train_i/slice5243.png', 1, [171.6]],
#  ['/content/train_i/slice41659.png', 1, [169.77]],
#  ['/content/train_i/slice554.png', 2, [0.28, 230.25]],
#  ['/content/train_i/slice33953.png', 1, [54.41]],
#  ['/content/train_i/slice18396.png', 2, [4.72, 204.21]],
#  ['/content/train_i/slice43051.png', 2, [0.2, 1.98]],
#  ['/content/train_i/slice27131.png', 1, [171.6]],
#  ['/content/train_i/slice33263.png', 1, [28.46]],
#  ['/content/train_i/slice44872.png', 1, [0.5]],
#  ['/content/train_i/slice36810.png', 2, [1.53, 251.42]],
#  ['/content/train_i/slice17038.png', 1, [142.95]],
#  ['/content/train_i/slice25720.png', 1, [0.5]],
#  ['/content/train_i/slice29927.png', 2, [212.87, 6.28]],
#  ['/content/train_i/slice16186.png', 1, [169.98]],
#  ['/content/train_i/slice29303.png', 1, [271.15]],
#  ['/content/train_i/slice19025.png', 2, [1.03, 246.09]],
#  ['/content/train_i/slice40773.png', 0, [0]],
#  ['/content/train_i/slice38877.png', 1, [273.22]],
#  ['/content/train_i/slice29892.png', 2, [2.12, 210.69]],
#  ['/content/train_i/slice42800.png', 0, [0]],
#  ['/content/train_i/slice19549.png', 0, [0]],
#  ['/content/train_i/slice40071.png', 0, [0]],
#  ['/content/train_i/slice28703.png', 0, [0]],
#  ['/content/train_i/slice2693.png', 2, [0.09, 5.38]],
#  ['/content/train_i/slice21723.png', 2, [203.74, 9.59]],
#  ['/content/train_i/slice16282.png', 1, [207.35]],
#  ['/content/train_i/slice30510.png', 0, [0]],
#  ['/content/train_i/slice42155.png', 1, [28.46]],
#  ['/content/train_i/slice39421.png', 1, [33.77]],
#  ['/content/train_i/slice2644.png', 2, [7.13, 250.72]],
#  ['/content/train_i/slice9355.png', 1, [196.02]],
#  ['/content/train_i/slice44315.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_i/slice34142.png', 1, [107.99]],
#  ['/content/train_i/slice48339.png', 1, [184.03]],
#  ['/content/train_i/slice45592.png', 1, [136.51]],
#  ['/content/train_i/slice36665.png', 1, [0.19]],
#  ['/content/train_i/slice23201.png', 1, [84.71]],
#  ['/content/train_i/slice7431.png', 2, [6.54, 252.78]],
#  ['/content/train_i/slice15578.png', 2, [179.16, 5.34]],
#  ['/content/train_i/slice45685.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_i/slice40754.png', 0, [0]],
#  ['/content/train_i/slice14207.png', 2, [188.25, 7.57]],
#  ['/content/train_i/slice6547.png', 0, [0]],
#  ['/content/train_i/slice28554.png', 2, [215.41, 1.61]],
#  ['/content/train_i/slice13652.png', 0, [0]],
#  ['/content/train_i/slice14890.png', 2, [194.65, 8.52]],
#  ['/content/train_i/slice34053.png', 4, [9.29, 1.52, 149.57, 0.57]],
#  ['/content/train_i/slice46439.png', 2, [5.53, 209.39]],
#  ['/content/train_i/slice7358.png', 2, [207.31, 8.92]],
#  ['/content/train_i/slice45003.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_i/slice37529.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_i/slice12117.png', 1, [207.78]],
#  ['/content/train_i/slice15450.png', 0, [0]],
#  ['/content/train_i/slice33970.png', 1, [169.98]],
#  ['/content/train_i/slice1882.png', 2, [210.46, 5.48]],
#  ['/content/train_i/slice6589.png', 1, [33.77]],
#  ['/content/train_i/slice16377.png', 1, [0.45]],
#  ['/content/train_i/slice42149.png', 1, [9.26]],
#  ['/content/train_i/slice40309.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_i/slice35476.png', 2, [7.13, 250.72]],
#  ['/content/train_i/slice19034.png', 3, [1.88, 2.34, 270.21]],
#  ['/content/train_i/slice20303.png', 2, [186.43, 15.39]],
#  ['/content/train_i/slice31973.png', 2, [218.16, 1.01]],
#  ['/content/train_i/slice25013.png', 0, [0]],
#  ['/content/train_i/slice37325.png', 0, [0]],
#  ['/content/train_i/slice35335.png', 2, [1.44, 153.02]],
#  ['/content/train_i/slice33321.png', 1, [207.78]],
#  ['/content/train_i/slice21646.png', 1, [95.36]],
#  ['/content/train_i/slice41578.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_i/slice2472.png', 2, [0.0, 0.01]],
#  ['/content/train_i/slice8597.png', 0, [0]],
#  ['/content/train_i/slice43593.png', 1, [227.05]],
#  ['/content/train_i/slice39381.png', 0, [0]],
#  ['/content/train_i/slice47855.png', 0, [0]],
#  ['/content/train_i/slice34102.png', 2, [2.84, 279.11]],
#  ['/content/train_i/slice25249.png', 1, [114.8]],
#  ['/content/train_i/slice1344.png', 0, [0]],
#  ['/content/train_i/slice25129.png', 1, [221.77]],
#  ['/content/train_i/slice9356.png', 1, [197.47]],
#  ['/content/train_i/slice27840.png', 2, [2.12, 210.69]],
#  ['/content/train_i/slice15545.png', 1, [217.26]],
#  ['/content/train_i/slice16877.png', 1, [189.94]],
#  ['/content/train_i/slice38854.png', 1, [207.35]],
#  ['/content/train_i/slice48302.png', 1, [3.24]],
#  ['/content/train_i/slice19544.png', 0, [0]],
#  ['/content/train_i/slice40867.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice18928.png', 1, [187.02]],
#  ['/content/train_i/slice23885.png', 1, [84.71]],
#  ['/content/train_i/slice12182.png', 2, [0.28, 230.25]],
#  ['/content/train_i/slice3932.png', 2, [212.61, 3.06]],
#  ['/content/train_i/slice35289.png', 0, [0]],
#  ['/content/train_i/slice3177.png', 1, [87.67]],
#  ['/content/train_i/slice36865.png', 2, [4.0, 198.37]],
#  ['/content/train_i/slice20936.png', 0, [0]],
#  ['/content/train_i/slice38781.png', 2, [203.84, 6.54]],
#  ['/content/train_i/slice35976.png', 1, [1.22]],
#  ['/content/train_i/slice40317.png', 1, [0.45]],
#  ['/content/train_i/slice42903.png', 1, [212.82]],
#  ['/content/train_i/slice38758.png', 1, [169.98]],
#  ['/content/train_i/slice5870.png', 0, [0]],
#  ['/content/train_i/slice39517.png', 2, [179.64, 5.91]],
#  ['/content/train_i/slice1813.png', 1, [118.2]],
#  ['/content/train_i/slice40165.png', 1, [207.02]],
#  ['/content/train_i/slice9984.png', 1, [1.22]],
#  ['/content/train_i/slice25752.png', 1, [114.22]],
#  ['/content/train_i/slice32644.png', 1, [214.85]],
#  ['/content/train_i/slice40271.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_i/slice15015.png', 0, [0]],
#  ['/content/train_i/slice3906.png', 1, [209.22]],
#  ['/content/train_i/slice22303.png', 0, [0]],
#  ['/content/train_i/slice41585.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_i/slice9504.png', 2, [4.72, 204.21]],
#  ['/content/train_i/slice33911.png', 0, [0]],
#  ['/content/train_i/slice7939.png', 0, [0]],
#  ['/content/train_i/slice10174.png', 3, [0.73, 3.1, 239.17]],
#  ['/content/train_i/slice8691.png', 1, [211.01]],
#  ['/content/train_i/slice35502.png', 1, [172.81]],
#  ['/content/train_i/slice27152.png', 2, [201.69, 7.33]],
#  ['/content/train_i/slice44926.png', 1, [199.79]],
#  ['/content/train_i/slice29324.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_i/slice21016.png', 1, [214.85]],
#  ['/content/train_i/slice10225.png', 0, [0]],
#  ['/content/train_i/slice16955.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_i/slice35505.png', 1, [153.86]],
#  ['/content/train_i/slice1962.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_i/slice3962.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_i/slice14846.png', 2, [0.01, 211.38]],
#  ['/content/train_i/slice20911.png', 0, [0]],
#  ['/content/train_i/slice14102.png', 1, [3.24]],
#  ['/content/train_i/slice36079.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice3153.png', 0, [0]],
#  ['/content/train_i/slice7397.png', 2, [1.03, 246.09]],
#  ['/content/train_i/slice28690.png', 1, [0.44]],
#  ['/content/train_i/slice21744.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_i/slice19084.png', 2, [2.18, 181.76]],
#  ['/content/train_i/slice44981.png', 2, [198.28, 10.12]],
#  ['/content/train_i/slice22518.png', 1, [74.76]],
#  ['/content/train_i/slice42127.png', 0, [0]],
#  ['/content/train_i/slice47167.png', 0, [0]],
#  ['/content/train_i/slice3967.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_i/slice4624.png', 2, [202.71, 9.68]],
#  ['/content/train_i/slice17742.png', 2, [0.05, 3.56]],
#  ['/content/train_i/slice12068.png', 1, [78.83]],
#  ['/content/train_i/slice22366.png', 2, [205.58, 5.93]],
#  ['/content/train_i/slice12967.png', 0, [0]],
#  ['/content/train_i/slice44239.png', 1, [196.02]],
#  ['/content/train_i/slice1759.png', 0, [0]],
#  ['/content/train_i/slice29947.png', 2, [171.82, 1.59]],
#  ['/content/train_i/slice10811.png', 1, [212.75]],
#  ['/content/train_i/slice32654.png', 1, [221.64]],
#  ['/content/train_i/slice17711.png', 2, [5.53, 209.39]],
#  ['/content/train_i/slice14873.png', 2, [218.16, 1.01]],
#  ['/content/train_i/slice45737.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_i/slice33219.png', 0, [0]],
#  ['/content/train_i/slice36120.png', 1, [218.98]],
#  ['/content/train_i/slice8736.png', 2, [183.3, 6.6]],
#  ['/content/train_i/slice46987.png', 2, [198.05, 8.0]],
#  ['/content/train_i/slice49044.png', 2, [2.12, 210.69]],
#  ['/content/train_i/slice38878.png', 1, [272.64]],
#  ['/content/train_i/slice27192.png', 2, [218.66, 7.9]],
#  ['/content/train_i/slice1919.png', 1, [212.75]],
#  ['/content/train_i/slice12913.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_i/slice16241.png', 2, [218.16, 1.01]],
#  ['/content/train_i/slice47103.png', 2, [6.54, 252.78]],
#  ['/content/train_i/slice2492.png', 1, [78.83]],
#  ['/content/train_i/slice18967.png', 1, [222.0]],
#  ['/content/train_i/slice32073.png', 2, [4.86, 215.11]],
#  ['/content/train_i/slice45587.png', 1, [104.7]],
#  ['/content/train_i/slice30625.png', 2, [179.64, 5.91]],
#  ['/content/train_i/slice45031.png', 2, [0.62, 279.65]],
#  ['/content/train_i/slice31377.png', 3, [1.39, 4.72, 242.28]],
#  ['/content/train_i/slice17694.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_i/slice31277.png', 1, [217.26]],
#  ['/content/train_i/slice45061.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_i/slice12222.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_i/slice22306.png', 0, [0]],
#  ['/content/train_i/slice21093.png', 1, [273.22]],
#  ['/content/train_i/slice44851.png', 0, [0]],
#  ['/content/train_i/slice3952.png', 2, [180.17, 4.18]],
#  ['/content/train_i/slice18927.png', 1, [184.03]],
#  ['/content/train_i/slice20469.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_i/slice27105.png', 1, [23.71]],
#  ['/content/train_i/slice38256.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_i/slice41495.png', 1, [171.6]],
#  ['/content/train_i/slice16351.png', 1, [169.77]],
#  ['/content/train_i/slice42876.png', 2, [187.46, 15.31]],
#  ['/content/train_i/slice44307.png', 2, [179.64, 4.51]],
#  ['/content/train_i/slice34678.png', 2, [205.58, 5.93]],
#  ['/content/train_i/slice21673.png', 2, [189.52, 15.4]],
#  ['/content/train_i/slice30063.png', 0, [0]],
#  ['/content/train_i/slice21122.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_i/slice36651.png', 0, [0]],
#  ['/content/train_i/slice10027.png', 2, [1.44, 153.02]],
#  ['/content/train_i/slice46235.png', 1, [0.61]],
#  ['/content/train_i/slice44928.png', 2, [187.46, 15.31]],
#  ['/content/train_i/slice12242.png', 2, [3.15, 191.52]],
#  ['/content/train_i/slice48978.png', 0, [0]],
#  ['/content/train_i/slice41527.png', 1, [208.69]],
#  ['/content/train_i/slice43637.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_i/slice9493.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_i/slice5364.png', 2, [0.13, 272.04]],
#  ['/content/train_i/slice10736.png', 2, [201.69, 7.33]],
#  ['/content/train_i/slice2541.png', 1, [207.78]],
#  ['/content/train_i/slice43659.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_i/slice39497.png', 2, [218.16, 1.01]],
#  ['/content/train_i/slice42299.png', 1, [271.15]],
#  ['/content/train_i/slice2007.png', 2, [0.3, 6.3]],
#  ['/content/train_i/slice11487.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_i/slice45691.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_i/slice24498.png', 2, [1.53, 251.42]],
#  ['/content/train_i/slice9290.png', 0, [0]],
#  ['/content/train_i/slice48396.png', 2, [218.66, 7.9]],
#  ['/content/train_i/slice36073.png', 1, [221.77]],
#  ['/content/train_i/slice23050.png', 2, [205.58, 5.93]],
#  ['/content/train_i/slice8751.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_i/slice44855.png', 0, [0]],
#  ['/content/train_i/slice41433.png', 0, [0]],
#  ['/content/train_i/slice20958.png', 1, [60.17]],
#  ['/content/train_i/slice32653.png', 1, [221.77]],
#  ['/content/train_i/slice21172.png', 0, [0]],
#  ['/content/train_i/slice7461.png', 1, [153.86]],
#  ['/content/train_i/slice7997.png', 2, [195.37, 9.54]],
#  ['/content/train_i/slice12277.png', 0, [0]],
#  ['/content/train_i/slice27097.png', 1, [2.34]],
#  ['/content/train_i/slice11458.png', 2, [210.46, 5.48]],
#  ['/content/train_i/slice42863.png', 1, [171.6]],
#  ['/content/train_i/slice5924.png', 2, [1.84, 157.64]],
#  ['/content/train_i/slice46903.png', 0, [0]],
#  ['/content/train_i/slice38146.png', 2, [194.65, 8.52]],
#  ['/content/train_i/slice6047.png', 1, [271.15]],
#  ['/content/train_i/slice24602.png', 0, [0]],
#  ['/content/train_i/slice12049.png', 1, [2.34]],
#  ['/content/train_i/slice6059.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_i/slice42361.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_i/slice5299.png', 2, [213.14, 2.09]],
#  ['/content/train_i/slice1084.png', 0, [0]],
#  ['/content/train_i/slice12142.png', 2, [210.46, 5.48]],
#  ['/content/train_i/slice18895.png', 1, [19.67]],
#  ['/content/train_i/slice3233.png', 1, [217.26]],
#  ['/content/train_i/slice18203.png', 0, [0]],
#  ['/content/train_i/slice34173.png', 0, [0]],
#  ['/content/train_i/slice24440.png', 1, [224.54]],
#  ['/content/train_i/slice12200.png', 1, [277.02]],
#  ['/content/train_i/slice42206.png', 2, [0.01, 211.38]],
#  ['/content/train_i/slice7448.png', 2, [4.59, 218.29]],
#  ['/content/train_i/slice47127.png', 2, [2.57, 186.09]],
#  ['/content/train_i/slice7388.png', 2, [0.48, 198.31]],
#  ['/content/train_i/slice29943.png', 2, [179.64, 4.51]],
#  ['/content/train_i/slice4675.png', 2, [0.62, 279.65]],
#  ['/content/train_i/slice20253.png', 0, [0]],
#  ['/content/train_i/slice13629.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_i/slice42804.png', 0, [0]],
#  ['/content/train_i/slice16172.png', 1, [78.83]],
#  ['/content/train_i/slice12868.png', 2, [0.91, 241.08]],
#  ['/content/train_i/slice47612.png', 0, [0]],
#  ['/content/train_i/slice33259.png', 1, [19.67]],
#  ['/content/train_i/slice26546.png', 2, [0.28, 230.25]],
#  ['/content/train_i/slice7259.png', 0, [0]],
#  ['/content/train_i/slice6730.png', 1, [272.64]],
#  ['/content/train_i/slice14144.png', 1, [197.47]],
#  ['/content/train_i/slice47054.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_i/slice39471.png', 1, [211.01]],
#  ['/content/train_i/slice18225.png', 1, [87.67]],
#  ['/content/train_i/slice32623.png', 2, [198.05, 8.0]],
#  ['/content/train_i/slice30565.png', 2, [189.52, 15.4]],
#  ['/content/train_i/slice29286.png', 2, [1.53, 251.42]],
#  ['/content/train_i/slice9328.png', 1, [47.53]],
#  ['/content/train_i/slice34017.png', 1, [227.05]],
#  ['/content/train_i/slice20976.png', 1, [175.21]],
#  ['/content/train_i/slice29215.png', 1, [208.69]],
#  ['/content/train_i/slice32788.png', 2, [0.77, 5.62]],
#  ['/content/train_i/slice21765.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_i/slice23010.png', 1, [60.17]],
#  ['/content/train_i/slice17762.png', 0, [0]],
#  ['/content/train_i/slice3877.png', 1, [177.05]],
#  ['/content/train_i/slice8777.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_i/slice44246.png', 2, [190.5, 12.86]],
#  ['/content/train_i/slice22330.png', 1, [95.36]],
#  ['/content/train_i/slice10237.png', 0, [0]],
#  ['/content/train_i/slice21180.png', 0, [0]],
#  ...]

# %%
lst_RGB_image
# Out:
# [['/content/train_RGB_i/slice12197.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_RGB_i/slice43011.png', 3, [2.67, 0.04, 231.21]],
#  ['/content/train_RGB_i/slice13556.png', 3, [0.38, 1.6, 260.67]],
#  ['/content/train_RGB_i/slice32559.png', 1, [1.53]],
#  ['/content/train_RGB_i/slice13515.png', 2, [203.74, 9.59]],
#  ['/content/train_RGB_i/slice12915.png', 3, [2.67, 0.04, 231.21]],
#  ['/content/train_RGB_i/slice49179.png', 2, [2.57, 186.09]],
#  ['/content/train_RGB_i/slice33903.png', 0, [0]],
#  ['/content/train_RGB_i/slice12285.png', 0, [0]],
#  ['/content/train_RGB_i/slice38953.png', 0, [0]],
#  ['/content/train_RGB_i/slice45581.png', 1, [54.41]],
#  ['/content/train_RGB_i/slice14903.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_RGB_i/slice21148.png', 1, [94.92]],
#  ['/content/train_RGB_i/slice34096.png', 2, [1.77, 278.1]],
#  ['/content/train_RGB_i/slice23041.png', 2, [189.52, 15.4]],
#  ['/content/train_RGB_i/slice12044.png', 0, [0]],
#  ['/content/train_RGB_i/slice8017.png', 1, [207.02]],
#  ['/content/train_RGB_i/slice20937.png', 0, [0]],
#  ['/content/train_RGB_i/slice39600.png', 2, [4.72, 204.21]],
#  ['/content/train_RGB_i/slice12917.png', 2, [3.53, 225.61]],
#  ['/content/train_RGB_i/slice4605.png', 1, [227.05]],
#  ['/content/train_RGB_i/slice29994.png', 2, [2.83, 280.34]],
#  ['/content/train_RGB_i/slice19798.png', 1, [0.44]],
#  ['/content/train_RGB_i/slice32705.png', 2, [1.03, 246.09]],
#  ['/content/train_RGB_i/slice10894.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_RGB_i/slice17739.png', 2, [0.3, 6.3]],
#  ['/content/train_RGB_i/slice4722.png', 1, [172.81]],
#  ['/content/train_RGB_i/slice37362.png', 1, [13.52]],
#  ['/content/train_RGB_i/slice22519.png', 1, [64.66]],
#  ['/content/train_RGB_i/slice18223.png', 1, [68.09]],
#  ['/content/train_RGB_i/slice14993.png', 1, [84.71]],
#  ['/content/train_RGB_i/slice3147.png', 1, [1.53]],
#  ['/content/train_RGB_i/slice10016.png', 1, [78.83]],
#  ['/content/train_RGB_i/slice45621.png', 2, [203.84, 6.54]],
#  ['/content/train_RGB_i/slice41609.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_RGB_i/slice39438.png', 1, [146.83]],
#  ['/content/train_RGB_i/slice26482.png', 1, [207.02]],
#  ['/content/train_RGB_i/slice44278.png', 1, [224.78]],
#  ['/content/train_RGB_i/slice32097.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_RGB_i/slice14900.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_RGB_i/slice35429.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_RGB_i/slice29971.png', 2, [1.79, 259.36]],
#  ['/content/train_RGB_i/slice38268.png', 0, [0]],
#  ['/content/train_RGB_i/slice34097.png', 2, [2.12, 277.47]],
#  ['/content/train_RGB_i/slice17005.png', 2, [5.56, 257.6]],
#  ['/content/train_RGB_i/slice25781.png', 2, [195.37, 9.54]],
#  ['/content/train_RGB_i/slice10125.png', 2, [0.12, 201.14]],
#  ['/content/train_RGB_i/slice34024.png', 2, [219.34, 0.48]],
#  ['/content/train_RGB_i/slice27899.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_RGB_i/slice13427.png', 1, [28.46]],
#  ['/content/train_RGB_i/slice662.png', 0, [0]],
#  ['/content/train_RGB_i/slice7269.png', 1, [23.71]],
#  ['/content/train_RGB_i/slice16184.png', 2, [1.84, 157.64]],
#  ['/content/train_RGB_i/slice30635.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_RGB_i/slice11371.png', 1, [19.67]],
#  ['/content/train_RGB_i/slice1251.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_RGB_i/slice22517.png', 1, [84.71]],
#  ['/content/train_RGB_i/slice27819.png', 1, [184.03]],
#  ['/content/train_RGB_i/slice31213.png', 1, [33.77]],
#  ['/content/train_RGB_i/slice1147.png', 1, [196.02]],
#  ['/content/train_RGB_i/slice31251.png', 2, [191.45, 11.15]],
#  ['/content/train_RGB_i/slice17584.png', 1, [210.25]],
#  ['/content/train_RGB_i/slice44350.png', 1, [272.64]],
#  ['/content/train_RGB_i/slice33403.png', 2, [0.62, 279.65]],
#  ['/content/train_RGB_i/slice2465.png', 1, [0.19]],
#  ['/content/train_RGB_i/slice20311.png', 2, [198.05, 8.0]],
#  ['/content/train_RGB_i/slice3999.png', 2, [1.15, 272.53]],
#  ['/content/train_RGB_i/slice14885.png', 2, [198.28, 10.12]],
#  ['/content/train_RGB_i/slice7962.png', 1, [60.17]],
#  ['/content/train_RGB_i/slice32785.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_RGB_i/slice14894.png', 2, [179.16, 5.34]],
#  ['/content/train_RGB_i/slice31349.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_RGB_i/slice1217.png', 2, [175.59, 3.52]],
#  ['/content/train_RGB_i/slice38780.png', 2, [201.69, 7.33]],
#  ['/content/train_RGB_i/slice2479.png', 1, [19.67]],
#  ['/content/train_RGB_i/slice23161.png', 2, [5.56, 257.6]],
#  ['/content/train_RGB_i/slice18933.png', 1, [199.23]],
#  ['/content/train_RGB_i/slice32119.png', 0, [0]],
#  ['/content/train_RGB_i/slice36771.png', 2, [203.74, 9.59]],
#  ['/content/train_RGB_i/slice8632.png', 1, [6.91]],
#  ['/content/train_RGB_i/slice36129.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_RGB_i/slice30499.png', 0, [0]],
#  ['/content/train_RGB_i/slice17502.png', 0, [0]],
#  ['/content/train_RGB_i/slice1846.png', 2, [205.58, 5.93]],
#  ['/content/train_RGB_i/slice22465.png', 2, [0.56, 276.34]],
#  ['/content/train_RGB_i/slice40840.png', 1, [210.25]],
#  ['/content/train_RGB_i/slice535.png', 2, [171.82, 1.59]],
#  ['/content/train_RGB_i/slice12717.png', 0, [0]],
#  ['/content/train_RGB_i/slice14070.png', 0, [0]],
#  ['/content/train_RGB_i/slice30666.png', 2, [0.75, 277.48]],
#  ['/content/train_RGB_i/slice17657.png', 2, [1.03, 246.09]],
#  ['/content/train_RGB_i/slice8163.png', 2, [0.3, 6.3]],
#  ['/content/train_RGB_i/slice25058.png', 1, [38.63]],
#  ['/content/train_RGB_i/slice19692.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_RGB_i/slice44396.png', 1, [166.78]],
#  ['/content/train_RGB_i/slice20327.png', 1, [206.35]],
#  ['/content/train_RGB_i/slice6074.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_RGB_i/slice4542.png', 1, [60.17]],
#  ['/content/train_RGB_i/slice2463.png', 1, [1.53]],
#  ['/content/train_RGB_i/slice23114.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_RGB_i/slice27837.png', 2, [203.84, 6.54]],
#  ['/content/train_RGB_i/slice9987.png', 1, [1.53]],
#  ['/content/train_RGB_i/slice39560.png', 1, [277.02]],
#  ['/content/train_RGB_i/slice35360.png', 2, [201.69, 7.33]],
#  ['/content/train_RGB_i/slice2585.png', 2, [175.59, 3.52]],
#  ['/content/train_RGB_i/slice19637.png', 1, [209.4]],
#  ['/content/train_RGB_i/slice9453.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_RGB_i/slice20960.png', 1, [78.83]],
#  ['/content/train_RGB_i/slice19080.png', 2, [4.72, 204.21]],
#  ['/content/train_RGB_i/slice7230.png', 0, [0]],
#  ['/content/train_RGB_i/slice47611.png', 0, [0]],
#  ['/content/train_RGB_i/slice5987.png', 2, [212.87, 6.28]],
#  ['/content/train_RGB_i/slice4639.png', 2, [171.82, 1.59]],
#  ['/content/train_RGB_i/slice40164.png', 1, [205.71]],
#  ['/content/train_RGB_i/slice40951.png', 3, [1.48, 7.22, 242.87]],
#  ['/content/train_RGB_i/slice12750.png', 1, [60.17]],
#  ['/content/train_RGB_i/slice27155.png', 2, [207.87, 3.7]],
#  ['/content/train_RGB_i/slice12747.png', 1, [42.84]],
#  ['/content/train_RGB_i/slice15529.png', 2, [1.1, 213.14]],
#  ['/content/train_RGB_i/slice16905.png', 1, [207.78]],
#  ['/content/train_RGB_i/slice21660.png', 1, [175.21]],
#  ['/content/train_RGB_i/slice16988.png', 1, [277.02]],
#  ['/content/train_RGB_i/slice25722.png', 0, [0]],
#  ['/content/train_RGB_i/slice36042.png', 2, [196.65, 8.59]],
#  ['/content/train_RGB_i/slice36838.png', 2, [2.84, 279.11]],
#  ['/content/train_RGB_i/slice10112.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_RGB_i/slice44947.png', 1, [208.69]],
#  ['/content/train_RGB_i/slice23092.png', 2, [202.71, 9.68]],
#  ['/content/train_RGB_i/slice37344.png', 1, [1.22]],
#  ['/content/train_RGB_i/slice5920.png', 1, [136.51]],
#  ['/content/train_RGB_i/slice20346.png', 2, [215.41, 1.61]],
#  ['/content/train_RGB_i/slice7451.png', 2, [5.53, 209.39]],
#  ['/content/train_RGB_i/slice31416.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_RGB_i/slice14333.png', 0, [0]],
#  ['/content/train_RGB_i/slice1816.png', 1, [136.51]],
#  ['/content/train_RGB_i/slice12930.png', 1, [172.81]],
#  ['/content/train_RGB_i/slice22487.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_RGB_i/slice21609.png', 0, [0]],
#  ['/content/train_RGB_i/slice15586.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_RGB_i/slice6024.png', 1, [218.98]],
#  ['/content/train_RGB_i/slice31284.png', 1, [222.54]],
#  ['/content/train_RGB_i/slice12238.png', 2, [5.3, 212.21]],
#  ['/content/train_RGB_i/slice42964.png', 2, [0.91, 241.08]],
#  ['/content/train_RGB_i/slice46904.png', 0, [0]],
#  ['/content/train_RGB_i/slice39515.png', 2, [188.25, 7.57]],
#  ['/content/train_RGB_i/slice47753.png', 2, [1.03, 246.09]],
#  ['/content/train_RGB_i/slice33470.png', 2, [0.22, 6.5]],
#  ['/content/train_RGB_i/slice43027.png', 1, [169.77]],
#  ['/content/train_RGB_i/slice4524.png', 2, [0.0, 0.01]],
#  ['/content/train_RGB_i/slice38041.png', 1, [2.34]],
#  ['/content/train_RGB_i/slice5398.png', 2, [5.3, 212.21]],
#  ['/content/train_RGB_i/slice23029.png', 1, [177.05]],
#  ['/content/train_RGB_i/slice8177.png', 0, [0]],
#  ['/content/train_RGB_i/slice1832.png', 1, [197.47]],
#  ['/content/train_RGB_i/slice5859.png', 0, [0]],
#  ['/content/train_RGB_i/slice12037.png', 1, [1.24]],
#  ['/content/train_RGB_i/slice18307.png', 2, [196.96, 11.58]],
#  ['/content/train_RGB_i/slice29864.png', 2, [1.84, 157.64]],
#  ['/content/train_RGB_i/slice15540.png', 1, [205.71]],
#  ['/content/train_RGB_i/slice17555.png', 1, [171.6]],
#  ['/content/train_RGB_i/slice14316.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_RGB_i/slice20328.png', 1, [205.71]],
#  ['/content/train_RGB_i/slice33240.png', 1, [1.22]],
#  ['/content/train_RGB_i/slice37537.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_RGB_i/slice11426.png', 2, [0.01, 211.38]],
#  ['/content/train_RGB_i/slice33928.png', 1, [0.5]],
#  ['/content/train_RGB_i/slice1935.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_RGB_i/slice35399.png', 2, [212.87, 6.28]],
#  ['/content/train_RGB_i/slice8779.png', 2, [0.62, 279.65]],
#  ['/content/train_RGB_i/slice28678.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_RGB_i/slice4012.png', 2, [7.13, 250.72]],
#  ['/content/train_RGB_i/slice39435.png', 1, [130.7]],
#  ['/content/train_RGB_i/slice29141.png', 1, [0.19]],
#  ['/content/train_RGB_i/slice3327.png', 2, [6.54, 252.78]],
#  ['/content/train_RGB_i/slice43658.png', 3, [1.88, 2.34, 270.21]],
#  ['/content/train_RGB_i/slice19719.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_RGB_i/slice11391.png', 1, [130.7]],
#  ['/content/train_RGB_i/slice44937.png', 2, [203.84, 6.54]],
#  ['/content/train_RGB_i/slice18886.png', 0, [0]],
#  ['/content/train_RGB_i/slice19670.png', 2, [207.31, 8.92]],
#  ['/content/train_RGB_i/slice23156.png', 2, [3.94, 283.63]],
#  ['/content/train_RGB_i/slice12772.png', 1, [187.02]],
#  ['/content/train_RGB_i/slice9491.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_RGB_i/slice16271.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_RGB_i/slice34113.png', 3, [1.39, 4.72, 242.28]],
#  ['/content/train_RGB_i/slice31289.png', 2, [218.16, 1.01]],
#  ['/content/train_RGB_i/slice29342.png', 2, [3.15, 191.52]],
#  ['/content/train_RGB_i/slice37442.png', 1, [221.64]],
#  ['/content/train_RGB_i/slice32051.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_RGB_i/slice36193.png', 1, [114.8]],
#  ['/content/train_RGB_i/slice47732.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_RGB_i/slice38826.png', 2, [197.55, 11.07]],
#  ['/content/train_RGB_i/slice1303.png', 1, [169.77]],
#  ['/content/train_RGB_i/slice46287.png', 1, [184.03]],
#  ['/content/train_RGB_i/slice48347.png', 2, [186.43, 15.39]],
#  ['/content/train_RGB_i/slice588.png', 2, [4.91, 260.75]],
#  ['/content/train_RGB_i/slice23062.png', 1, [207.02]],
#  ['/content/train_RGB_i/slice12214.png', 2, [2.84, 279.11]],
#  ['/content/train_RGB_i/slice43703.png', 2, [5.53, 209.39]],
#  ['/content/train_RGB_i/slice9464.png', 1, [277.02]],
#  ['/content/train_RGB_i/slice1292.png', 2, [4.59, 218.29]],
#  ['/content/train_RGB_i/slice25283.png', 0, [0]],
#  ['/content/train_RGB_i/slice35387.png', 1, [224.58]],
#  ['/content/train_RGB_i/slice19605.png', 2, [2.59, 164.07]],
#  ['/content/train_RGB_i/slice7336.png', 1, [214.85]],
#  ['/content/train_RGB_i/slice12861.png', 2, [0.12, 201.14]],
#  ['/content/train_RGB_i/slice31427.png', 0, [0]],
#  ['/content/train_RGB_i/slice42970.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_RGB_i/slice3968.png', 2, [0.48, 198.31]],
#  ['/content/train_RGB_i/slice39455.png', 2, [186.43, 15.39]],
#  ['/content/train_RGB_i/slice3318.png', 2, [2.83, 280.34]],
#  ['/content/train_RGB_i/slice44890.png', 1, [26.05]],
#  ['/content/train_RGB_i/slice5867.png', 0, [0]],
#  ['/content/train_RGB_i/slice44204.png', 1, [21.64]],
#  ['/content/train_RGB_i/slice6134.png', 0, [0]],
#  ['/content/train_RGB_i/slice18266.png', 2, [0.01, 211.38]],
#  ['/content/train_RGB_i/slice20391.png', 2, [0.44, 233.44]],
#  ['/content/train_RGB_i/slice40772.png', 0, [0]],
#  ['/content/train_RGB_i/slice48332.png', 2, [1.84, 157.64]],
#  ['/content/train_RGB_i/slice34083.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_RGB_i/slice4726.png', 1, [142.95]],
#  ['/content/train_RGB_i/slice21134.png', 2, [3.15, 191.52]],
#  ['/content/train_RGB_i/slice48957.png', 0, [0]],
#  ['/content/train_RGB_i/slice41484.png', 1, [114.22]],
#  ['/content/train_RGB_i/slice23076.png', 1, [222.54]],
#  ['/content/train_RGB_i/slice16134.png', 0, [0]],
#  ['/content/train_RGB_i/slice19800.png', 0, [0]],
#  ['/content/train_RGB_i/slice36748.png', 1, [214.85]],
#  ['/content/train_RGB_i/slice37448.png', 2, [212.61, 3.06]],
#  ['/content/train_RGB_i/slice48484.png', 2, [3.12, 227.94]],
#  ['/content/train_RGB_i/slice34596.png', 0, [0]],
#  ['/content/train_RGB_i/slice39479.png', 1, [206.35]],
#  ['/content/train_RGB_i/slice20493.png', 0, [0]],
#  ['/content/train_RGB_i/slice43627.png', 2, [171.82, 1.59]],
#  ['/content/train_RGB_i/slice36790.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_RGB_i/slice6101.png', 1, [84.71]],
#  ['/content/train_RGB_i/slice45627.png', 1, [211.01]],
#  ['/content/train_RGB_i/slice14233.png', 1, [226.13]],
#  ['/content/train_RGB_i/slice19038.png', 2, [0.75, 277.48]],
#  ['/content/train_RGB_i/slice40943.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_RGB_i/slice21633.png', 1, [23.71]],
#  ['/content/train_RGB_i/slice9327.png', 1, [42.84]],
#  ['/content/train_RGB_i/slice47596.png', 0, [0]],
#  ['/content/train_RGB_i/slice40123.png', 2, [1.44, 153.02]],
#  ['/content/train_RGB_i/slice40313.png', 2, [0.09, 5.38]],
#  ['/content/train_RGB_i/slice35365.png', 2, [1.1, 213.14]],
#  ['/content/train_RGB_i/slice22970.png', 0, [0]],
#  ['/content/train_RGB_i/slice8767.png', 2, [1.79, 259.36]],
#  ['/content/train_RGB_i/slice2501.png', 1, [141.86]],
#  ['/content/train_RGB_i/slice26415.png', 1, [4.52]],
#  ['/content/train_RGB_i/slice23705.png', 1, [141.86]],
#  ['/content/train_RGB_i/slice600.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_RGB_i/slice37511.png', 1, [271.15]],
#  ['/content/train_RGB_i/slice14275.png', 3, [1.48, 7.22, 242.87]],
#  ['/content/train_RGB_i/slice18318.png', 2, [181.76, 3.4]],
#  ['/content/train_RGB_i/slice42885.png', 2, [203.84, 6.54]],
#  ['/content/train_RGB_i/slice9454.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_RGB_i/slice47657.png', 1, [189.94]],
#  ['/content/train_RGB_i/slice28623.png', 2, [1.15, 272.53]],
#  ['/content/train_RGB_i/slice2532.png', 2, [2.12, 210.69]],
#  ['/content/train_RGB_i/slice21616.png', 1, [0.5]],
#  ['/content/train_RGB_i/slice23712.png', 1, [175.21]],
#  ['/content/train_RGB_i/slice5357.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_RGB_i/slice13473.png', 2, [203.84, 6.54]],
#  ['/content/train_RGB_i/slice26484.png', 1, [205.71]],
#  ['/content/train_RGB_i/slice37416.png', 2, [2.12, 210.69]],
#  ['/content/train_RGB_i/slice29228.png', 1, [224.54]],
#  ['/content/train_RGB_i/slice8834.png', 1, [107.99]],
#  ['/content/train_RGB_i/slice47771.png', 1, [271.15]],
#  ['/content/train_RGB_i/slice43753.png', 0, [0]],
#  ['/content/train_RGB_i/slice12038.png', 1, [1.35]],
#  ['/content/train_RGB_i/slice47031.png', 2, [203.74, 9.59]],
#  ['/content/train_RGB_i/slice8715.png', 1, [220.08]],
#  ['/content/train_RGB_i/slice10145.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_RGB_i/slice29167.png', 1, [68.09]],
#  ['/content/train_RGB_i/slice8098.png', 1, [272.64]],
#  ['/content/train_RGB_i/slice3226.png', 1, [207.02]],
#  ['/content/train_RGB_i/slice47705.png', 2, [218.16, 1.01]],
#  ['/content/train_RGB_i/slice2011.png', 2, [0.2, 1.98]],
#  ['/content/train_RGB_i/slice3977.png', 2, [1.03, 246.09]],
#  ['/content/train_RGB_i/slice1911.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_RGB_i/slice24553.png', 2, [4.0, 198.37]],
#  ['/content/train_RGB_i/slice2508.png', 1, [175.21]],
#  ['/content/train_RGB_i/slice47659.png', 1, [196.02]],
#  ['/content/train_RGB_i/slice22985.png', 1, [0.19]],
#  ['/content/train_RGB_i/slice40972.png', 2, [2.18, 181.76]],
#  ['/content/train_RGB_i/slice31308.png', 2, [183.3, 6.6]],
#  ['/content/train_RGB_i/slice40942.png', 2, [2.84, 279.11]],
#  ['/content/train_RGB_i/slice26537.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_RGB_i/slice5905.png', 1, [33.77]],
#  ['/content/train_RGB_i/slice28652.png', 2, [4.59, 218.29]],
#  ['/content/train_RGB_i/slice9404.png', 2, [212.61, 3.06]],
#  ['/content/train_RGB_i/slice4500.png', 0, [0]],
#  ['/content/train_RGB_i/slice12800.png', 1, [208.25]],
#  ['/content/train_RGB_i/slice48454.png', 1, [272.64]],
#  ['/content/train_RGB_i/slice12825.png', 2, [210.36, 4.03]],
#  ['/content/train_RGB_i/slice38847.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_RGB_i/slice44998.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_RGB_i/slice16318.png', 2, [2.84, 279.11]],
#  ['/content/train_RGB_i/slice18917.png', 1, [141.86]],
#  ['/content/train_RGB_i/slice2526.png', 2, [196.65, 8.59]],
#  ['/content/train_RGB_i/slice25837.png', 2, [179.64, 5.91]],
#  ['/content/train_RGB_i/slice40102.png', 1, [26.05]],
#  ['/content/train_RGB_i/slice10878.png', 1, [172.81]],
#  ['/content/train_RGB_i/slice46384.png', 2, [0.91, 241.08]],
#  ['/content/train_RGB_i/slice10692.png', 1, [31.83]],
#  ['/content/train_RGB_i/slice24481.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_RGB_i/slice8773.png', 3, [2.22, 2.54, 269.77]],
#  ['/content/train_RGB_i/slice47619.png', 1, [4.52]],
#  ['/content/train_RGB_i/slice38769.png', 1, [199.23]],
#  ['/content/train_RGB_i/slice42150.png', 1, [13.52]],
#  ['/content/train_RGB_i/slice17735.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_RGB_i/slice37472.png', 4, [10.82, 1.35, 147.8, 0.73]],
#  ['/content/train_RGB_i/slice24459.png', 2, [203.74, 9.59]],
#  ['/content/train_RGB_i/slice33351.png', 2, [203.74, 9.59]],
#  ['/content/train_RGB_i/slice1805.png', 1, [54.41]],
#  ['/content/train_RGB_i/slice11473.png', 2, [179.64, 5.91]],
#  ['/content/train_RGB_i/slice26646.png', 0, [0]],
#  ['/content/train_RGB_i/slice44358.png', 2, [2.83, 280.34]],
#  ['/content/train_RGB_i/slice13551.png', 2, [0.44, 233.44]],
#  ['/content/train_RGB_i/slice18268.png', 1, [210.25]],
#  ['/content/train_RGB_i/slice2443.png', 0, [0]],
#  ['/content/train_RGB_i/slice31364.png', 2, [3.94, 283.63]],
#  ['/content/train_RGB_i/slice17648.png', 2, [0.48, 198.31]],
#  ['/content/train_RGB_i/slice1216.png', 2, [180.17, 4.18]],
#  ['/content/train_RGB_i/slice25895.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_RGB_i/slice1236.png', 1, [218.98]],
#  ['/content/train_RGB_i/slice8618.png', 1, [1.35]],
#  ['/content/train_RGB_i/slice32586.png', 1, [60.17]],
#  ['/content/train_RGB_i/slice23195.png', 1, [132.07]],
#  ['/content/train_RGB_i/slice16290.png', 2, [1.53, 251.42]],
#  ['/content/train_RGB_i/slice4635.png', 2, [179.64, 4.51]],
#  ['/content/train_RGB_i/slice18985.png', 2, [213.66, 8.26]],
#  ['/content/train_RGB_i/slice9529.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_RGB_i/slice8097.png', 1, [273.22]],
#  ['/content/train_RGB_i/slice39482.png', 1, [209.68]],
#  ['/content/train_RGB_i/slice40098.png', 1, [13.52]],
#  ['/content/train_RGB_i/slice33261.png', 1, [23.71]],
#  ['/content/train_RGB_i/slice45609.png', 1, [199.23]],
#  ['/content/train_RGB_i/slice7360.png', 2, [202.71, 9.68]],
#  ['/content/train_RGB_i/slice46954.png', 1, [95.36]],
#  ['/content/train_RGB_i/slice41640.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_RGB_i/slice29157.png', 1, [23.71]],
#  ['/content/train_RGB_i/slice11461.png', 2, [213.66, 8.26]],
#  ['/content/train_RGB_i/slice24594.png', 0, [0]],
#  ['/content/train_RGB_i/slice10118.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_RGB_i/slice13508.png', 2, [212.61, 3.06]],
#  ['/content/train_RGB_i/slice38731.png', 1, [19.67]],
#  ['/content/train_RGB_i/slice9351.png', 1, [184.03]],
#  ['/content/train_RGB_i/slice4603.png', 1, [222.0]],
#  ['/content/train_RGB_i/slice25091.png', 2, [186.43, 15.39]],
#  ['/content/train_RGB_i/slice31248.png', 2, [187.46, 15.31]],
#  ['/content/train_RGB_i/slice19625.png', 2, [195.37, 9.54]],
#  ['/content/train_RGB_i/slice15595.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_RGB_i/slice40067.png', 0, [0]],
#  ['/content/train_RGB_i/slice12104.png', 2, [201.69, 7.33]],
#  ['/content/train_RGB_i/slice44351.png', 1, [271.15]],
#  ['/content/train_RGB_i/slice33934.png', 0, [0]],
#  ['/content/train_RGB_i/slice45572.png', 1, [21.64]],
#  ['/content/train_RGB_i/slice34805.png', 2, [3.53, 225.61]],
#  ['/content/train_RGB_i/slice11488.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_RGB_i/slice27933.png', 1, [273.22]],
#  ['/content/train_RGB_i/slice29210.png', 2, [0.01, 211.38]],
#  ['/content/train_RGB_i/slice36130.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_RGB_i/slice4713.png', 2, [4.86, 215.11]],
#  ['/content/train_RGB_i/slice21754.png', 1, [207.35]],
#  ['/content/train_RGB_i/slice38206.png', 2, [2.84, 279.11]],
#  ['/content/train_RGB_i/slice30685.png', 2, [5.56, 257.6]],
#  ['/content/train_RGB_i/slice27104.png', 1, [21.64]],
#  ['/content/train_RGB_i/slice40888.png', 2, [180.17, 4.18]],
#  ['/content/train_RGB_i/slice19803.png', 0, [0]],
#  ['/content/train_RGB_i/slice42134.png', 1, [1.35]],
#  ['/content/train_RGB_i/slice25924.png', 2, [2.18, 181.76]],
#  ['/content/train_RGB_i/slice47677.png', 2, [1.1, 213.14]],
#  ['/content/train_RGB_i/slice6724.png', 3, [1.44, 1.36, 276.57]],
#  ['/content/train_RGB_i/slice48349.png', 2, [189.52, 15.4]],
#  ['/content/train_RGB_i/slice38893.png', 2, [5.56, 257.6]],
#  ['/content/train_RGB_i/slice30657.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_RGB_i/slice43692.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_RGB_i/slice26553.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_RGB_i/slice22305.png', 0, [0]],
#  ['/content/train_RGB_i/slice5320.png', 2, [180.17, 4.18]],
#  ['/content/train_RGB_i/slice26462.png', 2, [190.5, 12.86]],
#  ['/content/train_RGB_i/slice41695.png', 0, [0]],
#  ['/content/train_RGB_i/slice1784.png', 0, [0]],
#  ['/content/train_RGB_i/slice24549.png', 2, [4.86, 215.11]],
#  ['/content/train_RGB_i/slice14928.png', 4, [0.83, 1.83, 0.78, 266.04]],
#  ['/content/train_RGB_i/slice43032.png', 1, [122.05]],
#  ['/content/train_RGB_i/slice3866.png', 1, [124.18]],
#  ['/content/train_RGB_i/slice19052.png', 2, [3.94, 283.63]],
#  ['/content/train_RGB_i/slice49080.png', 2, [218.66, 7.9]],
#  ['/content/train_RGB_i/slice12812.png', 1, [224.54]],
#  ['/content/train_RGB_i/slice36097.png', 2, [179.64, 5.91]],
#  ['/content/train_RGB_i/slice9403.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice21662.png', 1, [180.19]],
#  ['/content/train_RGB_i/slice46296.png', 2, [187.46, 15.31]],
#  ['/content/train_RGB_i/slice45732.png', 2, [4.91, 260.75]],
#  ['/content/train_RGB_i/slice36815.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_RGB_i/slice36019.png', 2, [1.44, 153.02]],
#  ['/content/train_RGB_i/slice36903.png', 0, [0]],
#  ['/content/train_RGB_i/slice30554.png', 1, [180.19]],
#  ['/content/train_RGB_i/slice14123.png', 1, [104.7]],
#  ['/content/train_RGB_i/slice6673.png', 2, [213.66, 8.26]],
#  ['/content/train_RGB_i/slice49114.png', 1, [207.35]],
#  ['/content/train_RGB_i/slice2470.png', 0, [0]],
#  ['/content/train_RGB_i/slice5384.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_RGB_i/slice25855.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_RGB_i/slice17700.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_RGB_i/slice2461.png', 1, [1.24]],
#  ['/content/train_RGB_i/slice43671.png', 2, [1.15, 272.53]],
#  ['/content/train_RGB_i/slice40808.png', 2, [1.84, 157.64]],
#  ['/content/train_RGB_i/slice25866.png', 2, [1.53, 251.42]],
#  ['/content/train_RGB_i/slice12802.png', 1, [207.02]],
#  ['/content/train_RGB_i/slice8044.png', 2, [202.71, 9.68]],
#  ['/content/train_RGB_i/slice3840.png', 2, [0.0, 0.01]],
#  ['/content/train_RGB_i/slice5869.png', 0, [0]],
#  ['/content/train_RGB_i/slice18934.png', 1, [199.79]],
#  ['/content/train_RGB_i/slice49220.png', 0, [0]],
#  ['/content/train_RGB_i/slice35350.png', 1, [199.79]],
#  ['/content/train_RGB_i/slice27296.png', 1, [166.78]],
#  ['/content/train_RGB_i/slice23805.png', 2, [0.12, 201.14]],
#  ['/content/train_RGB_i/slice28551.png', 1, [220.08]],
#  ['/content/train_RGB_i/slice40074.png', 0, [0]],
#  ['/content/train_RGB_i/slice21090.png', 2, [0.75, 277.48]],
#  ['/content/train_RGB_i/slice6561.png', 0, [0]],
#  ['/content/train_RGB_i/slice10679.png', 0, [0]],
#  ['/content/train_RGB_i/slice29387.png', 0, [0]],
#  ['/content/train_RGB_i/slice20443.png', 2, [4.18, 220.12]],
#  ['/content/train_RGB_i/slice46246.png', 0, [0]],
#  ['/content/train_RGB_i/slice13521.png', 2, [194.95, 9.05]],
#  ['/content/train_RGB_i/slice40777.png', 1, [2.34]],
#  ['/content/train_RGB_i/slice47141.png', 1, [84.71]],
#  ['/content/train_RGB_i/slice2489.png', 1, [54.41]],
#  ['/content/train_RGB_i/slice24361.png', 1, [2.34]],
#  ['/content/train_RGB_i/slice11468.png', 2, [194.6, 10.42]],
#  ['/content/train_RGB_i/slice29283.png', 2, [0.44, 233.44]],
#  ['/content/train_RGB_i/slice25044.png', 2, [0.0, 0.01]],
#  ['/content/train_RGB_i/slice30747.png', 0, [0]],
#  ['/content/train_RGB_i/slice38881.png', 2, [0.56, 276.34]],
#  ['/content/train_RGB_i/slice31388.png', 2, [4.59, 218.29]],
#  ['/content/train_RGB_i/slice25727.png', 0, [0]],
#  ['/content/train_RGB_i/slice42959.png', 1, [212.75]],
#  ['/content/train_RGB_i/slice13586.png', 2, [5.71, 253.95]],
#  ['/content/train_RGB_i/slice10738.png', 2, [205.58, 5.93]],
#  ['/content/train_RGB_i/slice42795.png', 0, [0]],
#  ['/content/train_RGB_i/slice15596.png', 2, [0.48, 198.31]],
#  ['/content/train_RGB_i/slice21840.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_RGB_i/slice10199.png', 1, [132.07]],
#  ['/content/train_RGB_i/slice18263.png', 2, [207.87, 3.7]],
#  ['/content/train_RGB_i/slice29877.png', 1, [199.23]],
#  ['/content/train_RGB_i/slice27829.png', 2, [189.52, 15.4]],
#  ['/content/train_RGB_i/slice22289.png', 0, [0]],
#  ['/content/train_RGB_i/slice5868.png', 0, [0]],
#  ['/content/train_RGB_i/slice21705.png', 1, [227.05]],
#  ['/content/train_RGB_i/slice15514.png', 1, [199.79]],
#  ['/content/train_RGB_i/slice35485.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_RGB_i/slice35381.png', 1, [217.26]],
#  ['/content/train_RGB_i/slice24516.png', 2, [0.13, 272.04]],
#  ['/content/train_RGB_i/slice2639.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_RGB_i/slice44936.png', 2, [201.69, 7.33]],
#  ['/content/train_RGB_i/slice34653.png', 2, [2.59, 164.07]],
#  ['/content/train_RGB_i/slice34775.png', 1, [271.15]],
#  ['/content/train_RGB_i/slice44184.png', 1, [1.22]],
#  ['/content/train_RGB_i/slice10164.png', 2, [4.91, 260.75]],
#  ['/content/train_RGB_i/slice20413.png', 2, [0.56, 276.34]],
#  ['/content/train_RGB_i/slice32002.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_RGB_i/slice29170.png', 1, [95.36]],
#  ['/content/train_RGB_i/slice10116.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_RGB_i/slice37452.png', 2, [218.66, 7.9]],
#  ['/content/train_RGB_i/slice17028.png', 2, [4.72, 204.21]],
#  ['/content/train_RGB_i/slice10216.png', 2, [0.77, 5.62]],
#  ['/content/train_RGB_i/slice29239.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice48451.png', 2, [0.62, 279.65]],
#  ['/content/train_RGB_i/slice542.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_RGB_i/slice48280.png', 0, [0]],
#  ['/content/train_RGB_i/slice44393.png', 1, [177.89]],
#  ['/content/train_RGB_i/slice17708.png', 2, [4.59, 218.29]],
#  ['/content/train_RGB_i/slice33332.png', 1, [224.54]],
#  ['/content/train_RGB_i/slice22967.png', 0, [0]],
#  ['/content/train_RGB_i/slice19807.png', 0, [0]],
#  ['/content/train_RGB_i/slice44887.png', 1, [19.67]],
#  ['/content/train_RGB_i/slice19784.png', 2, [4.79, 41.22]],
#  ['/content/train_RGB_i/slice47052.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_RGB_i/slice14976.png', 2, [4.72, 204.21]],
#  ['/content/train_RGB_i/slice29980.png', 3, [1.44, 1.36, 276.57]],
#  ['/content/train_RGB_i/slice3253.png', 2, [213.66, 8.26]],
#  ['/content/train_RGB_i/slice21033.png', 2, [210.36, 4.03]],
#  ['/content/train_RGB_i/slice38757.png', 2, [2.59, 164.07]],
#  ['/content/train_RGB_i/slice8118.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_RGB_i/slice20380.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_RGB_i/slice27094.png', 0, [0]],
#  ['/content/train_RGB_i/slice42280.png', 2, [0.91, 241.08]],
#  ['/content/train_RGB_i/slice20429.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_RGB_i/slice9538.png', 1, [0.44]],
#  ['/content/train_RGB_i/slice39612.png', 1, [122.05]],
#  ['/content/train_RGB_i/slice31436.png', 0, [0]],
#  ['/content/train_RGB_i/slice29929.png', 2, [213.66, 8.26]],
#  ['/content/train_RGB_i/slice40312.png', 2, [0.77, 5.62]],
#  ['/content/train_RGB_i/slice26467.png', 2, [198.05, 8.0]],
#  ['/content/train_RGB_i/slice6061.png', 2, [5.56, 257.6]],
#  ['/content/train_RGB_i/slice7244.png', 0, [0]],
#  ['/content/train_RGB_i/slice26472.png', 2, [2.12, 210.69]],
#  ['/content/train_RGB_i/slice38246.png', 1, [107.99]],
#  ['/content/train_RGB_i/slice42355.png', 1, [64.66]],
#  ['/content/train_RGB_i/slice46354.png', 2, [194.65, 8.52]],
#  ['/content/train_RGB_i/slice47056.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_RGB_i/slice47789.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_RGB_i/slice22982.png', 1, [1.35]],
#  ['/content/train_RGB_i/slice47146.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_RGB_i/slice31933.png', 2, [189.52, 15.4]],
#  ['/content/train_RGB_i/slice34104.png', 2, [4.91, 260.75]],
#  ['/content/train_RGB_i/slice522.png', 2, [197.55, 11.07]],
#  ['/content/train_RGB_i/slice48442.png', 4, [0.69, 1.46, 0.85, 266.66]],
#  ['/content/train_RGB_i/slice44921.png', 1, [189.94]],
#  ['/content/train_RGB_i/slice21176.png', 0, [0]],
#  ['/content/train_RGB_i/slice33247.png', 0, [0]],
#  ['/content/train_RGB_i/slice46395.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_RGB_i/slice20324.png', 1, [208.25]],
#  ['/content/train_RGB_i/slice45798.png', 0, [0]],
#  ['/content/train_RGB_i/slice14145.png', 1, [199.23]],
#  ['/content/train_RGB_i/slice38848.png', 3, [1.47, 0.22, 186.41]],
#  ['/content/train_RGB_i/slice19603.png', 2, [1.44, 153.02]],
#  ['/content/train_RGB_i/slice12724.png', 1, [0.5]],
#  ['/content/train_RGB_i/slice7937.png', 1, [0.19]],
#  ['/content/train_RGB_i/slice43673.png', 2, [2.12, 277.47]],
#  ['/content/train_RGB_i/slice21079.png', 2, [1.79, 259.36]],
#  ['/content/train_RGB_i/slice12787.png', 2, [198.05, 8.0]],
#  ['/content/train_RGB_i/slice42379.png', 0, [0]],
#  ['/content/train_RGB_i/slice19014.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_RGB_i/slice34706.png', 1, [221.64]],
#  ['/content/train_RGB_i/slice31317.png', 4, [9.29, 1.52, 149.57, 0.57]],
#  ['/content/train_RGB_i/slice24576.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_RGB_i/slice8794.png', 2, [2.84, 279.11]],
#  ['/content/train_RGB_i/slice44404.png', 1, [94.92]],
#  ['/content/train_RGB_i/slice26550.png', 2, [1.53, 251.42]],
#  ['/content/train_RGB_i/slice43694.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_RGB_i/slice47774.png', 2, [1.15, 275.35]],
#  ['/content/train_RGB_i/slice8859.png', 0, [0]],
#  ['/content/train_RGB_i/slice43729.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_RGB_i/slice7470.png', 1, [74.76]],
#  ['/content/train_RGB_i/slice18905.png', 1, [54.41]],
#  ['/content/train_RGB_i/slice3256.png', 2, [202.71, 9.68]],
#  ['/content/train_RGB_i/slice21150.png', 1, [74.76]],
#  ['/content/train_RGB_i/slice41007.png', 0, [0]],
#  ['/content/train_RGB_i/slice17626.png', 2, [194.65, 8.52]],
#  ['/content/train_RGB_i/slice36117.png', 2, [0.12, 201.14]],
#  ['/content/train_RGB_i/slice39444.png', 1, [175.21]],
#  ['/content/train_RGB_i/slice3193.png', 1, [177.05]],
#  ['/content/train_RGB_i/slice24511.png', 2, [0.62, 279.65]],
#  ['/content/train_RGB_i/slice8176.png', 0, [0]],
#  ['/content/train_RGB_i/slice48368.png', 1, [208.25]],
#  ['/content/train_RGB_i/slice5447.png', 0, [0]],
#  ['/content/train_RGB_i/slice16374.png', 2, [0.05, 3.56]],
#  ['/content/train_RGB_i/slice4756.png', 0, [0]],
#  ['/content/train_RGB_i/slice18222.png', 1, [60.17]],
#  ['/content/train_RGB_i/slice21081.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_RGB_i/slice43519.png', 1, [19.67]],
#  ['/content/train_RGB_i/slice11406.png', 1, [191.8]],
#  ['/content/train_RGB_i/slice31403.png', 1, [132.07]],
#  ['/content/train_RGB_i/slice5305.png', 2, [213.66, 8.26]],
#  ['/content/train_RGB_i/slice28456.png', 1, [0.5]],
#  ['/content/train_RGB_i/slice27962.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_RGB_i/slice39491.png', 1, [224.58]],
#  ['/content/train_RGB_i/slice13459.png', 1, [196.02]],
#  ['/content/train_RGB_i/slice44287.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice36153.png', 2, [3.21, 278.18]],
#  ['/content/train_RGB_i/slice32038.png', 1, [272.64]],
#  ['/content/train_RGB_i/slice10701.png', 1, [87.67]],
#  ['/content/train_RGB_i/slice48438.png', 2, [1.53, 251.42]],
#  ['/content/train_RGB_i/slice30497.png', 0, [0]],
#  ['/content/train_RGB_i/slice6577.png', 1, [2.34]],
#  ['/content/train_RGB_i/slice23055.png', 1, [211.01]],
#  ['/content/train_RGB_i/slice15680.png', 2, [4.79, 41.22]],
#  ['/content/train_RGB_i/slice21112.png', 2, [7.13, 250.72]],
#  ['/content/train_RGB_i/slice18341.png', 2, [1.03, 246.09]],
#  ['/content/train_RGB_i/slice14753.png', 0, [0]],
#  ['/content/train_RGB_i/slice8123.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_RGB_i/slice45023.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_RGB_i/slice12769.png', 1, [177.05]],
#  ['/content/train_RGB_i/slice46300.png', 2, [192.82, 10.38]],
#  ['/content/train_RGB_i/slice16311.png', 2, [1.15, 272.53]],
#  ['/content/train_RGB_i/slice1850.png', 2, [0.01, 211.38]],
#  ['/content/train_RGB_i/slice2712.png', 0, [0]],
#  ['/content/train_RGB_i/slice38925.png', 1, [153.86]],
#  ['/content/train_RGB_i/slice43552.png', 1, [187.02]],
#  ['/content/train_RGB_i/slice47655.png', 1, [184.03]],
#  ['/content/train_RGB_i/slice33408.png', 2, [0.13, 272.04]],
#  ['/content/train_RGB_i/slice14760.png', 0, [0]],
#  ['/content/train_RGB_i/slice22301.png', 1, [0.19]],
#  ['/content/train_RGB_i/slice14121.png', 1, [87.67]],
#  ['/content/train_RGB_i/slice45654.png', 2, [215.41, 1.61]],
#  ['/content/train_RGB_i/slice38254.png', 3, [9.86, 1.98, 16.87]],
#  ['/content/train_RGB_i/slice15619.png', 2, [0.62, 279.65]],
#  ['/content/train_RGB_i/slice3821.png', 0, [0]],
#  ['/content/train_RGB_i/slice6005.png', 2, [175.59, 3.52]],
#  ['/content/train_RGB_i/slice10019.png', 1, [104.7]],
#  ['/content/train_RGB_i/slice46309.png', 2, [1.1, 213.14]],
#  ['/content/train_RGB_i/slice6131.png', 0, [0]],
#  ['/content/train_RGB_i/slice35529.png', 1, [0.45]],
#  ['/content/train_RGB_i/slice39410.png', 1, [3.24]],
#  ['/content/train_RGB_i/slice10895.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_RGB_i/slice6010.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_RGB_i/slice24541.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_RGB_i/slice20462.png', 1, [107.99]],
#  ['/content/train_RGB_i/slice32703.png', 2, [0.44, 233.44]],
#  ['/content/train_RGB_i/slice2444.png', 0, [0]],
#  ['/content/train_RGB_i/slice14933.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_RGB_i/slice16962.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_RGB_i/slice37545.png', 2, [4.86, 215.11]],
#  ['/content/train_RGB_i/slice40076.png', 0, [0]],
#  ['/content/train_RGB_i/slice42273.png', 2, [0.12, 201.14]],
#  ['/content/train_RGB_i/slice2668.png', 2, [2.18, 181.76]],
#  ['/content/train_RGB_i/slice1987.png', 1, [169.77]],
#  ['/content/train_RGB_i/slice26503.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice22278.png', 0, [0]],
#  ['/content/train_RGB_i/slice10080.png', 1, [222.54]],
#  ['/content/train_RGB_i/slice15495.png', 1, [130.7]],
#  ['/content/train_RGB_i/slice19662.png', 2, [215.41, 1.61]],
#  ['/content/train_RGB_i/slice44224.png', 1, [136.51]],
#  ['/content/train_RGB_i/slice25926.png', 1, [172.81]],
#  ['/content/train_RGB_i/slice3247.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice44389.png', 2, [4.0, 198.37]],
#  ['/content/train_RGB_i/slice29269.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_RGB_i/slice20432.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_RGB_i/slice1810.png', 1, [95.36]],
#  ['/content/train_RGB_i/slice39433.png', 1, [118.2]],
#  ['/content/train_RGB_i/slice39450.png', 1, [191.8]],
#  ['/content/train_RGB_i/slice27936.png', 2, [0.13, 272.04]],
#  ['/content/train_RGB_i/slice12193.png', 3, [2.22, 2.54, 269.77]],
#  ['/content/train_RGB_i/slice39508.png', 2, [202.71, 9.68]],
#  ['/content/train_RGB_i/slice20909.png', 0, [0]],
#  ['/content/train_RGB_i/slice29134.png', 1, [0.24]],
#  ['/content/train_RGB_i/slice9282.png', 0, [0]],
#  ['/content/train_RGB_i/slice28509.png', 1, [199.23]],
#  ['/content/train_RGB_i/slice9442.png', 1, [207.35]],
#  ['/content/train_RGB_i/slice25187.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_RGB_i/slice14956.png', 2, [7.13, 250.72]],
#  ['/content/train_RGB_i/slice43543.png', 2, [1.44, 153.02]],
#  ['/content/train_RGB_i/slice21677.png', 2, [195.37, 9.54]],
#  ['/content/train_RGB_i/slice12157.png', 2, [179.64, 5.91]],
#  ['/content/train_RGB_i/slice16208.png', 2, [201.69, 7.33]],
#  ['/content/train_RGB_i/slice16332.png', 4, [0.81, 0.22, 1.42, 237.33]],
#  ['/content/train_RGB_i/slice27211.png', 2, [171.82, 1.59]],
#  ['/content/train_RGB_i/slice40278.png', 2, [3.85, 223.1]],
#  ['/content/train_RGB_i/slice2552.png', 1, [224.54]],
#  ['/content/train_RGB_i/slice32810.png', 0, [0]],
#  ['/content/train_RGB_i/slice15509.png', 1, [189.94]],
#  ['/content/train_RGB_i/slice44988.png', 2, [183.3, 6.6]],
#  ['/content/train_RGB_i/slice5906.png', 1, [38.63]],
#  ['/content/train_RGB_i/slice10680.png', 2, [0.0, 0.01]],
#  ['/content/train_RGB_i/slice14819.png', 1, [171.6]],
#  ['/content/train_RGB_i/slice11437.png', 1, [207.02]],
#  ['/content/train_RGB_i/slice28573.png', 2, [179.64, 5.91]],
#  ['/content/train_RGB_i/slice14814.png', 1, [146.83]],
#  ['/content/train_RGB_i/slice37412.png', 2, [201.69, 7.33]],
#  ['/content/train_RGB_i/slice42167.png', 1, [104.7]],
#  ['/content/train_RGB_i/slice24357.png', 0, [0]],
#  ['/content/train_RGB_i/slice27136.png', 1, [187.02]],
#  ['/content/train_RGB_i/slice8634.png', 1, [13.52]],
#  ['/content/train_RGB_i/slice20944.png', 1, [6.91]],
#  ['/content/train_RGB_i/slice38936.png', 2, [4.79, 41.22]],
#  ['/content/train_RGB_i/slice20451.png', 2, [2.57, 186.09]],
#  ['/content/train_RGB_i/slice5318.png', 2, [179.16, 5.34]],
#  ['/content/train_RGB_i/slice48426.png', 3, [0.7, 0.07, 193.53]],
#  ['/content/train_RGB_i/slice2615.png', 4, [0.57, 1.98, 0.86, 267.39]],
#  ['/content/train_RGB_i/slice12866.png', 2, [0.28, 230.25]],
#  ['/content/train_RGB_i/slice43680.png', 2, [4.91, 260.75]],
#  ['/content/train_RGB_i/slice41559.png', 2, [203.74, 9.59]],
#  ['/content/train_RGB_i/slice30536.png', 1, [78.83]],
#  ['/content/train_RGB_i/slice38852.png', 2, [0.48, 198.31]],
#  ['/content/train_RGB_i/slice36057.png', 1, [207.78]],
#  ['/content/train_RGB_i/slice48346.png', 1, [199.79]],
#  ['/content/train_RGB_i/slice19016.png', 2, [0.48, 198.31]],
#  ['/content/train_RGB_i/slice6676.png', 2, [202.71, 9.68]],
#  ['/content/train_RGB_i/slice43546.png', 1, [169.98]],
#  ['/content/train_RGB_i/slice8129.png', 2, [3.53, 225.61]],
#  ['/content/train_RGB_i/slice43558.png', 1, [199.79]],
#  ['/content/train_RGB_i/slice17503.png', 0, [0]],
#  ['/content/train_RGB_i/slice31947.png', 1, [211.01]],
#  ['/content/train_RGB_i/slice11498.png', 2, [0.28, 230.25]],
#  ['/content/train_RGB_i/slice10205.png', 1, [84.71]],
#  ['/content/train_RGB_i/slice21071.png', 1, [212.75]],
#  ['/content/train_RGB_i/slice8664.png', 1, [175.21]],
#  ['/content/train_RGB_i/slice519.png', 2, [203.74, 9.59]],
#  ['/content/train_RGB_i/slice23767.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice45533.png', 0, [0]],
#  ['/content/train_RGB_i/slice36218.png', 0, [0]],
#  ['/content/train_RGB_i/slice17551.png', 2, [1.44, 153.02]],
#  ['/content/train_RGB_i/slice24463.png', 2, [196.96, 11.58]],
#  ['/content/train_RGB_i/slice25108.png', 1, [210.25]],
#  ['/content/train_RGB_i/slice23729.png', 2, [195.37, 9.54]],
#  ['/content/train_RGB_i/slice20289.png', 2, [2.59, 164.07]],
#  ['/content/train_RGB_i/slice7274.png', 1, [38.63]],
#  ['/content/train_RGB_i/slice38939.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_RGB_i/slice34061.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_RGB_i/slice5910.png', 1, [60.17]],
#  ['/content/train_RGB_i/slice35326.png', 1, [95.36]],
#  ['/content/train_RGB_i/slice40081.png', 1, [1.24]],
#  ['/content/train_RGB_i/slice27187.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice47831.png', 3, [7.78, 1.06, 14.58]],
#  ['/content/train_RGB_i/slice16860.png', 1, [114.22]],
#  ['/content/train_RGB_i/slice20418.png', 2, [2.83, 280.34]],
#  ['/content/train_RGB_i/slice11338.png', 0, [0]],
#  ['/content/train_RGB_i/slice1106.png', 1, [3.24]],
#  ['/content/train_RGB_i/slice2518.png', 1, [199.79]],
#  ['/content/train_RGB_i/slice18413.png', 1, [84.71]],
#  ['/content/train_RGB_i/slice11532.png', 2, [4.91, 260.75]],
#  ['/content/train_RGB_i/slice1982.png', 2, [3.15, 191.52]],
#  ['/content/train_RGB_i/slice22440.png', 1, [218.98]],
#  ['/content/train_RGB_i/slice3191.png', 1, [171.6]],
#  ['/content/train_RGB_i/slice43737.png', 1, [0.45]],
#  ['/content/train_RGB_i/slice25921.png', 2, [4.0, 198.37]],
#  ['/content/train_RGB_i/slice19596.png', 1, [114.22]],
#  ['/content/train_RGB_i/slice29886.png', 2, [196.65, 8.59]],
#  ['/content/train_RGB_i/slice6783.png', 1, [100.85]],
#  ['/content/train_RGB_i/slice39523.png', 2, [171.82, 1.59]],
#  ['/content/train_RGB_i/slice27932.png', 1, [277.02]],
#  ['/content/train_RGB_i/slice11471.png', 2, [188.25, 7.57]],
#  ['/content/train_RGB_i/slice3263.png', 2, [188.25, 7.57]],
#  ['/content/train_RGB_i/slice1893.png', 2, [194.95, 9.05]],
#  ['/content/train_RGB_i/slice5243.png', 1, [171.6]],
#  ['/content/train_RGB_i/slice41659.png', 1, [169.77]],
#  ['/content/train_RGB_i/slice554.png', 2, [0.28, 230.25]],
#  ['/content/train_RGB_i/slice33953.png', 1, [54.41]],
#  ['/content/train_RGB_i/slice18396.png', 2, [4.72, 204.21]],
#  ['/content/train_RGB_i/slice43051.png', 2, [0.2, 1.98]],
#  ['/content/train_RGB_i/slice27131.png', 1, [171.6]],
#  ['/content/train_RGB_i/slice33263.png', 1, [28.46]],
#  ['/content/train_RGB_i/slice44872.png', 1, [0.5]],
#  ['/content/train_RGB_i/slice36810.png', 2, [1.53, 251.42]],
#  ['/content/train_RGB_i/slice17038.png', 1, [142.95]],
#  ['/content/train_RGB_i/slice25720.png', 1, [0.5]],
#  ['/content/train_RGB_i/slice29927.png', 2, [212.87, 6.28]],
#  ['/content/train_RGB_i/slice16186.png', 1, [169.98]],
#  ['/content/train_RGB_i/slice29303.png', 1, [271.15]],
#  ['/content/train_RGB_i/slice19025.png', 2, [1.03, 246.09]],
#  ['/content/train_RGB_i/slice40773.png', 0, [0]],
#  ['/content/train_RGB_i/slice38877.png', 1, [273.22]],
#  ['/content/train_RGB_i/slice29892.png', 2, [2.12, 210.69]],
#  ['/content/train_RGB_i/slice42800.png', 0, [0]],
#  ['/content/train_RGB_i/slice19549.png', 0, [0]],
#  ['/content/train_RGB_i/slice40071.png', 0, [0]],
#  ['/content/train_RGB_i/slice28703.png', 0, [0]],
#  ['/content/train_RGB_i/slice2693.png', 2, [0.09, 5.38]],
#  ['/content/train_RGB_i/slice21723.png', 2, [203.74, 9.59]],
#  ['/content/train_RGB_i/slice16282.png', 1, [207.35]],
#  ['/content/train_RGB_i/slice30510.png', 0, [0]],
#  ['/content/train_RGB_i/slice42155.png', 1, [28.46]],
#  ['/content/train_RGB_i/slice39421.png', 1, [33.77]],
#  ['/content/train_RGB_i/slice2644.png', 2, [7.13, 250.72]],
#  ['/content/train_RGB_i/slice9355.png', 1, [196.02]],
#  ['/content/train_RGB_i/slice44315.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_RGB_i/slice34142.png', 1, [107.99]],
#  ['/content/train_RGB_i/slice48339.png', 1, [184.03]],
#  ['/content/train_RGB_i/slice45592.png', 1, [136.51]],
#  ['/content/train_RGB_i/slice36665.png', 1, [0.19]],
#  ['/content/train_RGB_i/slice23201.png', 1, [84.71]],
#  ['/content/train_RGB_i/slice7431.png', 2, [6.54, 252.78]],
#  ['/content/train_RGB_i/slice15578.png', 2, [179.16, 5.34]],
#  ['/content/train_RGB_i/slice45685.png', 3, [0.66, 2.46, 170.74]],
#  ['/content/train_RGB_i/slice40754.png', 0, [0]],
#  ['/content/train_RGB_i/slice14207.png', 2, [188.25, 7.57]],
#  ['/content/train_RGB_i/slice6547.png', 0, [0]],
#  ['/content/train_RGB_i/slice28554.png', 2, [215.41, 1.61]],
#  ['/content/train_RGB_i/slice13652.png', 0, [0]],
#  ['/content/train_RGB_i/slice14890.png', 2, [194.65, 8.52]],
#  ['/content/train_RGB_i/slice34053.png', 4, [9.29, 1.52, 149.57, 0.57]],
#  ['/content/train_RGB_i/slice46439.png', 2, [5.53, 209.39]],
#  ['/content/train_RGB_i/slice7358.png', 2, [207.31, 8.92]],
#  ['/content/train_RGB_i/slice45003.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_RGB_i/slice37529.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_RGB_i/slice12117.png', 1, [207.78]],
#  ['/content/train_RGB_i/slice15450.png', 0, [0]],
#  ['/content/train_RGB_i/slice33970.png', 1, [169.98]],
#  ['/content/train_RGB_i/slice1882.png', 2, [210.46, 5.48]],
#  ['/content/train_RGB_i/slice6589.png', 1, [33.77]],
#  ['/content/train_RGB_i/slice16377.png', 1, [0.45]],
#  ['/content/train_RGB_i/slice42149.png', 1, [9.26]],
#  ['/content/train_RGB_i/slice40309.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_RGB_i/slice35476.png', 2, [7.13, 250.72]],
#  ['/content/train_RGB_i/slice19034.png', 3, [1.88, 2.34, 270.21]],
#  ['/content/train_RGB_i/slice20303.png', 2, [186.43, 15.39]],
#  ['/content/train_RGB_i/slice31973.png', 2, [218.16, 1.01]],
#  ['/content/train_RGB_i/slice25013.png', 0, [0]],
#  ['/content/train_RGB_i/slice37325.png', 0, [0]],
#  ['/content/train_RGB_i/slice35335.png', 2, [1.44, 153.02]],
#  ['/content/train_RGB_i/slice33321.png', 1, [207.78]],
#  ['/content/train_RGB_i/slice21646.png', 1, [95.36]],
#  ['/content/train_RGB_i/slice41578.png', 4, [8.39, 2.01, 154.38, 0.69]],
#  ['/content/train_RGB_i/slice2472.png', 2, [0.0, 0.01]],
#  ['/content/train_RGB_i/slice8597.png', 0, [0]],
#  ['/content/train_RGB_i/slice43593.png', 1, [227.05]],
#  ['/content/train_RGB_i/slice39381.png', 0, [0]],
#  ['/content/train_RGB_i/slice47855.png', 0, [0]],
#  ['/content/train_RGB_i/slice34102.png', 2, [2.84, 279.11]],
#  ['/content/train_RGB_i/slice25249.png', 1, [114.8]],
#  ['/content/train_RGB_i/slice1344.png', 0, [0]],
#  ['/content/train_RGB_i/slice25129.png', 1, [221.77]],
#  ['/content/train_RGB_i/slice9356.png', 1, [197.47]],
#  ['/content/train_RGB_i/slice27840.png', 2, [2.12, 210.69]],
#  ['/content/train_RGB_i/slice15545.png', 1, [217.26]],
#  ['/content/train_RGB_i/slice16877.png', 1, [189.94]],
#  ['/content/train_RGB_i/slice38854.png', 1, [207.35]],
#  ['/content/train_RGB_i/slice48302.png', 1, [3.24]],
#  ['/content/train_RGB_i/slice19544.png', 0, [0]],
#  ['/content/train_RGB_i/slice40867.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice18928.png', 1, [187.02]],
#  ['/content/train_RGB_i/slice23885.png', 1, [84.71]],
#  ['/content/train_RGB_i/slice12182.png', 2, [0.28, 230.25]],
#  ['/content/train_RGB_i/slice3932.png', 2, [212.61, 3.06]],
#  ['/content/train_RGB_i/slice35289.png', 0, [0]],
#  ['/content/train_RGB_i/slice3177.png', 1, [87.67]],
#  ['/content/train_RGB_i/slice36865.png', 2, [4.0, 198.37]],
#  ['/content/train_RGB_i/slice20936.png', 0, [0]],
#  ['/content/train_RGB_i/slice38781.png', 2, [203.84, 6.54]],
#  ['/content/train_RGB_i/slice35976.png', 1, [1.22]],
#  ['/content/train_RGB_i/slice40317.png', 1, [0.45]],
#  ['/content/train_RGB_i/slice42903.png', 1, [212.82]],
#  ['/content/train_RGB_i/slice38758.png', 1, [169.98]],
#  ['/content/train_RGB_i/slice5870.png', 0, [0]],
#  ['/content/train_RGB_i/slice39517.png', 2, [179.64, 5.91]],
#  ['/content/train_RGB_i/slice1813.png', 1, [118.2]],
#  ['/content/train_RGB_i/slice40165.png', 1, [207.02]],
#  ['/content/train_RGB_i/slice9984.png', 1, [1.22]],
#  ['/content/train_RGB_i/slice25752.png', 1, [114.22]],
#  ['/content/train_RGB_i/slice32644.png', 1, [214.85]],
#  ['/content/train_RGB_i/slice40271.png', 4, [0.34, 0.42, 2.16, 238.59]],
#  ['/content/train_RGB_i/slice15015.png', 0, [0]],
#  ['/content/train_RGB_i/slice3906.png', 1, [209.22]],
#  ['/content/train_RGB_i/slice22303.png', 0, [0]],
#  ['/content/train_RGB_i/slice41585.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_RGB_i/slice9504.png', 2, [4.72, 204.21]],
#  ['/content/train_RGB_i/slice33911.png', 0, [0]],
#  ['/content/train_RGB_i/slice7939.png', 0, [0]],
#  ['/content/train_RGB_i/slice10174.png', 3, [0.73, 3.1, 239.17]],
#  ['/content/train_RGB_i/slice8691.png', 1, [211.01]],
#  ['/content/train_RGB_i/slice35502.png', 1, [172.81]],
#  ['/content/train_RGB_i/slice27152.png', 2, [201.69, 7.33]],
#  ['/content/train_RGB_i/slice44926.png', 1, [199.79]],
#  ['/content/train_RGB_i/slice29324.png', 3, [1.34, 5.61, 241.11]],
#  ['/content/train_RGB_i/slice21016.png', 1, [214.85]],
#  ['/content/train_RGB_i/slice10225.png', 0, [0]],
#  ['/content/train_RGB_i/slice16955.png', 3, [7.37, 2.16, 158.18]],
#  ['/content/train_RGB_i/slice35505.png', 1, [153.86]],
#  ['/content/train_RGB_i/slice1962.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_RGB_i/slice3962.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_RGB_i/slice14846.png', 2, [0.01, 211.38]],
#  ['/content/train_RGB_i/slice20911.png', 0, [0]],
#  ['/content/train_RGB_i/slice14102.png', 1, [3.24]],
#  ['/content/train_RGB_i/slice36079.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice3153.png', 0, [0]],
#  ['/content/train_RGB_i/slice7397.png', 2, [1.03, 246.09]],
#  ['/content/train_RGB_i/slice28690.png', 1, [0.44]],
#  ['/content/train_RGB_i/slice21744.png', 3, [2.62, 2.06, 163.57]],
#  ['/content/train_RGB_i/slice19084.png', 2, [2.18, 181.76]],
#  ['/content/train_RGB_i/slice44981.png', 2, [198.28, 10.12]],
#  ['/content/train_RGB_i/slice22518.png', 1, [74.76]],
#  ['/content/train_RGB_i/slice42127.png', 0, [0]],
#  ['/content/train_RGB_i/slice47167.png', 0, [0]],
#  ['/content/train_RGB_i/slice3967.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_RGB_i/slice4624.png', 2, [202.71, 9.68]],
#  ['/content/train_RGB_i/slice17742.png', 2, [0.05, 3.56]],
#  ['/content/train_RGB_i/slice12068.png', 1, [78.83]],
#  ['/content/train_RGB_i/slice22366.png', 2, [205.58, 5.93]],
#  ['/content/train_RGB_i/slice12967.png', 0, [0]],
#  ['/content/train_RGB_i/slice44239.png', 1, [196.02]],
#  ['/content/train_RGB_i/slice1759.png', 0, [0]],
#  ['/content/train_RGB_i/slice29947.png', 2, [171.82, 1.59]],
#  ['/content/train_RGB_i/slice10811.png', 1, [212.75]],
#  ['/content/train_RGB_i/slice32654.png', 1, [221.64]],
#  ['/content/train_RGB_i/slice17711.png', 2, [5.53, 209.39]],
#  ['/content/train_RGB_i/slice14873.png', 2, [218.16, 1.01]],
#  ['/content/train_RGB_i/slice45737.png', 3, [1.94, 7.4, 248.6]],
#  ['/content/train_RGB_i/slice33219.png', 0, [0]],
#  ['/content/train_RGB_i/slice36120.png', 1, [218.98]],
#  ['/content/train_RGB_i/slice8736.png', 2, [183.3, 6.6]],
#  ['/content/train_RGB_i/slice46987.png', 2, [198.05, 8.0]],
#  ['/content/train_RGB_i/slice49044.png', 2, [2.12, 210.69]],
#  ['/content/train_RGB_i/slice38878.png', 1, [272.64]],
#  ['/content/train_RGB_i/slice27192.png', 2, [218.66, 7.9]],
#  ['/content/train_RGB_i/slice1919.png', 1, [212.75]],
#  ['/content/train_RGB_i/slice12913.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_RGB_i/slice16241.png', 2, [218.16, 1.01]],
#  ['/content/train_RGB_i/slice47103.png', 2, [6.54, 252.78]],
#  ['/content/train_RGB_i/slice2492.png', 1, [78.83]],
#  ['/content/train_RGB_i/slice18967.png', 1, [222.0]],
#  ['/content/train_RGB_i/slice32073.png', 2, [4.86, 215.11]],
#  ['/content/train_RGB_i/slice45587.png', 1, [104.7]],
#  ['/content/train_RGB_i/slice30625.png', 2, [179.64, 5.91]],
#  ['/content/train_RGB_i/slice45031.png', 2, [0.62, 279.65]],
#  ['/content/train_RGB_i/slice31377.png', 3, [1.39, 4.72, 242.28]],
#  ['/content/train_RGB_i/slice17694.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_RGB_i/slice31277.png', 1, [217.26]],
#  ['/content/train_RGB_i/slice45061.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_RGB_i/slice12222.png', 3, [1.51, 6.99, 243.14]],
#  ['/content/train_RGB_i/slice22306.png', 0, [0]],
#  ['/content/train_RGB_i/slice21093.png', 1, [273.22]],
#  ['/content/train_RGB_i/slice44851.png', 0, [0]],
#  ['/content/train_RGB_i/slice3952.png', 2, [180.17, 4.18]],
#  ['/content/train_RGB_i/slice18927.png', 1, [184.03]],
#  ['/content/train_RGB_i/slice20469.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_RGB_i/slice27105.png', 1, [23.71]],
#  ['/content/train_RGB_i/slice38256.png', 3, [2.53, 0.54, 10.7]],
#  ['/content/train_RGB_i/slice41495.png', 1, [171.6]],
#  ['/content/train_RGB_i/slice16351.png', 1, [169.77]],
#  ['/content/train_RGB_i/slice42876.png', 2, [187.46, 15.31]],
#  ['/content/train_RGB_i/slice44307.png', 2, [179.64, 4.51]],
#  ['/content/train_RGB_i/slice34678.png', 2, [205.58, 5.93]],
#  ['/content/train_RGB_i/slice21673.png', 2, [189.52, 15.4]],
#  ['/content/train_RGB_i/slice30063.png', 0, [0]],
#  ['/content/train_RGB_i/slice21122.png', 4, [2.67, 0.16, 0.83, 233.67]],
#  ['/content/train_RGB_i/slice36651.png', 0, [0]],
#  ['/content/train_RGB_i/slice10027.png', 2, [1.44, 153.02]],
#  ['/content/train_RGB_i/slice46235.png', 1, [0.61]],
#  ['/content/train_RGB_i/slice44928.png', 2, [187.46, 15.31]],
#  ['/content/train_RGB_i/slice12242.png', 2, [3.15, 191.52]],
#  ['/content/train_RGB_i/slice48978.png', 0, [0]],
#  ['/content/train_RGB_i/slice41527.png', 1, [208.69]],
#  ['/content/train_RGB_i/slice43637.png', 3, [1.08, 0.08, 188.82]],
#  ['/content/train_RGB_i/slice9493.png', 4, [1.56, 0.19, 1.06, 234.35]],
#  ['/content/train_RGB_i/slice5364.png', 2, [0.13, 272.04]],
#  ['/content/train_RGB_i/slice10736.png', 2, [201.69, 7.33]],
#  ['/content/train_RGB_i/slice2541.png', 1, [207.78]],
#  ['/content/train_RGB_i/slice43659.png', 3, [1.92, 2.51, 276.89]],
#  ['/content/train_RGB_i/slice39497.png', 2, [218.16, 1.01]],
#  ['/content/train_RGB_i/slice42299.png', 1, [271.15]],
#  ['/content/train_RGB_i/slice2007.png', 2, [0.3, 6.3]],
#  ['/content/train_RGB_i/slice11487.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_RGB_i/slice45691.png', 3, [0.54, 0.09, 198.0]],
#  ['/content/train_RGB_i/slice24498.png', 2, [1.53, 251.42]],
#  ['/content/train_RGB_i/slice9290.png', 0, [0]],
#  ['/content/train_RGB_i/slice48396.png', 2, [218.66, 7.9]],
#  ['/content/train_RGB_i/slice36073.png', 1, [221.77]],
#  ['/content/train_RGB_i/slice23050.png', 2, [205.58, 5.93]],
#  ['/content/train_RGB_i/slice8751.png', 3, [1.91, 0.15, 181.37]],
#  ['/content/train_RGB_i/slice44855.png', 0, [0]],
#  ['/content/train_RGB_i/slice41433.png', 0, [0]],
#  ['/content/train_RGB_i/slice20958.png', 1, [60.17]],
#  ['/content/train_RGB_i/slice32653.png', 1, [221.77]],
#  ['/content/train_RGB_i/slice21172.png', 0, [0]],
#  ['/content/train_RGB_i/slice7461.png', 1, [153.86]],
#  ['/content/train_RGB_i/slice7997.png', 2, [195.37, 9.54]],
#  ['/content/train_RGB_i/slice12277.png', 0, [0]],
#  ['/content/train_RGB_i/slice27097.png', 1, [2.34]],
#  ['/content/train_RGB_i/slice11458.png', 2, [210.46, 5.48]],
#  ['/content/train_RGB_i/slice42863.png', 1, [171.6]],
#  ['/content/train_RGB_i/slice5924.png', 2, [1.84, 157.64]],
#  ['/content/train_RGB_i/slice46903.png', 0, [0]],
#  ['/content/train_RGB_i/slice38146.png', 2, [194.65, 8.52]],
#  ['/content/train_RGB_i/slice6047.png', 1, [271.15]],
#  ['/content/train_RGB_i/slice24602.png', 0, [0]],
#  ['/content/train_RGB_i/slice12049.png', 1, [2.34]],
#  ['/content/train_RGB_i/slice6059.png', 3, [1.19, 4.91, 264.29]],
#  ['/content/train_RGB_i/slice42361.png', 3, [0.71, 0.36, 7.7]],
#  ['/content/train_RGB_i/slice5299.png', 2, [213.14, 2.09]],
#  ['/content/train_RGB_i/slice1084.png', 0, [0]],
#  ['/content/train_RGB_i/slice12142.png', 2, [210.46, 5.48]],
#  ['/content/train_RGB_i/slice18895.png', 1, [19.67]],
#  ['/content/train_RGB_i/slice3233.png', 1, [217.26]],
#  ['/content/train_RGB_i/slice18203.png', 0, [0]],
#  ['/content/train_RGB_i/slice34173.png', 0, [0]],
#  ['/content/train_RGB_i/slice24440.png', 1, [224.54]],
#  ['/content/train_RGB_i/slice12200.png', 1, [277.02]],
#  ['/content/train_RGB_i/slice42206.png', 2, [0.01, 211.38]],
#  ['/content/train_RGB_i/slice7448.png', 2, [4.59, 218.29]],
#  ['/content/train_RGB_i/slice47127.png', 2, [2.57, 186.09]],
#  ['/content/train_RGB_i/slice7388.png', 2, [0.48, 198.31]],
#  ['/content/train_RGB_i/slice29943.png', 2, [179.64, 4.51]],
#  ['/content/train_RGB_i/slice4675.png', 2, [0.62, 279.65]],
#  ['/content/train_RGB_i/slice20253.png', 0, [0]],
#  ['/content/train_RGB_i/slice13629.png', 3, [12.57, 2.95, 20.35]],
#  ['/content/train_RGB_i/slice42804.png', 0, [0]],
#  ['/content/train_RGB_i/slice16172.png', 1, [78.83]],
#  ['/content/train_RGB_i/slice12868.png', 2, [0.91, 241.08]],
#  ['/content/train_RGB_i/slice47612.png', 0, [0]],
#  ['/content/train_RGB_i/slice33259.png', 1, [19.67]],
#  ['/content/train_RGB_i/slice26546.png', 2, [0.28, 230.25]],
#  ['/content/train_RGB_i/slice7259.png', 0, [0]],
#  ['/content/train_RGB_i/slice6730.png', 1, [272.64]],
#  ['/content/train_RGB_i/slice14144.png', 1, [197.47]],
#  ['/content/train_RGB_i/slice47054.png', 3, [2.95, 0.21, 180.6]],
#  ['/content/train_RGB_i/slice39471.png', 1, [211.01]],
#  ['/content/train_RGB_i/slice18225.png', 1, [87.67]],
#  ['/content/train_RGB_i/slice32623.png', 2, [198.05, 8.0]],
#  ['/content/train_RGB_i/slice30565.png', 2, [189.52, 15.4]],
#  ['/content/train_RGB_i/slice29286.png', 2, [1.53, 251.42]],
#  ['/content/train_RGB_i/slice9328.png', 1, [47.53]],
#  ['/content/train_RGB_i/slice34017.png', 1, [227.05]],
#  ['/content/train_RGB_i/slice20976.png', 1, [175.21]],
#  ['/content/train_RGB_i/slice29215.png', 1, [208.69]],
#  ['/content/train_RGB_i/slice32788.png', 2, [0.77, 5.62]],
#  ['/content/train_RGB_i/slice21765.png', 4, [0.44, 1.36, 0.22, 261.14]],
#  ['/content/train_RGB_i/slice23010.png', 1, [60.17]],
#  ['/content/train_RGB_i/slice17762.png', 0, [0]],
#  ['/content/train_RGB_i/slice3877.png', 1, [177.05]],
#  ['/content/train_RGB_i/slice8777.png', 3, [1.31, 1.06, 279.14]],
#  ['/content/train_RGB_i/slice44246.png', 2, [190.5, 12.86]],
#  ['/content/train_RGB_i/slice22330.png', 1, [95.36]],
#  ['/content/train_RGB_i/slice10237.png', 0, [0]],
#  ['/content/train_RGB_i/slice21180.png', 0, [0]],
#  ...]

# %%
'''!rm -rf '/content/mask_class A/'
# !rm -rf '/content/mask_class B/'
# !rm -rf '/content/mask_class E/' # Cancer
# !rm -rf '/content/mask_class 0/'

# !rm -rf '/content/image_class A/'
# !rm -rf '/content/image_class B/'
# !rm -rf '/content/image_class E/' # Cancer
# !rm -rf '/content/image_class 0/'

# !rm -rf '/content/train_m1/'
# !rm -rf '/content/train_i1/'''

# %%
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/mask_class A/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/mask_class B/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/mask_class E/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/mask_class 0/')

os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_class A/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_class B/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_class E/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_class 0/')

os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_RGB_class A/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_RGB_class B/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_RGB_class E/')
os.mkdir('/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_RGB_class 0/')

# %%
''' 1 <=2 => 0
    1 : 3 <=3 => A
    otherwise => B
    0 => E
'''
modelLabel = []

for i in range(len(lst)) :

    if lst[i][1] == 0:
      shutil.copy(lst_image[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_class E/")
      shutil.copy(lst[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/mask_class E/")
      shutil.copy(lst_RGB_image[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_RGB_class E/")

      modelLabel.append([lst_image[i][0], lst_RGB_image[i][0], lst[i][0], lst[i][1], lst[i][2], "E" ])

    elif lst[i][1] == 1 and max(lst[i][2]) <= 2:
      shutil.copy(lst_image[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_class 0/")
      shutil.copy(lst[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/mask_class 0/")
      shutil.copy(lst_RGB_image[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_RGB_class 0/")

      modelLabel.append([lst_image[i][0], lst_RGB_image[i][0], lst[i][0], lst[i][1], lst[i][2], "0" ])

    elif lst[i][1] >= 1 and lst[i][1] <= 3 and max(lst[i][2]) <= 3:
      shutil.copy(lst_image[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_class A/")
      shutil.copy(lst[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/mask_class A/")
      shutil.copy(lst_RGB_image[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_RGB_class A/")

      modelLabel.append([lst_image[i][0], lst_RGB_image[i][0], lst[i][0], lst[i][1], lst[i][2], "A" ])

    else:
      shutil.copy(lst_image[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_class B/")
      shutil.copy(lst[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/mask_class B/")
      shutil.copy(lst_RGB_image[i][0], "/content/gdrive/MyDrive/Graduation Project /GP_FirstModels/image_RGB_class B/")

      modelLabel.append([lst_image[i][0], lst_RGB_image[i][0], lst[i][0], lst[i][1], lst[i][2], "B" ])

# %%
# importing the csv module
import csv

# field names
fields = ['Path Gray Image','Path RGB Image','Path Mask', 'Object Counter', 'Objects Size', 'Class']

# data rows of csv file
rows = modelLabel

# name of csv file
filename = "ModelLabels.csv"

# writing to csv file
with open(filename, 'w') as csvfile:
	# creating a csv writer object
	csvwriter = csv.writer(csvfile)

	# writing the fields
	csvwriter.writerow(fields)

	# writing the data rows
	csvwriter.writerows(rows)


from csv import DictReader

# open file in read mode
with open("ModelLabels.csv", 'r') as f:

    dict_reader = DictReader(f)

    list_of_dict = list(dict_reader)

    print(list_of_dict)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
